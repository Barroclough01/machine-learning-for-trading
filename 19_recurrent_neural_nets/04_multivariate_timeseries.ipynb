# %% [markdown]
# # Multivariate Time Series Regression

# %% [markdown]
# So far, we have limited our modeling efforts to single time series. RNNs are naturally well suited to multivariate time series and represent a non-linear alternative to the Vector Autoregressive (VAR) models we covered in Chapter 8, Time Series Models.

# %% [markdown]
# ## Imports & Settings

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
# %matplotlib inline

from pathlib import Path
import numpy as np
import pandas as pd
import pandas_datareader.data as web

from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import minmax_scale

import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, LSTM
import tensorflow.keras.backend as K

import matplotlib.pyplot as plt
import seaborn as sns

# %%
gpu_devices = tf.config.experimental.list_physical_devices("GPU")
if gpu_devices:
    print("Using GPU")
    tf.config.experimental.set_memory_growth(gpu_devices[0], True)
else:
    print("Using CPU")
# Out:
# Using CPU

# %%
sns.set_style("whitegrid")
np.random.seed(42)

# %%
results_path = Path("results", "multivariate_time_series")
if not results_path.exists():
    results_path.mkdir(parents=True)

# %% [markdown]
# ## Load Data

# %% [markdown]
# For comparison, we illustrate the application of RNNs to modeling and forecasting several time series using the same dataset we used for the VAR example, monthly data on consumer sentiment, and industrial production from the Federal Reserve's FRED service in Chapter 8, Time Series Models:

# %%
df = web.DataReader(["UMCSENT", "IPGMFN"], "fred", "1980", "2019-12").dropna()
df.columns = ["sentiment", "ip"]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 480 entries, 1980-01-01 to 2019-12-01
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   sentiment  480 non-null    float64
#  1   ip         480 non-null    float64
# dtypes: float64(2)
# memory usage: 11.2 KB

# %%
df.head()
# Out:
#             sentiment       ip
# DATE
# 1980-01-01       67.0  45.8562
# 1980-02-01       66.9  46.9435
# 1980-03-01       56.5  47.5013
# 1980-04-01       52.7  46.1175
# 1980-05-01       51.7  44.7997

# %% [markdown]
# ## Prepare Data

# %% [markdown]
# ### Stationarity

# %% [markdown]
# We apply the same transformation—annual difference for both series, prior log-transform for industrial production—to achieve stationarity that we used in Chapter 8 on Time Series Models:

# %%
df_transformed = pd.DataFrame(
    { "sentiment": df.sentiment.diff(12), "ip": np.log(df.ip).diff(12)}
).dropna()

# %% [markdown]
# ### Scaling

# %% [markdown]
# Then we scale the transformed data to the [0,1] interval:

# %%
df_transformed = df_transformed.apply(minmax_scale)

# %% [markdown]
# ### Plot original and transformed series

# %%
fig, axes = plt.subplots(ncols=2, figsize=(14, 4))
columns = {"ip": "Industrial Production", "sentiment": "Sentiment"}
df.rename(columns=columns).plot(ax=axes[0], title="Original Series")
df_transformed.rename(columns=columns).plot(ax=axes[1], title="Transformed Series")
sns.despine()
fig.tight_layout()
fig.savefig(results_path / "multi_rnn", dpi=300)

# %% [markdown]
# ### Reshape data into RNN format

# %% [markdown]
# We can reshape directly to get non-overlapping series, i.e., one sample for each year (works only if the number of samples is divisible by window size):

# %%
df.values.reshape(-1, 12, 2).shape
# Out:
# (40, 12, 2)

# %% [markdown]
# However, we want rolling, not non-overlapping lagged values. The create_multivariate_rnn_data function transforms a dataset of several time series into the shape required by the Keras RNN layers, namely `n_samples` x `window_size` x `n_series`, as follows:

# %%
def create_multivariate_rnn_data(data, window_size):
    y = data[window_size:]
    n = data.shape[0]
    X = np.stack([data[i:j] for i, j in enumerate(range(window_size, n))], axis=0)
    return X, y

# %% [markdown]
# We will use window_size of 24 months and obtain the desired inputs for our RNN model, as follows:

# %%
window_size = 18

# %%
X, y = create_multivariate_rnn_data(df_transformed, window_size=window_size)

# %%
X.shape, y.shape
# Out:
# ((450, 18, 2), (450, 2))

# %%
df_transformed.head()
# Out:
#             sentiment        ip
# DATE
# 1981-01-01   0.576214  0.529737
# 1981-02-01   0.502513  0.517451
# 1981-03-01   0.670017  0.545862
# 1981-04-01   0.832496  0.616060
# 1981-05-01   0.914573  0.734106

# %% [markdown]
# Finally, we split our data into a train and a test set, using the last 24 months to test the out-of-sample performance, as shown here:

# %%
test_size = 24
train_size = X.shape[0] - test_size

# %%
X_train, y_train = X[:train_size], y[:train_size]
X_test, y_test = X[train_size:], y[train_size:]

# %%
X_train.shape, X_test.shape
# Out:
# ((426, 18, 2), (24, 18, 2))

# %% [markdown]
# ## Define Model Architecture

# %% [markdown]
# We use a similar architecture with two stacked LSTM layers with 12 and 6 units, respectively, followed by a fully-connected layer with 10 units. The output layer has two units, one for each time series. We compile them using mean absolute loss and the recommended RMSProp optimizer, as follows:

# %%
n_features = output_size = 2

# %%
lstm_units = 12
dense_units = 6

# %%
rnn = Sequential(
    [
        LSTM(
            units=lstm_units,
            dropout=0.1,
            recurrent_dropout=0.1,
            input_shape=(window_size, n_features),
            name="LSTM",
            return_sequences=False,
        ),
        Dense(dense_units, name="FC"),
        Dense(output_size, name="Output"),
    ]
)

# %% [markdown]
# The model has 1,268 parameters, as shown here:

# %%
rnn.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ LSTM (LSTM)                     │ (None, 12)             │           720 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ FC (Dense)                      │ (None, 6)              │            78 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output (Dense)                  │ (None, 2)              │            14 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 812 (3.17 KB)
#  Trainable params: 812 (3.17 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
rnn.compile(loss="mae", optimizer="RMSProp")

# %% [markdown]
# ## Train the Model

# %% [markdown]
# We train for 50 epochs with a batch_size value of 20 using early stopping:

# %%
lstm_path = (results_path / "lstm.keras").as_posix()

checkpointer = ModelCheckpoint(
    filepath=lstm_path, verbose=1, monitor="val_loss", mode="min", save_best_only=True
)

# %%
early_stopping = EarlyStopping(
    monitor="val_loss", patience=10, restore_best_weights=True
)

# %%
result = rnn.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=20,
    shuffle=False,
    validation_data=(X_test, y_test),
    callbacks=[early_stopping, checkpointer],
    verbose=1,
)
# Out:
# Epoch 1/100
# 14/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5620
# Epoch 1: val_loss improved from inf to 0.09370, saving model to results/multivariate_time_series/lstm.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.5044 - val_loss: 0.0937
# Epoch 2/100
# 15/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1703
# Epoch 2: val_loss improved from 0.09370 to 0.05185, saving model to results/multivariate_time_series/lstm.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1583 - val_loss: 0.0518
# Epoch 3/100
# 16/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1396
# Epoch 3: val_loss improved from 0.05185 to 0.05154, saving model to results/multivariate_time_series/lstm.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1345 - val_loss: 0.0515
# Epoch 4/100
# 15/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1297
# Epoch 4: val_loss improved from 0.05154 to 0.04725, saving model to results/multivariate_time_series/lstm.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1249 - val_loss: 0.0473
# Epoch 5/100
# 15/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1316
# Epoch 5: val_loss did not improve from 0.04725
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1261 - val_loss: 0.0473
# Epoch 6/100
# 16/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1223
# Epoch 6: val_loss did not improve from 0.04725
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1187 - val_loss: 0.0491
# Epoch 7/100
# 14/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1200
# Epoch 7: val_loss improved from 0.04725 to 0.04688, saving model to results/multivariate_time_series/lstm.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1153 - val_loss: 0.0469
# Epoch 8/100
# 13/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1263
# Epoch 8: val_loss did not improve from 0.04688
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1189 - val_loss: 0.0535
# Epoch 9/100
# 15/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1215
# Epoch 9: val_loss did not improve from 0.04688
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1171 - val_loss: 0.0547
# Epoch 10/100
# 15/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1190
# Epoch 10: val_loss did not improve from 0.04688
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1142 - val_loss: 0.0498
# Epoch 11/100
# 14/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1162
# Epoch 11: val_loss did not improve from 0.04688
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1124 - val_loss: 0.0476
# Epoch 12/100
# 14/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1133
# Epoch 12: val_loss did not improve from 0.04688
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1095 - val_loss: 0.0493
# Epoch 13/100
# 16/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1138
# Epoch 13: val_loss did not improve from 0.04688
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1104 - val_loss: 0.0491
# Epoch 14/100
# 13/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1080
# Epoch 14: val_loss did not improve from 0.04688
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1041 - val_loss: 0.0523
# Epoch 15/100
# 11/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1128
# Epoch 15: val_loss improved from 0.04688 to 0.04638, saving model to results/multivariate_time_series/lstm.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1052 - val_loss: 0.0464
# Epoch 16/100
# 16/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1090
# Epoch 16: val_loss did not improve from 0.04638
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1060 - val_loss: 0.0464
# Epoch 17/100
# 15/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1073
# Epoch 17: val_loss did not improve from 0.04638
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1045 - val_loss: 0.0490
# Epoch 18/100
# 15/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1039
# Epoch 18: val_loss did not improve from 0.04638
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1012 - val_loss: 0.0481
# Epoch 19/100
# 13/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1032
# Epoch 19: val_loss improved from 0.04638 to 0.04388, saving model to results/multivariate_time_series/lstm.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0996 - val_loss: 0.0439
# Epoch 20/100
# 15/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1093
# Epoch 20: val_loss did not improve from 0.04388
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1052 - val_loss: 0.0515
# Epoch 21/100
# 15/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1041
# Epoch 21: val_loss did not improve from 0.04388
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1016 - val_loss: 0.0470
# Epoch 22/100
# 12/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1034
# Epoch 22: val_loss did not improve from 0.04388
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0990 - val_loss: 0.0495
# Epoch 23/100
# 13/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1013
# Epoch 23: val_loss did not improve from 0.04388
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0977 - val_loss: 0.0493
# Epoch 24/100
# 13/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1050
# Epoch 24: val_loss improved from 0.04388 to 0.04259, saving model to results/multivariate_time_series/lstm.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0996 - val_loss: 0.0426
# Epoch 25/100
# 13/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1100
# Epoch 25: val_loss did not improve from 0.04259
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1034 - val_loss: 0.0445
# Epoch 26/100
# 14/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0996
# Epoch 26: val_loss did not improve from 0.04259
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0964 - val_loss: 0.0471
# Epoch 27/100
# 14/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1064
# Epoch 27: val_loss did not improve from 0.04259
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1029 - val_loss: 0.0485
# Epoch 28/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0967
# Epoch 28: val_loss did not improve from 0.04259
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0965 - val_loss: 0.0443
# Epoch 29/100
# 11/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1062
# Epoch 29: val_loss did not improve from 0.04259
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0978 - val_loss: 0.0442
# Epoch 30/100
# 15/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0967
# Epoch 30: val_loss did not improve from 0.04259
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0948 - val_loss: 0.0472
# Epoch 31/100
# 15/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0996
# Epoch 31: val_loss did not improve from 0.04259
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0977 - val_loss: 0.0463
# Epoch 32/100
# 13/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1074
# Epoch 32: val_loss did not improve from 0.04259
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1026 - val_loss: 0.0454
# Epoch 33/100
# 14/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0965
# Epoch 33: val_loss did not improve from 0.04259
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0945 - val_loss: 0.0479
# Epoch 34/100
# 14/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0930
# Epoch 34: val_loss improved from 0.04259 to 0.04203, saving model to results/multivariate_time_series/lstm.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0909 - val_loss: 0.0420
# Epoch 35/100
# 15/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0962
# Epoch 35: val_loss did not improve from 0.04203
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0936 - val_loss: 0.0424
# Epoch 36/100
# 13/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0950
# Epoch 36: val_loss did not improve from 0.04203
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0914 - val_loss: 0.0439
# Epoch 37/100
# 15/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0906
# Epoch 37: val_loss did not improve from 0.04203
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0897 - val_loss: 0.0449
# Epoch 38/100
# 12/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1000
# Epoch 38: val_loss did not improve from 0.04203
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0946 - val_loss: 0.0450
# Epoch 39/100
# 15/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0977
# Epoch 39: val_loss improved from 0.04203 to 0.04108, saving model to results/multivariate_time_series/lstm.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0957 - val_loss: 0.0411
# Epoch 40/100
# 13/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0971
# Epoch 40: val_loss did not improve from 0.04108
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0926 - val_loss: 0.0423
# Epoch 41/100
# 11/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0950
# Epoch 41: val_loss did not improve from 0.04108
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0890 - val_loss: 0.0454
# Epoch 42/100
# 13/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0928
# Epoch 42: val_loss did not improve from 0.04108
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0901 - val_loss: 0.0438
# Epoch 43/100
# 13/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0916
# Epoch 43: val_loss did not improve from 0.04108
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0890 - val_loss: 0.0456
# Epoch 44/100
# 14/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0899
# Epoch 44: val_loss did not improve from 0.04108
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0882 - val_loss: 0.0440
# Epoch 45/100
# 13/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0885
# Epoch 45: val_loss improved from 0.04108 to 0.04025, saving model to results/multivariate_time_series/lstm.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0865 - val_loss: 0.0402
# Epoch 46/100
# 14/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0871
# Epoch 46: val_loss did not improve from 0.04025
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0855 - val_loss: 0.0439
# Epoch 47/100
# 12/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0908
# Epoch 47: val_loss did not improve from 0.04025
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0876 - val_loss: 0.0428
# Epoch 48/100
# 15/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0856
# Epoch 48: val_loss did not improve from 0.04025
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0841 - val_loss: 0.0440
# Epoch 49/100
# 14/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0854
# Epoch 49: val_loss did not improve from 0.04025
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0853 - val_loss: 0.0440
# Epoch 50/100
# 13/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0905
# Epoch 50: val_loss did not improve from 0.04025
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0881 - val_loss: 0.0416
# Epoch 51/100
# 15/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0826
# Epoch 51: val_loss did not improve from 0.04025
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0827 - val_loss: 0.0404
# Epoch 52/100
# 13/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0870
# Epoch 52: val_loss did not improve from 0.04025
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0852 - val_loss: 0.0417
# Epoch 53/100
# 13/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0880
# Epoch 53: val_loss did not improve from 0.04025
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0856 - val_loss: 0.0427
# Epoch 54/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0822
# Epoch 54: val_loss improved from 0.04025 to 0.03928, saving model to results/multivariate_time_series/lstm.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0821 - val_loss: 0.0393
# Epoch 55/100
# 12/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0868
# Epoch 55: val_loss did not improve from 0.03928
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0836 - val_loss: 0.0403
# Epoch 56/100
# 14/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0801
# Epoch 56: val_loss did not improve from 0.03928
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0802 - val_loss: 0.0402
# Epoch 57/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0836
# Epoch 57: val_loss did not improve from 0.03928
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0835 - val_loss: 0.0434
# Epoch 58/100
# 13/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0869
# Epoch 58: val_loss improved from 0.03928 to 0.03866, saving model to results/multivariate_time_series/lstm.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0841 - val_loss: 0.0387
# Epoch 59/100
# 13/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0865
# Epoch 59: val_loss did not improve from 0.03866
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0845 - val_loss: 0.0389
# Epoch 60/100
# 13/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0800
# Epoch 60: val_loss improved from 0.03866 to 0.03865, saving model to results/multivariate_time_series/lstm.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0784 - val_loss: 0.0386
# Epoch 61/100
# 15/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0874
# Epoch 61: val_loss did not improve from 0.03865
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0859 - val_loss: 0.0396
# Epoch 62/100
# 13/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0768
# Epoch 62: val_loss did not improve from 0.03865
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0770 - val_loss: 0.0421
# Epoch 63/100
# 13/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0854
# Epoch 63: val_loss improved from 0.03865 to 0.03837, saving model to results/multivariate_time_series/lstm.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0836 - val_loss: 0.0384
# Epoch 64/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0841
# Epoch 64: val_loss improved from 0.03837 to 0.03801, saving model to results/multivariate_time_series/lstm.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0840 - val_loss: 0.0380
# Epoch 65/100
# 12/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0856
# Epoch 65: val_loss did not improve from 0.03801
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0825 - val_loss: 0.0385
# Epoch 66/100
# 15/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0844
# Epoch 66: val_loss improved from 0.03801 to 0.03678, saving model to results/multivariate_time_series/lstm.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0833 - val_loss: 0.0368
# Epoch 67/100
# 13/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0764
# Epoch 67: val_loss did not improve from 0.03678
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0769 - val_loss: 0.0374
# Epoch 68/100
# 12/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0747
# Epoch 68: val_loss did not improve from 0.03678
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0752 - val_loss: 0.0393
# Epoch 69/100
# 12/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0853
# Epoch 69: val_loss did not improve from 0.03678
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0818 - val_loss: 0.0384
# Epoch 70/100
# 13/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0769
# Epoch 70: val_loss improved from 0.03678 to 0.03656, saving model to results/multivariate_time_series/lstm.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0766 - val_loss: 0.0366
# Epoch 71/100
# 13/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0742
# Epoch 71: val_loss did not improve from 0.03656
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0755 - val_loss: 0.0380
# Epoch 72/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0751
# Epoch 72: val_loss improved from 0.03656 to 0.03602, saving model to results/multivariate_time_series/lstm.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0752 - val_loss: 0.0360
# Epoch 73/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0724
# Epoch 73: val_loss did not improve from 0.03602
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0727 - val_loss: 0.0399
# Epoch 74/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0774
# Epoch 74: val_loss did not improve from 0.03602
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0774 - val_loss: 0.0372
# Epoch 75/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0822
# Epoch 75: val_loss did not improve from 0.03602
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0818 - val_loss: 0.0368
# Epoch 76/100
# 13/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0811
# Epoch 76: val_loss did not improve from 0.03602
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0787 - val_loss: 0.0372
# Epoch 77/100
# 13/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0829
# Epoch 77: val_loss did not improve from 0.03602
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0806 - val_loss: 0.0376
# Epoch 78/100
# 13/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0830
# Epoch 78: val_loss did not improve from 0.03602
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0795 - val_loss: 0.0401
# Epoch 79/100
# 13/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0792
# Epoch 79: val_loss did not improve from 0.03602
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0785 - val_loss: 0.0410
# Epoch 80/100
# 14/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0779
# Epoch 80: val_loss did not improve from 0.03602
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0775 - val_loss: 0.0371
# Epoch 81/100
# 13/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0739
# Epoch 81: val_loss did not improve from 0.03602
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0731 - val_loss: 0.0394
# Epoch 82/100
# 13/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0779
# Epoch 82: val_loss did not improve from 0.03602
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0765 - val_loss: 0.0379

# %% [markdown]
# ## Evaluate the Results

# %% [markdown]
# Training stops early after 22 epochs, yielding a test MAE of 1.71, which compares favorably to the test MAE for the VAR model of 1.91.

# %% [markdown]
# However, the two results are not fully comparable because the RNN model produces 24 one-step-ahead forecasts, whereas the VAR model uses its own predictions as input for its out-of-sample forecast. You may want to tweak the VAR setup to obtain comparable forecasts and compare their performance:

# %%
pd.DataFrame(result.history).plot();

# %%
y_pred = pd.DataFrame(rnn.predict(X_test), columns=y_test.columns, index=y_test.index)
y_pred.info()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 24 entries, 2018-01-01 to 2019-12-01
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   sentiment  24 non-null     float32
#  1   ip         24 non-null     float32
# dtypes: float32(2)
# memory usage: 384.0 bytes

# %%
test_mae = mean_absolute_error(y_pred, y_test)

# %%
print(test_mae)
# Out:
# 0.0360240631589446

# %%
y_test.index
# Out:
# DatetimeIndex(['2018-01-01', '2018-02-01', '2018-03-01', '2018-04-01',
#                '2018-05-01', '2018-06-01', '2018-07-01', '2018-08-01',
#                '2018-09-01', '2018-10-01', '2018-11-01', '2018-12-01',
#                '2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01'],
#               dtype='datetime64[ns]', name='DATE', freq=None)

# %%
fig, axes = plt.subplots(ncols=3, figsize=(17, 4))
pd.DataFrame(result.history).rename(
    columns={"loss": "Training", "val_loss": "Validation"}
).plot(ax=axes[0], title="Train & Validation Error")
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("MAE")
col_dict = {"ip": "Industrial Production", "sentiment": "Sentiment"}

for i, col in enumerate(y_test.columns, 1):
    y_train.loc["2010":, col].plot(ax=axes[i], label="training", title=col_dict[col])
    y_test[col].plot(ax=axes[i], label="out-of-sample")
    y_pred[col].plot(ax=axes[i], label="prediction")
    axes[i].set_xlabel("")

axes[1].set_ylim(0.3, 0.9)
axes[1].fill_between(x=y_test.index, y1=0.3, y2=0.9, color="grey", alpha=0.5)

axes[2].set_ylim(0.5, 0.9)
axes[2].fill_between(x=y_test.index, y1=0.5, y2=0.9, color="grey", alpha=0.5)

plt.legend()
fig.suptitle(
    "Multivariate RNN - Results | Test MAE = {:.4f}".format(test_mae), fontsize=14
)
sns.despine()
fig.tight_layout()
fig.subplots_adjust(top=0.85)
fig.savefig(results_path / "multivariate_results", dpi=300);
