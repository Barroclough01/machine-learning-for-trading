# %% [markdown]
# # LSTM & Word Embeddings for Sentiment Classification

# %% [markdown]
# RNNs are commonly applied to various natural language processing tasks. We've already encountered sentiment analysis using text data in part three of this book.
#
# We are now going to illustrate how to apply an RNN model to text data to detect positive or negative sentiment (which can easily be extended to a finer-grained sentiment scale). We are going to use word embeddings to represent the tokens in the documents. We covered word embeddings in Chapter 15, Word Embeddings. They are an excellent technique to convert text into a continuous vector representation such that the relative location of words in the latent space encodes useful semantic aspects based on the words' usage in context.
#
# We saw in the previous RNN example that Keras has a built-in embedding layer that allows us to train vector representations specific to the task at hand. Alternatively, we can use pretrained vectors.

# %% [markdown]
# ## Imports & Settings

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
# %matplotlib inline

from pathlib import Path

import numpy as np
import pandas as pd
from sklearn.metrics import roc_auc_score

import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.datasets import imdb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GRU, Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences

import matplotlib.pyplot as plt
import seaborn as sns

# %%
gpu_devices = tf.config.experimental.list_physical_devices("GPU")
if gpu_devices:
    print("Using GPU")
    tf.config.experimental.set_memory_growth(gpu_devices[0], True)
else:
    print("Using CPU")
# Out:
# Using CPU

# %%
sns.set_style("whitegrid")
np.random.seed(42)

# %%
results_path = Path("results", "sentiment_imdb")
if not results_path.exists():
    results_path.mkdir(parents=True)

# %% [markdown]
# ## Load Reviews

# %% [markdown]
# To keep the data manageable, we will illustrate this use case with the IMDB reviews dataset, which contains 50,000 positive and negative movie reviews evenly split into a train and a test set, and with balanced labels in each dataset. The vocabulary consists of 88,586 tokens.
#
# The dataset is bundled into Keras and can be loaded so that each review is represented as an integer-encoded sequence. We can limit the vocabulary to num_words while filtering out frequent and likely less informative words using skip_top, as well as sentences longer than maxlen. We can also choose oov_char, which represents tokens we chose to exclude from the vocabulary on frequency grounds, as follows:

# %%
vocab_size = 20000

# %%
(X_train, y_train), (X_test, y_test) = imdb.load_data(
    seed=42, skip_top=0, maxlen=None, oov_char=2, index_from=3, num_words=vocab_size
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
ax = sns.displot([len(review) for review in X_train])
ax.set(xscale="log");

# %% [markdown]
# ## Prepare Data

# %% [markdown]
# In the second step, convert the lists of integers into fixed-size arrays that we can stack and provide as input to our RNN. The pad_sequence function produces arrays of equal length, truncated, and padded to conform to maxlen, as follows:

# %%
maxlen = 100

# %%
X_train_padded = pad_sequences(X_train, truncating="pre", padding="pre", maxlen=maxlen)

X_test_padded = pad_sequences(X_test, truncating="pre", padding="pre", maxlen=maxlen)

# %%
X_train_padded.shape, X_test_padded.shape
# Out:
# ((25000, 100), (25000, 100))

# %% [markdown]
# ## Define Model Architecture

# %% [markdown]
# Now we can define our RNN architecture. The first layer learns the word embeddings. We define the embedding dimension as previously using the input_dim keyword to set the number of tokens that we need to embed, the output_dim keyword, which defines the size of each embedding, and how long each input sequence is going to be.

# %% [markdown]
# ### Custom Loss Metric

# %%
embedding_size = 100

# %% [markdown]
# Note that we are using GRUs this time, which train faster and perform better on smaller data. We are also using dropout for regularization, as follows:

# %%
rnn = Sequential(
    [
        Embedding(input_dim=vocab_size, output_dim=embedding_size, input_length=maxlen),
        GRU(
            units=32,
            dropout=0.2,  # comment out to use optimized GPU implementation
            recurrent_dropout=0.2,
        ),
        Dense(1, activation="sigmoid")
    ]
)

# %% [markdown]
# The resulting model has over 2 million parameters.

# %% [markdown]
# We compile the model to use our custom AUC metric, which we introduced previously, and train with early stopping:

# %%
rnn.compile(
    loss="binary_crossentropy",
    optimizer="RMSProp",
    metrics=["accuracy", tf.keras.metrics.AUC(name="AUC")],
)

# %%
rnn_path = (results_path / "lstm.keras").as_posix()

checkpointer = ModelCheckpoint(
    filepath=rnn_path, verbose=1, monitor="val_AUC", mode="max", save_best_only=True
)

# %%
early_stopping = EarlyStopping(
    monitor="val_AUC", mode="max", patience=5, restore_best_weights=True
)

# %% [markdown]
# Training stops after eight epochs and we recover the weights for the best models to find a high test AUC of 0.9346:

# %%
training = rnn.fit(
    X_train_padded,
    y_train,
    batch_size=32,
    epochs=100,
    validation_data=(X_test_padded, y_test),
    callbacks=[early_stopping, checkpointer],
    verbose=1,
)
# Out:
# Epoch 1/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - AUC: 0.7242 - accuracy: 0.6551 - loss: 0.5959
# Epoch 1: val_AUC improved from -inf to 0.89491, saving model to results/sentiment_imdb/lstm.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 25s 30ms/step - AUC: 0.7243 - accuracy: 0.6552 - loss: 0.5958 - val_AUC: 0.8949 - val_accuracy: 0.8138 - val_loss: 0.4162
# Epoch 2/100
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - AUC: 0.9073 - accuracy: 0.8331 - loss: 0.3864
# Epoch 2: val_AUC improved from 0.89491 to 0.92713, saving model to results/sentiment_imdb/lstm.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 34ms/step - AUC: 0.9073 - accuracy: 0.8332 - loss: 0.3864 - val_AUC: 0.9271 - val_accuracy: 0.8416 - val_loss: 0.3653
# Epoch 3/100
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - AUC: 0.9427 - accuracy: 0.8750 - loss: 0.3055
# Epoch 3: val_AUC improved from 0.92713 to 0.93347, saving model to results/sentiment_imdb/lstm.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - AUC: 0.9427 - accuracy: 0.8750 - loss: 0.3055 - val_AUC: 0.9335 - val_accuracy: 0.8503 - val_loss: 0.3387
# Epoch 4/100
# 780/782 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - AUC: 0.9627 - accuracy: 0.9029 - loss: 0.2451
# Epoch 4: val_AUC improved from 0.93347 to 0.93922, saving model to results/sentiment_imdb/lstm.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 25s 31ms/step - AUC: 0.9627 - accuracy: 0.9029 - loss: 0.2451 - val_AUC: 0.9392 - val_accuracy: 0.8630 - val_loss: 0.3172
# Epoch 5/100
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - AUC: 0.9735 - accuracy: 0.9215 - loss: 0.2045
# Epoch 5: val_AUC improved from 0.93922 to 0.94038, saving model to results/sentiment_imdb/lstm.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 25s 32ms/step - AUC: 0.9735 - accuracy: 0.9215 - loss: 0.2045 - val_AUC: 0.9404 - val_accuracy: 0.8638 - val_loss: 0.3253
# Epoch 6/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - AUC: 0.9812 - accuracy: 0.9369 - loss: 0.1709
# Epoch 6: val_AUC did not improve from 0.94038
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 24s 31ms/step - AUC: 0.9812 - accuracy: 0.9369 - loss: 0.1709 - val_AUC: 0.9381 - val_accuracy: 0.8560 - val_loss: 0.3431
# Epoch 7/100
# 780/782 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - AUC: 0.9861 - accuracy: 0.9507 - loss: 0.1428
# Epoch 7: val_AUC did not improve from 0.94038
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 25s 32ms/step - AUC: 0.9861 - accuracy: 0.9507 - loss: 0.1428 - val_AUC: 0.9367 - val_accuracy: 0.8588 - val_loss: 0.3745
# Epoch 8/100
# 780/782 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - AUC: 0.9901 - accuracy: 0.9612 - loss: 0.1164
# Epoch 8: val_AUC did not improve from 0.94038
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 25s 32ms/step - AUC: 0.9901 - accuracy: 0.9612 - loss: 0.1164 - val_AUC: 0.9328 - val_accuracy: 0.8544 - val_loss: 0.3920
# Epoch 9/100
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - AUC: 0.9930 - accuracy: 0.9688 - loss: 0.0965
# Epoch 9: val_AUC did not improve from 0.94038
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 25s 32ms/step - AUC: 0.9930 - accuracy: 0.9688 - loss: 0.0965 - val_AUC: 0.9298 - val_accuracy: 0.8526 - val_loss: 0.4182
# Epoch 10/100
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - AUC: 0.9952 - accuracy: 0.9771 - loss: 0.0748
# Epoch 10: val_AUC did not improve from 0.94038
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - AUC: 0.9952 - accuracy: 0.9771 - loss: 0.0748 - val_AUC: 0.9246 - val_accuracy: 0.8474 - val_loss: 0.4693

# %% [markdown]
# ## Evaluate Results

# %%
history = pd.DataFrame(training.history)
history.index += 1

# %%
fig, axes = plt.subplots(ncols=2, figsize=(14, 4))
df1 = history[["accuracy", "val_accuracy"]].rename(
    columns={"accuracy": "Training", "val_accuracy": "Validation"}
)
df1.plot(ax=axes[0], title="Accuracy", xlim=(1, len(history)))

axes[0].axvline(df1.Validation.idxmax(), ls="--", lw=1, c="k")

df2 = history[["AUC", "val_AUC"]].rename(
    columns={"AUC": "Training", "val_AUC": "Validation"}
)
df2.plot(ax=axes[1], title="Area under the ROC Curve", xlim=(1, len(history)))

axes[1].axvline(df2.Validation.idxmax(), ls="--", lw=1, c="k")

for i in [0, 1]:
    axes[i].set_xlabel("Epoch")

sns.despine()
fig.tight_layout()
fig.savefig(results_path / "rnn_imdb_cv", dpi=300)

# %%
y_score = rnn.predict(X_test_padded)
y_score.shape
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step
# (25000, 1)

# %%
roc_auc_score(y_score=y_score.squeeze(), y_true=y_test)
# Out:
# 0.9405123071999999
