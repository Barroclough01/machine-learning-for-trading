# %% [markdown]
# # Text classification and sentiment analysis: Yelp Reviews

# %% [markdown]
# Once text data has been converted into numerical features using the natural language processing techniques discussed in the previous sections, text classification works just like any other classification task.
#
# In this notebook, we will apply these preprocessing technique to Yelp business reviews to classify them by review scores and sentiment polarity. More specifically, we will apply sentiment analysis to the significantly larger Yelp business review dataset with five outcome classes.

# %% [markdown]
# ## Imports

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline

from pathlib import Path
import json
from time import time

import numpy as np
import pandas as pd

from scipy import sparse

# spacy, textblob and nltk for language processing
from textblob import TextBlob

# sklearn for feature extraction & modeling
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix
import joblib

import lightgbm as lgb

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style('white')
np.random.seed(42)

# %% [markdown]
# ## Yelp Challenge: business reviews dataset

# %% [markdown]
# ### Load Data

# %% [markdown]
# Follow the [instructions](../data/create_yelp_review_data.ipynb) to create the dataset.

# %%
data_dir = Path('..', 'data', 'yelp')

# %%
yelp_reviews = pd.read_parquet(data_dir / 'user_reviews.parquet')

# %%
yelp_reviews.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6990280 entries, 0 to 6990279
# Data columns (total 25 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   stars               6990280 non-null  float64
#  1   useful              6990280 non-null  int64
#  2   funny               6990280 non-null  int64
#  3   cool                6990280 non-null  int64
#  4   text                6990280 non-null  object
#  5   year                6990280 non-null  int32
#  6   month               6990280 non-null  int32
#  7   review_count        6990247 non-null  float64
#  8   useful_user         6990247 non-null  float64
#  9   funny_user          6990247 non-null  float64
#  10  cool_user           6990247 non-null  float64
#  11  fans                6990247 non-null  float64
#  12  average_stars       6990247 non-null  float64
#  13  compliment_hot      6990247 non-null  float64
#  14  compliment_more     6990247 non-null  float64
#  15  compliment_profile  6990247 non-null  float64
#  16  compliment_cute     6990247 non-null  float64
#  17  compliment_list     6990247 non-null  float64
#  18  compliment_note     6990247 non-null  float64
#  19  compliment_plain    6990247 non-null  float64
#  20  compliment_cool     6990247 non-null  float64
#  21  compliment_funny    6990247 non-null  float64
#  22  compliment_writer   6990247 non-null  float64
#  23  compliment_photos   6990247 non-null  float64
#  24  member_yrs          6990247 non-null  float64
# dtypes: float64(19), int32(2), int64(3), object(1)
# memory usage: 1.2+ GB

# %% [markdown]
# ### Explore data

# %%
yelp_dir = Path('results', 'yelp')

text_features_dir = yelp_dir / 'data'
if not text_features_dir.exists():
    text_features_dir.mkdir(exist_ok=True, parents=True)

# %% [markdown]
# The following figure shows the number of reviews and the average number of stars per year.

# %% [markdown]
# #### Reviews & Stars by Year

# %%
fig, axes = plt.subplots(ncols=3, figsize=(18, 4))
yelp_reviews.year.value_counts().sort_index().plot.bar(title='Reviews per Year', ax=axes[0], rot=0);
sns.lineplot(x='year', y='stars', data=yelp_reviews, ax=axes[1])
axes[1].set_title('Stars per year')

stars_dist = yelp_reviews.stars.value_counts(normalize=True).sort_index().mul(100)
stars_dist.index = stars_dist.index.astype(int)
stars_dist.plot.barh(title='# Stars Breakdown', ax=axes[2])
axes[2].set_xlabel('Share of all Ratings (%)')
axes[2].set_ylabel('Number of Stars');

sns.despine()
fig.tight_layout();

# %% [markdown]
# #### Years of Membership Breakdown

# %%
ax = yelp_reviews.member_yrs.value_counts().div(1000).sort_index().plot.bar(title='Years of Membership',
                                                                            rot=0)
ax.set_xlabel('Number of Years')
ax.set_ylabel("Number of Members  ('000)")
sns.despine()
plt.tight_layout()

# %% [markdown]
# ### Create train-test split

# %%
train = yelp_reviews[yelp_reviews.year < 2020].sample(frac=1)
test = yelp_reviews[yelp_reviews.year >= 2020]

# %%
print(f'# Training Obs: {len(train):,.0f} | # Test Obs: {len(test):,.0f}')
# Out:
# # Training Obs: 5,785,869 | # Test Obs: 1,204,411

# %%
train.to_parquet(text_features_dir / 'train.parquet')
test.to_parquet(text_features_dir / 'test.parquet')

# %%
del yelp_reviews

# %% [markdown]
# #### Reload stored data

# %%
train = pd.read_parquet(text_features_dir / 'train.parquet')
test = pd.read_parquet(text_features_dir / 'test.parquet')

# %% [markdown]
# ## Create Yelp review document-term matrix

# %%
vectorizer = CountVectorizer(stop_words='english', ngram_range=(1, 2), max_features=10000)
train_dtm = vectorizer.fit_transform(train.text)
train_dtm
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 252250197 stored elements and shape (5785869, 10000)>

# %%
sparse.save_npz(text_features_dir / 'train_dtm', train_dtm)

# %%
test_dtm = vectorizer.transform(test.text)
sparse.save_npz(text_features_dir / 'test_dtm', test_dtm)

# %% [markdown]
# ### Reload stored data

# %%
train_dtm = sparse.load_npz(text_features_dir / 'train_dtm.npz')
test_dtm = sparse.load_npz(text_features_dir / 'test_dtm.npz')

# %% [markdown]
# ## Combine non-text features with the document-term matrix

# %% [markdown]
# The dataset contains various numerical features. The vectorizers produce [scipy.sparse matrices](https://docs.scipy.org/doc/scipy/reference/sparse.html). To combine the vectorized text data with other features, we need to first convert these to sparse matrices as well; many sklearn objects and other libraries like lightgbm can handle these very memory-efficient data structures. Converting the sparse matrix to a dense numpy array risks memory overflow.
#
# Most variables are categorical so we use one-hot encoding since we have a fairly large dataset to accommodate the increase in features.
#
# We convert the encoded numerical features and combine them with the document-term matrix:

# %% [markdown]
# ### One-hot-encoding

# %%
df = pd.concat([train.drop(['text', 'stars'], axis=1).assign(source='train'),
                test.drop(['text', 'stars'], axis=1).assign(source='test')])

# %%
uniques = df.nunique()
binned = pd.concat([(df.loc[:, uniques[uniques > 20].index]
                     .apply(pd.qcut, q=10, labels=False, duplicates='drop')),
                    df.loc[:, uniques[uniques <= 20].index]], axis=1)
binned.info(show_counts=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 5
#       1 uniques = df.nunique()
#       2 binned = pd.concat([(df.loc[:, uniques[uniques > 20].index]
#       3                      .apply(pd.qcut, q=10, labels=False, duplicates='drop')),
#       4                     df.loc[:, uniques[uniques <= 20].index]], axis=1)
# ----> 5 binned.info(null_counts=True)
#
# TypeError: DataFrame.info() got an unexpected keyword argument 'null_counts'

# %%
dummies = pd.get_dummies(binned, 
                         columns=binned.columns.drop('source'), 
                         drop_first=True)
dummies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6990280 entries, 4739505 to 6990278
# Columns: 123 entries, source to member_yrs_17.0
# dtypes: bool(122), object(1)
# memory usage: 920.0+ MB

# %%
train_dummies = dummies[dummies.source=='train'].drop('source', axis=1)
train_dummies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5785869 entries, 4739505 to 4948537
# Columns: 122 entries, useful_1 to member_yrs_17.0
# dtypes: bool(122)
# memory usage: 717.3 MB

# %% [markdown]
# ### Train set

# %%
# Cast other feature columns to float and convert to a sparse matrix.
train_numeric = sparse.csr_matrix(train_dummies.astype(np.uint8))
train_numeric.shape
# Out:
# (5785869, 122)

# %%
# Combine sparse matrices.
train_dtm_numeric = sparse.hstack((train_dtm, train_numeric))
train_dtm_numeric.shape
# Out:
# (5785869, 10122)

# %%
sparse.save_npz(text_features_dir / 'train_dtm_numeric', 
                train_dtm_numeric)

# %% [markdown]
# ### Repeat for test set

# %%
test_dummies = dummies[dummies.source=='test'].drop('source', axis=1)
test_numeric = sparse.csr_matrix(test_dummies.astype(np.int8))
test_dtm_numeric = sparse.hstack((test_dtm, test_numeric))
test_dtm_numeric.shape
# Out:
# (1204411, 10122)

# %%
sparse.save_npz(text_features_dir / 'test_dtm_numeric', test_dtm_numeric)

# %% [markdown]
# ### Reload stored data

# %%
train_dtm_numeric = sparse.load_npz(text_features_dir / 'train_dtm_numeric.npz')
test_dtm_numeric = sparse.load_npz(text_features_dir / 'test_dtm_numeric.npz')

# %% [markdown]
# ## Benchmark Accuracy

# %%
accuracy, runtime = {}, {}
predictions = test[['stars']].copy()

# %% [markdown]
# Using the most frequent number of stars (=5) to predict the test set achieve an accuracy close to 51%:

# %%
naive_prediction = np.full_like(predictions.stars,
                                fill_value=train.stars.mode().iloc[0])

# %%
naive_benchmark = accuracy_score(predictions.stars, naive_prediction)

# %%
naive_benchmark
# Out:
# 0.5353122812727549

# %% [markdown]
# ## Model Evaluation Helper

# %%
def evaluate_model(model, X_train, X_test, name, store=False):
    start = time()
    model.fit(X_train, train.stars)
    runtime[name] = time() - start
    predictions[name] = model.predict(X_test)
    accuracy[result] = accuracy_score(test.stars, predictions[result])
    if store:
        joblib.dump(model, f'results/{result}.joblib')

# %% [markdown]
# ## Multiclass Naive Bayes

# %%
nb = MultinomialNB()

# %% [markdown]
# ### Text Features

# %% [markdown]
# Next, we train a Naive Bayes classifier using a document-term matrix produced by the CountVectorizer with default settings.

# %%
result = 'nb_text'

# %%
evaluate_model(nb, train_dtm, test_dtm, result, store=False)

# %% [markdown]
# #### Accuracy

# %% [markdown]
# The prediction produces 64.4% accuracy on the test set, a 24.2% improvement over the benchmark:

# %%
accuracy[result]
# Out:
# 0.6622050114122172

# %% [markdown]
# #### Confusion Matrix

# %%
stars = index = list(range(1, 6))
pd.DataFrame(confusion_matrix(test.stars, 
                              predictions[result]),
             columns=stars,
             index=stars)
# Out:
#         1      2      3       4       5
# 1  186162  38916   7089    2448    3843
# 2   28796  28554  15891    3637    2575
# 3   12977  16731  31401   16291    5481
# 4    7958   5693  20362   84377   40493
# 5   34759   4455   7513  130936  467073

# %% [markdown]
# ### Text & Numeric Features

# %%
result = 'nb_combined'

# %%
evaluate_model(nb, train_dtm_numeric, test_dtm_numeric, result, store=False)

# %% [markdown]
# #### Accuracy

# %%
accuracy[result]
# Out:
# 0.6727985712518401

# %% [markdown]
# ## Multinomial Logistic Regression

# %% [markdown]
# Logistic regression also provides a multinomial training option that is faster and more accurate than the one-vs-all implementation. We use the lbfgs solver (see sklearn [documentation](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html) for details).

# %%
Cs = np.logspace(-5, 5, 11)

# %% [markdown]
# ### Text Features

# %%
log_reg_text_accuracy = {}
log_reg_text_runtime = []
for i, C in enumerate(Cs):
    start = time()
    model = LogisticRegression(C=C,
                               multi_class='multinomial',
                               solver='lbfgs')

    model.fit(train_dtm, train.stars)
    log_reg_text_runtime.append(time() - start)
    log_reg_text_accuracy[C] = accuracy_score(test.stars,
                                              model.predict(test_dtm))

    print(f'{C:12.5f}: {log_reg_text_runtime[i]:.2f}s | {log_reg_text_accuracy[C]:.2%}', flush=True)
# Out:
#      0.00001: 64.53s | 69.18%
#      0.00010: 110.78s | 74.38%
#      0.00100: 235.32s | 76.08%
#      0.01000: 215.12s | 76.38%
#      0.10000: 197.24s | 76.36%
#      1.00000: 199.03s | 76.34%
#     10.00000: 209.96s | 76.32%
#    100.00000: 233.04s | 76.40%
#   1000.00000: 229.37s | 76.34%
#  10000.00000: 236.14s | 76.36%
# 100000.00000: 233.65s | 76.34%

# %%
pd.Series(log_reg_text_accuracy).to_csv(yelp_dir / 'logreg_text.csv')

# %%
accuracy['lr_text'] = pd.Series(log_reg_text_accuracy).max()
runtime['lr_text'] = np.mean(log_reg_text_runtime)

# %% [markdown]
# ### Combined Features

# %%
Cs = np.logspace(-3, 4, 8)

# %%
log_reg_comb_accuracy = {}
log_reg_comb_runtime = []
for i, C in enumerate(Cs):
    start = time()
    model = LogisticRegression(C=C,
                               multi_class='multinomial',
                               solver='lbfgs')

    model.fit(train_dtm_numeric, train.stars)
    log_reg_comb_runtime.append(time() - start)
    log_reg_comb_accuracy[C] = accuracy_score(test.stars,
                                              model.predict(test_dtm_numeric))

    print(f'{C:12.5f}: {log_reg_comb_runtime[i]:.2f}s | {log_reg_comb_accuracy[C]:.2%}', flush=True)
# Out:
#      0.00100: 283.10s | 76.43%
#      0.01000: 280.85s | 76.50%
#      0.10000: 277.46s | 76.31%
#      1.00000: 275.58s | 76.33%
#     10.00000: 271.70s | 76.18%
#    100.00000: 273.96s | 76.27%
#   1000.00000: 268.66s | 76.29%
#  10000.00000: 243.31s | 76.30%

# %%
pd.Series(log_reg_comb_accuracy).to_csv(yelp_dir / 'logreg_combined.csv')

# %%
accuracy['lr_comb'] = pd.Series(log_reg_comb_accuracy).max()
runtime['lr_comb'] = np.mean(log_reg_comb_runtime)

# %% [markdown]
# ## Gradient Boosting

# %% [markdown]
# For illustration, we also train a lightgbm Gradient Boosting tree ensemble with default settings and multiclass objective.

# %%
lgb_train = lgb.Dataset(data=train_dtm_numeric.tocsr().astype(np.float32), 
                        label=train.stars.sub(1), 
                        categorical_feature=list(range(train_dtm_numeric.shape[1])))

# %%
lgb_test = lgb.Dataset(data=test_dtm_numeric.tocsr().astype(np.float32), 
                       label=test.stars.sub(1), 
                       reference=lgb_train)

# %%
param = {'objective': 'multiclass',
         'metrics': ['multi_error', 'multi_logloss'],
         'num_class': 5}

# %%
booster = lgb.train(params=param,
                    train_set=lgb_train,
                    num_boost_round=2000,
                    valid_sets=[lgb_train, lgb_test],
                    callbacks=[lgb.early_stopping(stopping_rounds=25), lgb.log_evaluation()])
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 58.535320 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 42400
# [LightGBM] [Info] Number of data points in the train set: 5785869, number of used features: 10122
# [LightGBM] [Info] Start training from score -1.940420
# [LightGBM] [Info] Start training from score -2.521595
# [LightGBM] [Info] Start training from score -2.251269
# [LightGBM] [Info] Start training from score -1.497653
# [LightGBM] [Info] Start training from score -0.804962
# [1]	training's multi_error: 0.552895	training's multi_logloss: 1.34734	valid_1's multi_error: 0.464688	valid_1's multi_logloss: 1.25412
# Training until validation scores don't improve for 25 rounds
# [2]	training's multi_error: 0.552895	training's multi_logloss: 1.29762	valid_1's multi_error: 0.464688	valid_1's multi_logloss: 1.19438
# [3]	training's multi_error: 0.543352	training's multi_logloss: 1.25557	valid_1's multi_error: 0.452041	valid_1's multi_logloss: 1.14245
# [4]	training's multi_error: 0.507792	training's multi_logloss: 1.22178	valid_1's multi_error: 0.400146	valid_1's multi_logloss: 1.10149
# [5]	training's multi_error: 0.487044	training's multi_logloss: 1.19394	valid_1's multi_error: 0.376768	valid_1's multi_logloss: 1.06836
# [6]	training's multi_error: 0.462821	training's multi_logloss: 1.16956	valid_1's multi_error: 0.340261	valid_1's multi_logloss: 1.03962
# [7]	training's multi_error: 0.452861	training's multi_logloss: 1.14748	valid_1's multi_error: 0.330556	valid_1's multi_logloss: 1.01326
# [8]	training's multi_error: 0.442541	training's multi_logloss: 1.12844	valid_1's multi_error: 0.32066	valid_1's multi_logloss: 0.99246
# [9]	training's multi_error: 0.435796	training's multi_logloss: 1.11233	valid_1's multi_error: 0.316421	valid_1's multi_logloss: 0.973697
# [10]	training's multi_error: 0.429596	training's multi_logloss: 1.09634	valid_1's multi_error: 0.31253	valid_1's multi_logloss: 0.954647
# [11]	training's multi_error: 0.424164	training's multi_logloss: 1.0831	valid_1's multi_error: 0.309616	valid_1's multi_logloss: 0.94075
# [12]	training's multi_error: 0.419076	training's multi_logloss: 1.06957	valid_1's multi_error: 0.306866	valid_1's multi_logloss: 0.927666
# [13]	training's multi_error: 0.41459	training's multi_logloss: 1.05784	valid_1's multi_error: 0.304205	valid_1's multi_logloss: 0.914875
# [14]	training's multi_error: 0.410784	training's multi_logloss: 1.04727	valid_1's multi_error: 0.302377	valid_1's multi_logloss: 0.905064
# [15]	training's multi_error: 0.407181	training's multi_logloss: 1.03617	valid_1's multi_error: 0.299906	valid_1's multi_logloss: 0.892129
# [16]	training's multi_error: 0.404339	training's multi_logloss: 1.02699	valid_1's multi_error: 0.29862	valid_1's multi_logloss: 0.883412
# [17]	training's multi_error: 0.400958	training's multi_logloss: 1.01752	valid_1's multi_error: 0.29688	valid_1's multi_logloss: 0.874719
# [18]	training's multi_error: 0.397964	training's multi_logloss: 1.00893	valid_1's multi_error: 0.295225	valid_1's multi_logloss: 0.866706
# [19]	training's multi_error: 0.395156	training's multi_logloss: 1.0006	valid_1's multi_error: 0.293927	valid_1's multi_logloss: 0.858859
# [20]	training's multi_error: 0.392226	training's multi_logloss: 0.992733	valid_1's multi_error: 0.292599	valid_1's multi_logloss: 0.852677
# [21]	training's multi_error: 0.389871	training's multi_logloss: 0.986031	valid_1's multi_error: 0.291815	valid_1's multi_logloss: 0.846879
# [22]	training's multi_error: 0.387656	training's multi_logloss: 0.978797	valid_1's multi_error: 0.290134	valid_1's multi_logloss: 0.83902
# [23]	training's multi_error: 0.38537	training's multi_logloss: 0.972346	valid_1's multi_error: 0.289068	valid_1's multi_logloss: 0.833339
# [24]	training's multi_error: 0.383128	training's multi_logloss: 0.965931	valid_1's multi_error: 0.28822	valid_1's multi_logloss: 0.828268
# [25]	training's multi_error: 0.381015	training's multi_logloss: 0.959519	valid_1's multi_error: 0.286974	valid_1's multi_logloss: 0.821365
# [26]	training's multi_error: 0.378994	training's multi_logloss: 0.953534	valid_1's multi_error: 0.285758	valid_1's multi_logloss: 0.815708
# [27]	training's multi_error: 0.377343	training's multi_logloss: 0.948323	valid_1's multi_error: 0.285523	valid_1's multi_logloss: 0.811816
# [28]	training's multi_error: 0.375747	training's multi_logloss: 0.943091	valid_1's multi_error: 0.284541	valid_1's multi_logloss: 0.806269
# [29]	training's multi_error: 0.373991	training's multi_logloss: 0.937862	valid_1's multi_error: 0.283343	valid_1's multi_logloss: 0.801116
# [30]	training's multi_error: 0.3724	training's multi_logloss: 0.93308	valid_1's multi_error: 0.282153	valid_1's multi_logloss: 0.795836
# [31]	training's multi_error: 0.370859	training's multi_logloss: 0.928419	valid_1's multi_error: 0.281302	valid_1's multi_logloss: 0.791398
# [32]	training's multi_error: 0.369334	training's multi_logloss: 0.923669	valid_1's multi_error: 0.280389	valid_1's multi_logloss: 0.787165
# [33]	training's multi_error: 0.367977	training's multi_logloss: 0.919358	valid_1's multi_error: 0.279994	valid_1's multi_logloss: 0.783505
# [34]	training's multi_error: 0.366779	training's multi_logloss: 0.915783	valid_1's multi_error: 0.279126	valid_1's multi_logloss: 0.780155
# [35]	training's multi_error: 0.365534	training's multi_logloss: 0.911711	valid_1's multi_error: 0.278373	valid_1's multi_logloss: 0.776167
# [36]	training's multi_error: 0.36446	training's multi_logloss: 0.908155	valid_1's multi_error: 0.277782	valid_1's multi_logloss: 0.772409
# [37]	training's multi_error: 0.363241	training's multi_logloss: 0.904455	valid_1's multi_error: 0.276947	valid_1's multi_logloss: 0.769195
# [38]	training's multi_error: 0.362238	training's multi_logloss: 0.90102	valid_1's multi_error: 0.276408	valid_1's multi_logloss: 0.765844
# [39]	training's multi_error: 0.361146	training's multi_logloss: 0.89763	valid_1's multi_error: 0.275609	valid_1's multi_logloss: 0.762464
# [40]	training's multi_error: 0.360156	training's multi_logloss: 0.894402	valid_1's multi_error: 0.275042	valid_1's multi_logloss: 0.759377
# [41]	training's multi_error: 0.359109	training's multi_logloss: 0.891173	valid_1's multi_error: 0.274779	valid_1's multi_logloss: 0.757079
# [42]	training's multi_error: 0.358261	training's multi_logloss: 0.88817	valid_1's multi_error: 0.274089	valid_1's multi_logloss: 0.753919
# [43]	training's multi_error: 0.357189	training's multi_logloss: 0.885191	valid_1's multi_error: 0.273643	valid_1's multi_logloss: 0.751679
# [44]	training's multi_error: 0.35643	training's multi_logloss: 0.882468	valid_1's multi_error: 0.273626	valid_1's multi_logloss: 0.74979
# [45]	training's multi_error: 0.355552	training's multi_logloss: 0.879699	valid_1's multi_error: 0.272959	valid_1's multi_logloss: 0.747085
# [46]	training's multi_error: 0.354741	training's multi_logloss: 0.877176	valid_1's multi_error: 0.272554	valid_1's multi_logloss: 0.744814
# [47]	training's multi_error: 0.35389	training's multi_logloss: 0.874552	valid_1's multi_error: 0.271852	valid_1's multi_logloss: 0.742285
# [48]	training's multi_error: 0.353101	training's multi_logloss: 0.872055	valid_1's multi_error: 0.271267	valid_1's multi_logloss: 0.73966
# [49]	training's multi_error: 0.352399	training's multi_logloss: 0.869675	valid_1's multi_error: 0.270954	valid_1's multi_logloss: 0.737554
# [50]	training's multi_error: 0.351661	training's multi_logloss: 0.867231	valid_1's multi_error: 0.270332	valid_1's multi_logloss: 0.73498
# [51]	training's multi_error: 0.350943	training's multi_logloss: 0.865002	valid_1's multi_error: 0.269691	valid_1's multi_logloss: 0.732766
# [52]	training's multi_error: 0.350222	training's multi_logloss: 0.862922	valid_1's multi_error: 0.269688	valid_1's multi_logloss: 0.731629
# [53]	training's multi_error: 0.349641	training's multi_logloss: 0.860902	valid_1's multi_error: 0.269243	valid_1's multi_logloss: 0.729594
# [54]	training's multi_error: 0.348913	training's multi_logloss: 0.858786	valid_1's multi_error: 0.269008	valid_1's multi_logloss: 0.728086
# [55]	training's multi_error: 0.348263	training's multi_logloss: 0.856652	valid_1's multi_error: 0.268452	valid_1's multi_logloss: 0.726154
# [56]	training's multi_error: 0.347636	training's multi_logloss: 0.854633	valid_1's multi_error: 0.26808	valid_1's multi_logloss: 0.724345
# [57]	training's multi_error: 0.347045	training's multi_logloss: 0.852715	valid_1's multi_error: 0.267605	valid_1's multi_logloss: 0.722486
# [58]	training's multi_error: 0.346507	training's multi_logloss: 0.850977	valid_1's multi_error: 0.267185	valid_1's multi_logloss: 0.720563
# [59]	training's multi_error: 0.345958	training's multi_logloss: 0.849197	valid_1's multi_error: 0.26679	valid_1's multi_logloss: 0.718808
# [60]	training's multi_error: 0.345361	training's multi_logloss: 0.847235	valid_1's multi_error: 0.26637	valid_1's multi_logloss: 0.717047
# [61]	training's multi_error: 0.344852	training's multi_logloss: 0.84551	valid_1's multi_error: 0.265958	valid_1's multi_logloss: 0.71547
# [62]	training's multi_error: 0.344307	training's multi_logloss: 0.843888	valid_1's multi_error: 0.265825	valid_1's multi_logloss: 0.714448
# [63]	training's multi_error: 0.343709	training's multi_logloss: 0.842132	valid_1's multi_error: 0.265556	valid_1's multi_logloss: 0.713048
# [64]	training's multi_error: 0.34317	training's multi_logloss: 0.840455	valid_1's multi_error: 0.265198	valid_1's multi_logloss: 0.711565
# [65]	training's multi_error: 0.342674	training's multi_logloss: 0.838761	valid_1's multi_error: 0.264774	valid_1's multi_logloss: 0.709902
# [66]	training's multi_error: 0.342195	training's multi_logloss: 0.837323	valid_1's multi_error: 0.264583	valid_1's multi_logloss: 0.708513
# [67]	training's multi_error: 0.341706	training's multi_logloss: 0.835773	valid_1's multi_error: 0.264128	valid_1's multi_logloss: 0.706964
# [68]	training's multi_error: 0.341225	training's multi_logloss: 0.834334	valid_1's multi_error: 0.263819	valid_1's multi_logloss: 0.70566
# [69]	training's multi_error: 0.340688	training's multi_logloss: 0.83284	valid_1's multi_error: 0.263923	valid_1's multi_logloss: 0.70504
# [70]	training's multi_error: 0.340208	training's multi_logloss: 0.831377	valid_1's multi_error: 0.263667	valid_1's multi_logloss: 0.7038
# [71]	training's multi_error: 0.339771	training's multi_logloss: 0.82995	valid_1's multi_error: 0.263344	valid_1's multi_logloss: 0.702483
# [72]	training's multi_error: 0.339343	training's multi_logloss: 0.828636	valid_1's multi_error: 0.262949	valid_1's multi_logloss: 0.70122
# [73]	training's multi_error: 0.338914	training's multi_logloss: 0.82729	valid_1's multi_error: 0.262618	valid_1's multi_logloss: 0.699811
# [74]	training's multi_error: 0.338531	training's multi_logloss: 0.826022	valid_1's multi_error: 0.262366	valid_1's multi_logloss: 0.698528
# [75]	training's multi_error: 0.338094	training's multi_logloss: 0.824713	valid_1's multi_error: 0.261983	valid_1's multi_logloss: 0.697366
# [76]	training's multi_error: 0.337659	training's multi_logloss: 0.823462	valid_1's multi_error: 0.261961	valid_1's multi_logloss: 0.696653
# [77]	training's multi_error: 0.337237	training's multi_logloss: 0.822169	valid_1's multi_error: 0.261639	valid_1's multi_logloss: 0.695464
# [78]	training's multi_error: 0.336816	training's multi_logloss: 0.820906	valid_1's multi_error: 0.26138	valid_1's multi_logloss: 0.694418
# [79]	training's multi_error: 0.336468	training's multi_logloss: 0.819742	valid_1's multi_error: 0.26104	valid_1's multi_logloss: 0.693162
# [80]	training's multi_error: 0.336114	training's multi_logloss: 0.818626	valid_1's multi_error: 0.26084	valid_1's multi_logloss: 0.692064
# [81]	training's multi_error: 0.335694	training's multi_logloss: 0.817447	valid_1's multi_error: 0.260593	valid_1's multi_logloss: 0.690981
# [82]	training's multi_error: 0.335346	training's multi_logloss: 0.816243	valid_1's multi_error: 0.26027	valid_1's multi_logloss: 0.689838
# [83]	training's multi_error: 0.334977	training's multi_logloss: 0.815152	valid_1's multi_error: 0.260065	valid_1's multi_logloss: 0.688876
# [84]	training's multi_error: 0.334627	training's multi_logloss: 0.814059	valid_1's multi_error: 0.259832	valid_1's multi_logloss: 0.687943
# [85]	training's multi_error: 0.334212	training's multi_logloss: 0.812927	valid_1's multi_error: 0.25956	valid_1's multi_logloss: 0.687006
# [86]	training's multi_error: 0.333881	training's multi_logloss: 0.811883	valid_1's multi_error: 0.259357	valid_1's multi_logloss: 0.68614
# [87]	training's multi_error: 0.333536	training's multi_logloss: 0.81081	valid_1's multi_error: 0.259113	valid_1's multi_logloss: 0.68515
# [88]	training's multi_error: 0.333166	training's multi_logloss: 0.809767	valid_1's multi_error: 0.25955	valid_1's multi_logloss: 0.685163
# [89]	training's multi_error: 0.332824	training's multi_logloss: 0.808733	valid_1's multi_error: 0.259288	valid_1's multi_logloss: 0.684238
# [90]	training's multi_error: 0.332501	training's multi_logloss: 0.80776	valid_1's multi_error: 0.25902	valid_1's multi_logloss: 0.683329
# [91]	training's multi_error: 0.332217	training's multi_logloss: 0.806723	valid_1's multi_error: 0.258809	valid_1's multi_logloss: 0.6823
# [92]	training's multi_error: 0.331888	training's multi_logloss: 0.805774	valid_1's multi_error: 0.258654	valid_1's multi_logloss: 0.681582
# [93]	training's multi_error: 0.331599	training's multi_logloss: 0.804866	valid_1's multi_error: 0.258423	valid_1's multi_logloss: 0.680707
# [94]	training's multi_error: 0.331278	training's multi_logloss: 0.803945	valid_1's multi_error: 0.258173	valid_1's multi_logloss: 0.68001
# [95]	training's multi_error: 0.330984	training's multi_logloss: 0.803006	valid_1's multi_error: 0.258036	valid_1's multi_logloss: 0.679165
# [96]	training's multi_error: 0.33068	training's multi_logloss: 0.802096	valid_1's multi_error: 0.257883	valid_1's multi_logloss: 0.678339
# [97]	training's multi_error: 0.330297	training's multi_logloss: 0.801148	valid_1's multi_error: 0.25759	valid_1's multi_logloss: 0.677559
# [98]	training's multi_error: 0.330039	training's multi_logloss: 0.800295	valid_1's multi_error: 0.257175	valid_1's multi_logloss: 0.676611
# [99]	training's multi_error: 0.329768	training's multi_logloss: 0.79946	valid_1's multi_error: 0.256928	valid_1's multi_logloss: 0.675725
# [100]	training's multi_error: 0.329493	training's multi_logloss: 0.798592	valid_1's multi_error: 0.256692	valid_1's multi_logloss: 0.674841
# [101]	training's multi_error: 0.329192	training's multi_logloss: 0.797792	valid_1's multi_error: 0.256432	valid_1's multi_logloss: 0.674159
# [102]	training's multi_error: 0.32891	training's multi_logloss: 0.796945	valid_1's multi_error: 0.256257	valid_1's multi_logloss: 0.673403
# [103]	training's multi_error: 0.328652	training's multi_logloss: 0.796164	valid_1's multi_error: 0.256578	valid_1's multi_logloss: 0.673524
# [104]	training's multi_error: 0.32841	training's multi_logloss: 0.795359	valid_1's multi_error: 0.256444	valid_1's multi_logloss: 0.672923
# [105]	training's multi_error: 0.328134	training's multi_logloss: 0.79458	valid_1's multi_error: 0.256294	valid_1's multi_logloss: 0.67237
# [106]	training's multi_error: 0.327905	training's multi_logloss: 0.793795	valid_1's multi_error: 0.256055	valid_1's multi_logloss: 0.671639
# [107]	training's multi_error: 0.327645	training's multi_logloss: 0.79307	valid_1's multi_error: 0.255893	valid_1's multi_logloss: 0.670905
# [108]	training's multi_error: 0.327404	training's multi_logloss: 0.792321	valid_1's multi_error: 0.255698	valid_1's multi_logloss: 0.670316
# [109]	training's multi_error: 0.327095	training's multi_logloss: 0.791477	valid_1's multi_error: 0.255512	valid_1's multi_logloss: 0.669647
# [110]	training's multi_error: 0.326874	training's multi_logloss: 0.790757	valid_1's multi_error: 0.255227	valid_1's multi_logloss: 0.66894
# [111]	training's multi_error: 0.326609	training's multi_logloss: 0.789943	valid_1's multi_error: 0.25495	valid_1's multi_logloss: 0.668178
# [112]	training's multi_error: 0.326335	training's multi_logloss: 0.789203	valid_1's multi_error: 0.254695	valid_1's multi_logloss: 0.667482
# [113]	training's multi_error: 0.326147	training's multi_logloss: 0.788525	valid_1's multi_error: 0.254557	valid_1's multi_logloss: 0.666815
# [114]	training's multi_error: 0.325917	training's multi_logloss: 0.787851	valid_1's multi_error: 0.254392	valid_1's multi_logloss: 0.666206
# [115]	training's multi_error: 0.325749	training's multi_logloss: 0.787221	valid_1's multi_error: 0.254342	valid_1's multi_logloss: 0.665884
# [116]	training's multi_error: 0.325533	training's multi_logloss: 0.786569	valid_1's multi_error: 0.254231	valid_1's multi_logloss: 0.66528
# [117]	training's multi_error: 0.32528	training's multi_logloss: 0.78585	valid_1's multi_error: 0.254055	valid_1's multi_logloss: 0.664684
# [118]	training's multi_error: 0.325042	training's multi_logloss: 0.785159	valid_1's multi_error: 0.253862	valid_1's multi_logloss: 0.663985
# [119]	training's multi_error: 0.324784	training's multi_logloss: 0.784444	valid_1's multi_error: 0.253727	valid_1's multi_logloss: 0.663496
# [120]	training's multi_error: 0.324559	training's multi_logloss: 0.783818	valid_1's multi_error: 0.253594	valid_1's multi_logloss: 0.663022
# [121]	training's multi_error: 0.324317	training's multi_logloss: 0.783153	valid_1's multi_error: 0.253345	valid_1's multi_logloss: 0.662387
# [122]	training's multi_error: 0.324097	training's multi_logloss: 0.782555	valid_1's multi_error: 0.253218	valid_1's multi_logloss: 0.661822
# [123]	training's multi_error: 0.323925	training's multi_logloss: 0.781921	valid_1's multi_error: 0.253091	valid_1's multi_logloss: 0.661281
# [124]	training's multi_error: 0.323747	training's multi_logloss: 0.781299	valid_1's multi_error: 0.253296	valid_1's multi_logloss: 0.661231
# [125]	training's multi_error: 0.32354	training's multi_logloss: 0.780719	valid_1's multi_error: 0.253226	valid_1's multi_logloss: 0.660792
# [126]	training's multi_error: 0.323339	training's multi_logloss: 0.780107	valid_1's multi_error: 0.253094	valid_1's multi_logloss: 0.660222
# [127]	training's multi_error: 0.32316	training's multi_logloss: 0.779513	valid_1's multi_error: 0.252833	valid_1's multi_logloss: 0.659589
# [128]	training's multi_error: 0.32294	training's multi_logloss: 0.778918	valid_1's multi_error: 0.252743	valid_1's multi_logloss: 0.659036
# [129]	training's multi_error: 0.322757	training's multi_logloss: 0.778334	valid_1's multi_error: 0.252595	valid_1's multi_logloss: 0.658545
# [130]	training's multi_error: 0.322584	training's multi_logloss: 0.777739	valid_1's multi_error: 0.252472	valid_1's multi_logloss: 0.658019
# [131]	training's multi_error: 0.32243	training's multi_logloss: 0.777187	valid_1's multi_error: 0.252278	valid_1's multi_logloss: 0.657381
# [132]	training's multi_error: 0.322236	training's multi_logloss: 0.776613	valid_1's multi_error: 0.25214	valid_1's multi_logloss: 0.656916
# [133]	training's multi_error: 0.322042	training's multi_logloss: 0.776067	valid_1's multi_error: 0.25197	valid_1's multi_logloss: 0.656407
# [134]	training's multi_error: 0.321832	training's multi_logloss: 0.775539	valid_1's multi_error: 0.251898	valid_1's multi_logloss: 0.656137
# [135]	training's multi_error: 0.321641	training's multi_logloss: 0.774973	valid_1's multi_error: 0.251795	valid_1's multi_logloss: 0.655666
# [136]	training's multi_error: 0.321475	training's multi_logloss: 0.774434	valid_1's multi_error: 0.251701	valid_1's multi_logloss: 0.655213
# [137]	training's multi_error: 0.32118	training's multi_logloss: 0.773672	valid_1's multi_error: 0.25143	valid_1's multi_logloss: 0.654484
# [138]	training's multi_error: 0.320997	training's multi_logloss: 0.773183	valid_1's multi_error: 0.251329	valid_1's multi_logloss: 0.654094
# [139]	training's multi_error: 0.320831	training's multi_logloss: 0.772678	valid_1's multi_error: 0.251146	valid_1's multi_logloss: 0.653602
# [140]	training's multi_error: 0.320659	training's multi_logloss: 0.772197	valid_1's multi_error: 0.251044	valid_1's multi_logloss: 0.653249
# [141]	training's multi_error: 0.320479	training's multi_logloss: 0.771711	valid_1's multi_error: 0.250914	valid_1's multi_logloss: 0.652839
# [142]	training's multi_error: 0.320359	training's multi_logloss: 0.771236	valid_1's multi_error: 0.250845	valid_1's multi_logloss: 0.652429
# [143]	training's multi_error: 0.320182	training's multi_logloss: 0.770722	valid_1's multi_error: 0.250737	valid_1's multi_logloss: 0.652012
# [144]	training's multi_error: 0.319966	training's multi_logloss: 0.770228	valid_1's multi_error: 0.250659	valid_1's multi_logloss: 0.651611
# [145]	training's multi_error: 0.319807	training's multi_logloss: 0.769743	valid_1's multi_error: 0.25059	valid_1's multi_logloss: 0.651241
# [146]	training's multi_error: 0.319653	training's multi_logloss: 0.769282	valid_1's multi_error: 0.250608	valid_1's multi_logloss: 0.651025
# [147]	training's multi_error: 0.319519	training's multi_logloss: 0.768819	valid_1's multi_error: 0.250444	valid_1's multi_logloss: 0.650593
# [148]	training's multi_error: 0.319358	training's multi_logloss: 0.768335	valid_1's multi_error: 0.250408	valid_1's multi_logloss: 0.650314
# [149]	training's multi_error: 0.319182	training's multi_logloss: 0.767863	valid_1's multi_error: 0.250271	valid_1's multi_logloss: 0.649807
# [150]	training's multi_error: 0.319024	training's multi_logloss: 0.767409	valid_1's multi_error: 0.25016	valid_1's multi_logloss: 0.649348
# [151]	training's multi_error: 0.318846	training's multi_logloss: 0.766953	valid_1's multi_error: 0.250108	valid_1's multi_logloss: 0.649069
# [152]	training's multi_error: 0.318601	training's multi_logloss: 0.766329	valid_1's multi_error: 0.249921	valid_1's multi_logloss: 0.648676
# [153]	training's multi_error: 0.318451	training's multi_logloss: 0.765873	valid_1's multi_error: 0.249788	valid_1's multi_logloss: 0.648285
# [154]	training's multi_error: 0.318293	training's multi_logloss: 0.765437	valid_1's multi_error: 0.249728	valid_1's multi_logloss: 0.647922
# [155]	training's multi_error: 0.318099	training's multi_logloss: 0.764926	valid_1's multi_error: 0.249601	valid_1's multi_logloss: 0.647571
# [156]	training's multi_error: 0.317936	training's multi_logloss: 0.764489	valid_1's multi_error: 0.249413	valid_1's multi_logloss: 0.6472
# [157]	training's multi_error: 0.317809	training's multi_logloss: 0.76406	valid_1's multi_error: 0.249289	valid_1's multi_logloss: 0.646833
# [158]	training's multi_error: 0.317689	training's multi_logloss: 0.763642	valid_1's multi_error: 0.249142	valid_1's multi_logloss: 0.646386
# [159]	training's multi_error: 0.317518	training's multi_logloss: 0.763235	valid_1's multi_error: 0.248977	valid_1's multi_logloss: 0.646003
# [160]	training's multi_error: 0.317383	training's multi_logloss: 0.762823	valid_1's multi_error: 0.248903	valid_1's multi_logloss: 0.645722
# [161]	training's multi_error: 0.317239	training's multi_logloss: 0.762406	valid_1's multi_error: 0.248818	valid_1's multi_logloss: 0.645433
# [162]	training's multi_error: 0.317119	training's multi_logloss: 0.762001	valid_1's multi_error: 0.248699	valid_1's multi_logloss: 0.645064
# [163]	training's multi_error: 0.316926	training's multi_logloss: 0.761545	valid_1's multi_error: 0.248606	valid_1's multi_logloss: 0.644757
# [164]	training's multi_error: 0.316771	training's multi_logloss: 0.761144	valid_1's multi_error: 0.248526	valid_1's multi_logloss: 0.644409
# [165]	training's multi_error: 0.316628	training's multi_logloss: 0.760752	valid_1's multi_error: 0.248554	valid_1's multi_logloss: 0.644265
# [166]	training's multi_error: 0.316458	training's multi_logloss: 0.760356	valid_1's multi_error: 0.248424	valid_1's multi_logloss: 0.643982
# [167]	training's multi_error: 0.316338	training's multi_logloss: 0.759907	valid_1's multi_error: 0.248394	valid_1's multi_logloss: 0.64349
# [168]	training's multi_error: 0.316221	training's multi_logloss: 0.759518	valid_1's multi_error: 0.248243	valid_1's multi_logloss: 0.643196
# [169]	training's multi_error: 0.316071	training's multi_logloss: 0.75913	valid_1's multi_error: 0.248032	valid_1's multi_logloss: 0.642782
# [170]	training's multi_error: 0.315939	training's multi_logloss: 0.758743	valid_1's multi_error: 0.24803	valid_1's multi_logloss: 0.642475
# [171]	training's multi_error: 0.315831	training's multi_logloss: 0.758366	valid_1's multi_error: 0.247884	valid_1's multi_logloss: 0.642116
# [172]	training's multi_error: 0.315671	training's multi_logloss: 0.757946	valid_1's multi_error: 0.247685	valid_1's multi_logloss: 0.641766
# [173]	training's multi_error: 0.315555	training's multi_logloss: 0.757587	valid_1's multi_error: 0.247626	valid_1's multi_logloss: 0.641423
# [174]	training's multi_error: 0.315414	training's multi_logloss: 0.757216	valid_1's multi_error: 0.247575	valid_1's multi_logloss: 0.64112
# [175]	training's multi_error: 0.315304	training's multi_logloss: 0.75685	valid_1's multi_error: 0.247488	valid_1's multi_logloss: 0.640823
# [176]	training's multi_error: 0.315175	training's multi_logloss: 0.756488	valid_1's multi_error: 0.24757	valid_1's multi_logloss: 0.640732
# [177]	training's multi_error: 0.315035	training's multi_logloss: 0.756154	valid_1's multi_error: 0.247474	valid_1's multi_logloss: 0.640462
# [178]	training's multi_error: 0.314933	training's multi_logloss: 0.755799	valid_1's multi_error: 0.24745	valid_1's multi_logloss: 0.640297
# [179]	training's multi_error: 0.314814	training's multi_logloss: 0.75545	valid_1's multi_error: 0.247357	valid_1's multi_logloss: 0.640001
# [180]	training's multi_error: 0.314711	training's multi_logloss: 0.755105	valid_1's multi_error: 0.247282	valid_1's multi_logloss: 0.639714
# [181]	training's multi_error: 0.31459	training's multi_logloss: 0.754768	valid_1's multi_error: 0.247224	valid_1's multi_logloss: 0.639434
# [182]	training's multi_error: 0.314497	training's multi_logloss: 0.754411	valid_1's multi_error: 0.247137	valid_1's multi_logloss: 0.639119
# [183]	training's multi_error: 0.314361	training's multi_logloss: 0.754068	valid_1's multi_error: 0.247079	valid_1's multi_logloss: 0.638883
# [184]	training's multi_error: 0.314251	training's multi_logloss: 0.75375	valid_1's multi_error: 0.246989	valid_1's multi_logloss: 0.638611
# [185]	training's multi_error: 0.314136	training's multi_logloss: 0.753422	valid_1's multi_error: 0.24685	valid_1's multi_logloss: 0.638382
# [186]	training's multi_error: 0.31402	training's multi_logloss: 0.753083	valid_1's multi_error: 0.24675	valid_1's multi_logloss: 0.638093
# [187]	training's multi_error: 0.313911	training's multi_logloss: 0.752752	valid_1's multi_error: 0.24665	valid_1's multi_logloss: 0.637792
# [188]	training's multi_error: 0.313799	training's multi_logloss: 0.752429	valid_1's multi_error: 0.246618	valid_1's multi_logloss: 0.637521
# [189]	training's multi_error: 0.313691	training's multi_logloss: 0.752075	valid_1's multi_error: 0.246475	valid_1's multi_logloss: 0.637266
# [190]	training's multi_error: 0.313554	training's multi_logloss: 0.751748	valid_1's multi_error: 0.246462	valid_1's multi_logloss: 0.637066
# [191]	training's multi_error: 0.313453	training's multi_logloss: 0.751431	valid_1's multi_error: 0.246398	valid_1's multi_logloss: 0.636813
# [192]	training's multi_error: 0.313339	training's multi_logloss: 0.751115	valid_1's multi_error: 0.246384	valid_1's multi_logloss: 0.63655
# [193]	training's multi_error: 0.313229	training's multi_logloss: 0.750803	valid_1's multi_error: 0.246319	valid_1's multi_logloss: 0.636279
# [194]	training's multi_error: 0.313124	training's multi_logloss: 0.750483	valid_1's multi_error: 0.246216	valid_1's multi_logloss: 0.635974
# [195]	training's multi_error: 0.313003	training's multi_logloss: 0.750177	valid_1's multi_error: 0.246137	valid_1's multi_logloss: 0.635664
# [196]	training's multi_error: 0.312895	training's multi_logloss: 0.749887	valid_1's multi_error: 0.246102	valid_1's multi_logloss: 0.635436
# [197]	training's multi_error: 0.312739	training's multi_logloss: 0.74953	valid_1's multi_error: 0.24588	valid_1's multi_logloss: 0.63519
# [198]	training's multi_error: 0.312676	training's multi_logloss: 0.749243	valid_1's multi_error: 0.245869	valid_1's multi_logloss: 0.634971
# [199]	training's multi_error: 0.312592	training's multi_logloss: 0.74895	valid_1's multi_error: 0.245816	valid_1's multi_logloss: 0.634709
# [200]	training's multi_error: 0.312464	training's multi_logloss: 0.748615	valid_1's multi_error: 0.245674	valid_1's multi_logloss: 0.634391
# [201]	training's multi_error: 0.312348	training's multi_logloss: 0.748317	valid_1's multi_error: 0.245697	valid_1's multi_logloss: 0.634438
# [202]	training's multi_error: 0.312234	training's multi_logloss: 0.747992	valid_1's multi_error: 0.24561	valid_1's multi_logloss: 0.634192
# [203]	training's multi_error: 0.312107	training's multi_logloss: 0.747697	valid_1's multi_error: 0.245545	valid_1's multi_logloss: 0.633898
# [204]	training's multi_error: 0.311995	training's multi_logloss: 0.747411	valid_1's multi_error: 0.245479	valid_1's multi_logloss: 0.63366
# [205]	training's multi_error: 0.311919	training's multi_logloss: 0.747141	valid_1's multi_error: 0.245337	valid_1's multi_logloss: 0.633453
# [206]	training's multi_error: 0.311824	training's multi_logloss: 0.74686	valid_1's multi_error: 0.245337	valid_1's multi_logloss: 0.6332
# [207]	training's multi_error: 0.311713	training's multi_logloss: 0.746582	valid_1's multi_error: 0.245197	valid_1's multi_logloss: 0.632964
# [208]	training's multi_error: 0.311619	training's multi_logloss: 0.746308	valid_1's multi_error: 0.24518	valid_1's multi_logloss: 0.632738
# [209]	training's multi_error: 0.311534	training's multi_logloss: 0.746024	valid_1's multi_error: 0.245093	valid_1's multi_logloss: 0.632505
# [210]	training's multi_error: 0.311427	training's multi_logloss: 0.745747	valid_1's multi_error: 0.245064	valid_1's multi_logloss: 0.632263
# [211]	training's multi_error: 0.311328	training's multi_logloss: 0.745472	valid_1's multi_error: 0.245	valid_1's multi_logloss: 0.632018
# [212]	training's multi_error: 0.311217	training's multi_logloss: 0.745201	valid_1's multi_error: 0.244911	valid_1's multi_logloss: 0.63179
# [213]	training's multi_error: 0.311127	training's multi_logloss: 0.744927	valid_1's multi_error: 0.244846	valid_1's multi_logloss: 0.631552
# [214]	training's multi_error: 0.311033	training's multi_logloss: 0.744662	valid_1's multi_error: 0.244827	valid_1's multi_logloss: 0.631358
# [215]	training's multi_error: 0.310937	training's multi_logloss: 0.744405	valid_1's multi_error: 0.244906	valid_1's multi_logloss: 0.631398
# [216]	training's multi_error: 0.310851	training's multi_logloss: 0.744143	valid_1's multi_error: 0.244872	valid_1's multi_logloss: 0.631181
# [217]	training's multi_error: 0.310742	training's multi_logloss: 0.743867	valid_1's multi_error: 0.244818	valid_1's multi_logloss: 0.630938
# [218]	training's multi_error: 0.31067	training's multi_logloss: 0.743607	valid_1's multi_error: 0.244813	valid_1's multi_logloss: 0.630727
# [219]	training's multi_error: 0.310573	training's multi_logloss: 0.743309	valid_1's multi_error: 0.244711	valid_1's multi_logloss: 0.630468
# [220]	training's multi_error: 0.310492	training's multi_logloss: 0.743057	valid_1's multi_error: 0.24477	valid_1's multi_logloss: 0.630447
# [221]	training's multi_error: 0.310379	training's multi_logloss: 0.742769	valid_1's multi_error: 0.244637	valid_1's multi_logloss: 0.630164
# [222]	training's multi_error: 0.310282	training's multi_logloss: 0.742523	valid_1's multi_error: 0.244608	valid_1's multi_logloss: 0.629924
# [223]	training's multi_error: 0.310198	training's multi_logloss: 0.742269	valid_1's multi_error: 0.244549	valid_1's multi_logloss: 0.629724
# [224]	training's multi_error: 0.310098	training's multi_logloss: 0.742003	valid_1's multi_error: 0.244476	valid_1's multi_logloss: 0.629654
# [225]	training's multi_error: 0.309983	training's multi_logloss: 0.741725	valid_1's multi_error: 0.24432	valid_1's multi_logloss: 0.62935
# [226]	training's multi_error: 0.309901	training's multi_logloss: 0.741469	valid_1's multi_error: 0.244278	valid_1's multi_logloss: 0.629118
# [227]	training's multi_error: 0.309809	training's multi_logloss: 0.741224	valid_1's multi_error: 0.244216	valid_1's multi_logloss: 0.628952
# [228]	training's multi_error: 0.309696	training's multi_logloss: 0.740977	valid_1's multi_error: 0.244155	valid_1's multi_logloss: 0.628692
# [229]	training's multi_error: 0.309645	training's multi_logloss: 0.740732	valid_1's multi_error: 0.244118	valid_1's multi_logloss: 0.628487
# [230]	training's multi_error: 0.309576	training's multi_logloss: 0.740497	valid_1's multi_error: 0.244056	valid_1's multi_logloss: 0.6283
# [231]	training's multi_error: 0.309493	training's multi_logloss: 0.740259	valid_1's multi_error: 0.244006	valid_1's multi_logloss: 0.628118
# [232]	training's multi_error: 0.309393	training's multi_logloss: 0.74002	valid_1's multi_error: 0.243949	valid_1's multi_logloss: 0.627918
# [233]	training's multi_error: 0.309301	training's multi_logloss: 0.739792	valid_1's multi_error: 0.243895	valid_1's multi_logloss: 0.627701
# [234]	training's multi_error: 0.309226	training's multi_logloss: 0.739556	valid_1's multi_error: 0.243869	valid_1's multi_logloss: 0.627527
# [235]	training's multi_error: 0.30909	training's multi_logloss: 0.739236	valid_1's multi_error: 0.243805	valid_1's multi_logloss: 0.627263
# [236]	training's multi_error: 0.309003	training's multi_logloss: 0.739003	valid_1's multi_error: 0.243776	valid_1's multi_logloss: 0.627063
# [237]	training's multi_error: 0.308912	training's multi_logloss: 0.738767	valid_1's multi_error: 0.243693	valid_1's multi_logloss: 0.62691
# [238]	training's multi_error: 0.308827	training's multi_logloss: 0.738541	valid_1's multi_error: 0.243629	valid_1's multi_logloss: 0.626726
# [239]	training's multi_error: 0.308762	training's multi_logloss: 0.738321	valid_1's multi_error: 0.24359	valid_1's multi_logloss: 0.626544
# [240]	training's multi_error: 0.308659	training's multi_logloss: 0.7381	valid_1's multi_error: 0.24358	valid_1's multi_logloss: 0.626366
# [241]	training's multi_error: 0.308585	training's multi_logloss: 0.737879	valid_1's multi_error: 0.243551	valid_1's multi_logloss: 0.626214
# [242]	training's multi_error: 0.308496	training's multi_logloss: 0.737658	valid_1's multi_error: 0.243512	valid_1's multi_logloss: 0.626028
# [243]	training's multi_error: 0.308408	training's multi_logloss: 0.737427	valid_1's multi_error: 0.243594	valid_1's multi_logloss: 0.626151
# [244]	training's multi_error: 0.308336	training's multi_logloss: 0.737208	valid_1's multi_error: 0.243585	valid_1's multi_logloss: 0.625987
# [245]	training's multi_error: 0.308261	training's multi_logloss: 0.736993	valid_1's multi_error: 0.243477	valid_1's multi_logloss: 0.625759
# [246]	training's multi_error: 0.30821	training's multi_logloss: 0.736779	valid_1's multi_error: 0.243417	valid_1's multi_logloss: 0.625554
# [247]	training's multi_error: 0.308138	training's multi_logloss: 0.736563	valid_1's multi_error: 0.2433	valid_1's multi_logloss: 0.625363
# [248]	training's multi_error: 0.308055	training's multi_logloss: 0.736348	valid_1's multi_error: 0.243253	valid_1's multi_logloss: 0.625194
# [249]	training's multi_error: 0.307976	training's multi_logloss: 0.73611	valid_1's multi_error: 0.243244	valid_1's multi_logloss: 0.624979
# [250]	training's multi_error: 0.307892	training's multi_logloss: 0.735895	valid_1's multi_error: 0.243205	valid_1's multi_logloss: 0.624789
# [251]	training's multi_error: 0.307804	training's multi_logloss: 0.735679	valid_1's multi_error: 0.243155	valid_1's multi_logloss: 0.62463
# [252]	training's multi_error: 0.307748	training's multi_logloss: 0.735469	valid_1's multi_error: 0.243106	valid_1's multi_logloss: 0.624457
# [253]	training's multi_error: 0.307661	training's multi_logloss: 0.735262	valid_1's multi_error: 0.243056	valid_1's multi_logloss: 0.624296
# [254]	training's multi_error: 0.307587	training's multi_logloss: 0.735068	valid_1's multi_error: 0.243228	valid_1's multi_logloss: 0.624408
# [255]	training's multi_error: 0.307521	training's multi_logloss: 0.734862	valid_1's multi_error: 0.243159	valid_1's multi_logloss: 0.62427
# [256]	training's multi_error: 0.307448	training's multi_logloss: 0.734659	valid_1's multi_error: 0.243129	valid_1's multi_logloss: 0.624109
# [257]	training's multi_error: 0.30739	training's multi_logloss: 0.734461	valid_1's multi_error: 0.243073	valid_1's multi_logloss: 0.623929
# [258]	training's multi_error: 0.30731	training's multi_logloss: 0.734231	valid_1's multi_error: 0.24301	valid_1's multi_logloss: 0.623702
# [259]	training's multi_error: 0.307202	training's multi_logloss: 0.733983	valid_1's multi_error: 0.242899	valid_1's multi_logloss: 0.623425
# [260]	training's multi_error: 0.307127	training's multi_logloss: 0.733784	valid_1's multi_error: 0.242838	valid_1's multi_logloss: 0.623259
# [261]	training's multi_error: 0.307079	training's multi_logloss: 0.733584	valid_1's multi_error: 0.242795	valid_1's multi_logloss: 0.623086
# [262]	training's multi_error: 0.307022	training's multi_logloss: 0.733392	valid_1's multi_error: 0.242744	valid_1's multi_logloss: 0.622885
# [263]	training's multi_error: 0.306941	training's multi_logloss: 0.733198	valid_1's multi_error: 0.242676	valid_1's multi_logloss: 0.622741
# [264]	training's multi_error: 0.306871	training's multi_logloss: 0.733004	valid_1's multi_error: 0.242632	valid_1's multi_logloss: 0.622572
# [265]	training's multi_error: 0.306789	training's multi_logloss: 0.732815	valid_1's multi_error: 0.242584	valid_1's multi_logloss: 0.62239
# [266]	training's multi_error: 0.306718	training's multi_logloss: 0.732618	valid_1's multi_error: 0.242484	valid_1's multi_logloss: 0.622152
# [267]	training's multi_error: 0.306634	training's multi_logloss: 0.732431	valid_1's multi_error: 0.24251	valid_1's multi_logloss: 0.622013
# [268]	training's multi_error: 0.306536	training's multi_logloss: 0.732185	valid_1's multi_error: 0.242538	valid_1's multi_logloss: 0.621951
# [269]	training's multi_error: 0.306453	training's multi_logloss: 0.731988	valid_1's multi_error: 0.242422	valid_1's multi_logloss: 0.621728
# [270]	training's multi_error: 0.306423	training's multi_logloss: 0.731793	valid_1's multi_error: 0.242364	valid_1's multi_logloss: 0.621553
# [271]	training's multi_error: 0.306344	training's multi_logloss: 0.731609	valid_1's multi_error: 0.242344	valid_1's multi_logloss: 0.621424
# [272]	training's multi_error: 0.306273	training's multi_logloss: 0.731415	valid_1's multi_error: 0.242259	valid_1's multi_logloss: 0.62124
# [273]	training's multi_error: 0.306178	training's multi_logloss: 0.731228	valid_1's multi_error: 0.242225	valid_1's multi_logloss: 0.621085
# [274]	training's multi_error: 0.306119	training's multi_logloss: 0.730979	valid_1's multi_error: 0.242147	valid_1's multi_logloss: 0.620806
# [275]	training's multi_error: 0.306032	training's multi_logloss: 0.730726	valid_1's multi_error: 0.242017	valid_1's multi_logloss: 0.620581
# [276]	training's multi_error: 0.305968	training's multi_logloss: 0.730532	valid_1's multi_error: 0.241989	valid_1's multi_logloss: 0.620497
# [277]	training's multi_error: 0.305921	training's multi_logloss: 0.730349	valid_1's multi_error: 0.241956	valid_1's multi_logloss: 0.620403
# [278]	training's multi_error: 0.305847	training's multi_logloss: 0.730162	valid_1's multi_error: 0.241885	valid_1's multi_logloss: 0.620218
# [279]	training's multi_error: 0.305794	training's multi_logloss: 0.729981	valid_1's multi_error: 0.241887	valid_1's multi_logloss: 0.620075
# [280]	training's multi_error: 0.305714	training's multi_logloss: 0.729801	valid_1's multi_error: 0.241869	valid_1's multi_logloss: 0.619959
# [281]	training's multi_error: 0.305657	training's multi_logloss: 0.729623	valid_1's multi_error: 0.241845	valid_1's multi_logloss: 0.619834
# [282]	training's multi_error: 0.305587	training's multi_logloss: 0.729445	valid_1's multi_error: 0.241806	valid_1's multi_logloss: 0.619693
# [283]	training's multi_error: 0.305524	training's multi_logloss: 0.729268	valid_1's multi_error: 0.241775	valid_1's multi_logloss: 0.61954
# [284]	training's multi_error: 0.305471	training's multi_logloss: 0.729095	valid_1's multi_error: 0.241754	valid_1's multi_logloss: 0.619415
# [285]	training's multi_error: 0.305385	training's multi_logloss: 0.728923	valid_1's multi_error: 0.241699	valid_1's multi_logloss: 0.619263
# [286]	training's multi_error: 0.305323	training's multi_logloss: 0.728743	valid_1's multi_error: 0.241638	valid_1's multi_logloss: 0.619114
# [287]	training's multi_error: 0.305255	training's multi_logloss: 0.728568	valid_1's multi_error: 0.241616	valid_1's multi_logloss: 0.618987
# [288]	training's multi_error: 0.305198	training's multi_logloss: 0.728392	valid_1's multi_error: 0.241628	valid_1's multi_logloss: 0.618882
# [289]	training's multi_error: 0.305157	training's multi_logloss: 0.728222	valid_1's multi_error: 0.241565	valid_1's multi_logloss: 0.618741
# [290]	training's multi_error: 0.305073	training's multi_logloss: 0.728053	valid_1's multi_error: 0.241557	valid_1's multi_logloss: 0.618628
# [291]	training's multi_error: 0.305009	training's multi_logloss: 0.727883	valid_1's multi_error: 0.241493	valid_1's multi_logloss: 0.618517
# [292]	training's multi_error: 0.304943	training's multi_logloss: 0.727706	valid_1's multi_error: 0.241435	valid_1's multi_logloss: 0.618379
# [293]	training's multi_error: 0.30487	training's multi_logloss: 0.727539	valid_1's multi_error: 0.241408	valid_1's multi_logloss: 0.618262
# [294]	training's multi_error: 0.304805	training's multi_logloss: 0.727372	valid_1's multi_error: 0.241355	valid_1's multi_logloss: 0.618111
# [295]	training's multi_error: 0.30479	training's multi_logloss: 0.727212	valid_1's multi_error: 0.241447	valid_1's multi_logloss: 0.618108
# [296]	training's multi_error: 0.304723	training's multi_logloss: 0.727039	valid_1's multi_error: 0.241419	valid_1's multi_logloss: 0.617968
# [297]	training's multi_error: 0.304663	training's multi_logloss: 0.726878	valid_1's multi_error: 0.241369	valid_1's multi_logloss: 0.617831
# [298]	training's multi_error: 0.304593	training's multi_logloss: 0.726717	valid_1's multi_error: 0.241321	valid_1's multi_logloss: 0.617677
# [299]	training's multi_error: 0.304551	training's multi_logloss: 0.726554	valid_1's multi_error: 0.241296	valid_1's multi_logloss: 0.617549
# [300]	training's multi_error: 0.304437	training's multi_logloss: 0.726311	valid_1's multi_error: 0.241252	valid_1's multi_logloss: 0.617446
# [301]	training's multi_error: 0.304373	training's multi_logloss: 0.72615	valid_1's multi_error: 0.241198	valid_1's multi_logloss: 0.617323
# [302]	training's multi_error: 0.304302	training's multi_logloss: 0.725964	valid_1's multi_error: 0.241147	valid_1's multi_logloss: 0.617228
# [303]	training's multi_error: 0.304246	training's multi_logloss: 0.725799	valid_1's multi_error: 0.24106	valid_1's multi_logloss: 0.617053
# [304]	training's multi_error: 0.304198	training's multi_logloss: 0.725635	valid_1's multi_error: 0.24101	valid_1's multi_logloss: 0.616885
# [305]	training's multi_error: 0.304135	training's multi_logloss: 0.725473	valid_1's multi_error: 0.240964	valid_1's multi_logloss: 0.61674
# [306]	training's multi_error: 0.304077	training's multi_logloss: 0.725318	valid_1's multi_error: 0.240923	valid_1's multi_logloss: 0.616608
# [307]	training's multi_error: 0.303988	training's multi_logloss: 0.725152	valid_1's multi_error: 0.240978	valid_1's multi_logloss: 0.61654
# [308]	training's multi_error: 0.303931	training's multi_logloss: 0.724992	valid_1's multi_error: 0.240983	valid_1's multi_logloss: 0.616409
# [309]	training's multi_error: 0.30388	training's multi_logloss: 0.724836	valid_1's multi_error: 0.240946	valid_1's multi_logloss: 0.616297
# [310]	training's multi_error: 0.30382	training's multi_logloss: 0.724685	valid_1's multi_error: 0.240911	valid_1's multi_logloss: 0.616161
# [311]	training's multi_error: 0.303779	training's multi_logloss: 0.724527	valid_1's multi_error: 0.240882	valid_1's multi_logloss: 0.616032
# [312]	training's multi_error: 0.303701	training's multi_logloss: 0.724371	valid_1's multi_error: 0.240775	valid_1's multi_logloss: 0.615863
# [313]	training's multi_error: 0.303639	training's multi_logloss: 0.724211	valid_1's multi_error: 0.24072	valid_1's multi_logloss: 0.615741
# [314]	training's multi_error: 0.30358	training's multi_logloss: 0.724054	valid_1's multi_error: 0.24069	valid_1's multi_logloss: 0.615645
# [315]	training's multi_error: 0.303525	training's multi_logloss: 0.723903	valid_1's multi_error: 0.240684	valid_1's multi_logloss: 0.615552
# [316]	training's multi_error: 0.303468	training's multi_logloss: 0.723748	valid_1's multi_error: 0.240835	valid_1's multi_logloss: 0.615694
# [317]	training's multi_error: 0.303429	training's multi_logloss: 0.723591	valid_1's multi_error: 0.240784	valid_1's multi_logloss: 0.615512
# [318]	training's multi_error: 0.303349	training's multi_logloss: 0.723428	valid_1's multi_error: 0.240767	valid_1's multi_logloss: 0.615395
# [319]	training's multi_error: 0.303285	training's multi_logloss: 0.723283	valid_1's multi_error: 0.24074	valid_1's multi_logloss: 0.615269
# [320]	training's multi_error: 0.303217	training's multi_logloss: 0.723136	valid_1's multi_error: 0.240746	valid_1's multi_logloss: 0.615158
# [321]	training's multi_error: 0.303181	training's multi_logloss: 0.722992	valid_1's multi_error: 0.240735	valid_1's multi_logloss: 0.61505
# [322]	training's multi_error: 0.303126	training's multi_logloss: 0.722845	valid_1's multi_error: 0.240743	valid_1's multi_logloss: 0.614935
# [323]	training's multi_error: 0.303073	training's multi_logloss: 0.722702	valid_1's multi_error: 0.240726	valid_1's multi_logloss: 0.614827
# [324]	training's multi_error: 0.303039	training's multi_logloss: 0.722556	valid_1's multi_error: 0.240669	valid_1's multi_logloss: 0.61468
# [325]	training's multi_error: 0.302977	training's multi_logloss: 0.722414	valid_1's multi_error: 0.240635	valid_1's multi_logloss: 0.614557
# [326]	training's multi_error: 0.302929	training's multi_logloss: 0.72227	valid_1's multi_error: 0.240644	valid_1's multi_logloss: 0.614497
# [327]	training's multi_error: 0.302875	training's multi_logloss: 0.722131	valid_1's multi_error: 0.240625	valid_1's multi_logloss: 0.61439
# [328]	training's multi_error: 0.302804	training's multi_logloss: 0.721984	valid_1's multi_error: 0.240578	valid_1's multi_logloss: 0.614268
# [329]	training's multi_error: 0.302769	training's multi_logloss: 0.721843	valid_1's multi_error: 0.240567	valid_1's multi_logloss: 0.614174
# [330]	training's multi_error: 0.302701	training's multi_logloss: 0.721695	valid_1's multi_error: 0.240489	valid_1's multi_logloss: 0.614052
# [331]	training's multi_error: 0.302665	training's multi_logloss: 0.721556	valid_1's multi_error: 0.240453	valid_1's multi_logloss: 0.613952
# [332]	training's multi_error: 0.302588	training's multi_logloss: 0.721392	valid_1's multi_error: 0.240622	valid_1's multi_logloss: 0.61427
# [333]	training's multi_error: 0.302535	training's multi_logloss: 0.721241	valid_1's multi_error: 0.240656	valid_1's multi_logloss: 0.614373
# [334]	training's multi_error: 0.302484	training's multi_logloss: 0.721102	valid_1's multi_error: 0.240727	valid_1's multi_logloss: 0.614454
# [335]	training's multi_error: 0.302445	training's multi_logloss: 0.720966	valid_1's multi_error: 0.240677	valid_1's multi_logloss: 0.614342
# [336]	training's multi_error: 0.302388	training's multi_logloss: 0.720814	valid_1's multi_error: 0.240647	valid_1's multi_logloss: 0.6142
# [337]	training's multi_error: 0.302342	training's multi_logloss: 0.720673	valid_1's multi_error: 0.240616	valid_1's multi_logloss: 0.614095
# [338]	training's multi_error: 0.302285	training's multi_logloss: 0.720538	valid_1's multi_error: 0.240576	valid_1's multi_logloss: 0.613989
# [339]	training's multi_error: 0.302247	training's multi_logloss: 0.720403	valid_1's multi_error: 0.240581	valid_1's multi_logloss: 0.613856
# ...
# [624]	training's multi_error: 0.291749	training's multi_logloss: 0.693372	valid_1's multi_error: 0.235538	valid_1's multi_logloss: 0.594917
# [625]	training's multi_error: 0.291726	training's multi_logloss: 0.693317	valid_1's multi_error: 0.235552	valid_1's multi_logloss: 0.594873
# [626]	training's multi_error: 0.291705	training's multi_logloss: 0.693262	valid_1's multi_error: 0.235533	valid_1's multi_logloss: 0.594833
# [627]	training's multi_error: 0.291682	training's multi_logloss: 0.6932	valid_1's multi_error: 0.235524	valid_1's multi_logloss: 0.594798
# [628]	training's multi_error: 0.291661	training's multi_logloss: 0.693143	valid_1's multi_error: 0.2355	valid_1's multi_logloss: 0.59476
# [629]	training's multi_error: 0.291621	training's multi_logloss: 0.693084	valid_1's multi_error: 0.235483	valid_1's multi_logloss: 0.594718
# [630]	training's multi_error: 0.291591	training's multi_logloss: 0.693025	valid_1's multi_error: 0.235473	valid_1's multi_logloss: 0.594675
# [631]	training's multi_error: 0.291561	training's multi_logloss: 0.692969	valid_1's multi_error: 0.235467	valid_1's multi_logloss: 0.594642
# [632]	training's multi_error: 0.291556	training's multi_logloss: 0.692911	valid_1's multi_error: 0.235447	valid_1's multi_logloss: 0.594611
# [633]	training's multi_error: 0.291546	training's multi_logloss: 0.692851	valid_1's multi_error: 0.23542	valid_1's multi_logloss: 0.594564
# [634]	training's multi_error: 0.291503	training's multi_logloss: 0.692795	valid_1's multi_error: 0.235445	valid_1's multi_logloss: 0.594522
# [635]	training's multi_error: 0.29149	training's multi_logloss: 0.692741	valid_1's multi_error: 0.23543	valid_1's multi_logloss: 0.594484
# [636]	training's multi_error: 0.291456	training's multi_logloss: 0.692684	valid_1's multi_error: 0.235422	valid_1's multi_logloss: 0.594451
# [637]	training's multi_error: 0.291459	training's multi_logloss: 0.692623	valid_1's multi_error: 0.23544	valid_1's multi_logloss: 0.594463
# [638]	training's multi_error: 0.291426	training's multi_logloss: 0.692565	valid_1's multi_error: 0.235425	valid_1's multi_logloss: 0.594423
# [639]	training's multi_error: 0.291412	training's multi_logloss: 0.692507	valid_1's multi_error: 0.235415	valid_1's multi_logloss: 0.594382
# [640]	training's multi_error: 0.291376	training's multi_logloss: 0.692453	valid_1's multi_error: 0.235413	valid_1's multi_logloss: 0.594344
# [641]	training's multi_error: 0.29135	training's multi_logloss: 0.692379	valid_1's multi_error: 0.235364	valid_1's multi_logloss: 0.594295
# [642]	training's multi_error: 0.291333	training's multi_logloss: 0.692318	valid_1's multi_error: 0.235302	valid_1's multi_logloss: 0.594206
# [643]	training's multi_error: 0.291307	training's multi_logloss: 0.69226	valid_1's multi_error: 0.235312	valid_1's multi_logloss: 0.594163
# [644]	training's multi_error: 0.291279	training's multi_logloss: 0.692176	valid_1's multi_error: 0.23528	valid_1's multi_logloss: 0.594073
# [645]	training's multi_error: 0.291243	training's multi_logloss: 0.692118	valid_1's multi_error: 0.235255	valid_1's multi_logloss: 0.594032
# [646]	training's multi_error: 0.291244	training's multi_logloss: 0.692052	valid_1's multi_error: 0.235244	valid_1's multi_logloss: 0.593968
# [647]	training's multi_error: 0.291227	training's multi_logloss: 0.691997	valid_1's multi_error: 0.235241	valid_1's multi_logloss: 0.593936
# [648]	training's multi_error: 0.291208	training's multi_logloss: 0.691942	valid_1's multi_error: 0.235223	valid_1's multi_logloss: 0.593907
# [649]	training's multi_error: 0.291191	training's multi_logloss: 0.691885	valid_1's multi_error: 0.23521	valid_1's multi_logloss: 0.593854
# [650]	training's multi_error: 0.291163	training's multi_logloss: 0.691832	valid_1's multi_error: 0.235237	valid_1's multi_logloss: 0.593832
# [651]	training's multi_error: 0.291138	training's multi_logloss: 0.691773	valid_1's multi_error: 0.235231	valid_1's multi_logloss: 0.593799
# [652]	training's multi_error: 0.29111	training's multi_logloss: 0.691712	valid_1's multi_error: 0.235223	valid_1's multi_logloss: 0.593769
# [653]	training's multi_error: 0.291091	training's multi_logloss: 0.691657	valid_1's multi_error: 0.235204	valid_1's multi_logloss: 0.593732
# [654]	training's multi_error: 0.291063	training's multi_logloss: 0.691602	valid_1's multi_error: 0.23518	valid_1's multi_logloss: 0.59371
# [655]	training's multi_error: 0.291046	training's multi_logloss: 0.691547	valid_1's multi_error: 0.235177	valid_1's multi_logloss: 0.593673
# [656]	training's multi_error: 0.291017	training's multi_logloss: 0.691494	valid_1's multi_error: 0.235189	valid_1's multi_logloss: 0.593637
# [657]	training's multi_error: 0.290991	training's multi_logloss: 0.69144	valid_1's multi_error: 0.235178	valid_1's multi_logloss: 0.593598
# [658]	training's multi_error: 0.290962	training's multi_logloss: 0.691384	valid_1's multi_error: 0.235182	valid_1's multi_logloss: 0.593566
# [659]	training's multi_error: 0.290942	training's multi_logloss: 0.69133	valid_1's multi_error: 0.235176	valid_1's multi_logloss: 0.59354
# [660]	training's multi_error: 0.290919	training's multi_logloss: 0.691278	valid_1's multi_error: 0.235164	valid_1's multi_logloss: 0.593509
# [661]	training's multi_error: 0.290891	training's multi_logloss: 0.691224	valid_1's multi_error: 0.235157	valid_1's multi_logloss: 0.593467
# [662]	training's multi_error: 0.290863	training's multi_logloss: 0.691164	valid_1's multi_error: 0.235134	valid_1's multi_logloss: 0.593456
# [663]	training's multi_error: 0.290843	training's multi_logloss: 0.69111	valid_1's multi_error: 0.235111	valid_1's multi_logloss: 0.593422
# [664]	training's multi_error: 0.290827	training's multi_logloss: 0.691058	valid_1's multi_error: 0.235127	valid_1's multi_logloss: 0.593396
# [665]	training's multi_error: 0.290801	training's multi_logloss: 0.691009	valid_1's multi_error: 0.235113	valid_1's multi_logloss: 0.593367
# [666]	training's multi_error: 0.290782	training's multi_logloss: 0.690956	valid_1's multi_error: 0.23511	valid_1's multi_logloss: 0.59334
# [667]	training's multi_error: 0.29076	training's multi_logloss: 0.690902	valid_1's multi_error: 0.235091	valid_1's multi_logloss: 0.593314
# [668]	training's multi_error: 0.290747	training's multi_logloss: 0.690849	valid_1's multi_error: 0.235083	valid_1's multi_logloss: 0.593283
# [669]	training's multi_error: 0.290722	training's multi_logloss: 0.690789	valid_1's multi_error: 0.235049	valid_1's multi_logloss: 0.593242
# [670]	training's multi_error: 0.290709	training's multi_logloss: 0.690736	valid_1's multi_error: 0.235048	valid_1's multi_logloss: 0.593198
# [671]	training's multi_error: 0.290692	training's multi_logloss: 0.690678	valid_1's multi_error: 0.235014	valid_1's multi_logloss: 0.593163
# [672]	training's multi_error: 0.290662	training's multi_logloss: 0.690625	valid_1's multi_error: 0.235026	valid_1's multi_logloss: 0.593117
# [673]	training's multi_error: 0.290631	training's multi_logloss: 0.690558	valid_1's multi_error: 0.234995	valid_1's multi_logloss: 0.593096
# [674]	training's multi_error: 0.290583	training's multi_logloss: 0.690494	valid_1's multi_error: 0.234981	valid_1's multi_logloss: 0.593043
# [675]	training's multi_error: 0.290563	training's multi_logloss: 0.690438	valid_1's multi_error: 0.23497	valid_1's multi_logloss: 0.593006
# [676]	training's multi_error: 0.290562	training's multi_logloss: 0.690387	valid_1's multi_error: 0.234953	valid_1's multi_logloss: 0.59298
# [677]	training's multi_error: 0.290554	training's multi_logloss: 0.690332	valid_1's multi_error: 0.234918	valid_1's multi_logloss: 0.592921
# [678]	training's multi_error: 0.290537	training's multi_logloss: 0.690269	valid_1's multi_error: 0.234876	valid_1's multi_logloss: 0.592915
# [679]	training's multi_error: 0.290498	training's multi_logloss: 0.690191	valid_1's multi_error: 0.234858	valid_1's multi_logloss: 0.59283
# [680]	training's multi_error: 0.290475	training's multi_logloss: 0.690129	valid_1's multi_error: 0.234835	valid_1's multi_logloss: 0.592771
# [681]	training's multi_error: 0.29046	training's multi_logloss: 0.69007	valid_1's multi_error: 0.234814	valid_1's multi_logloss: 0.592712
# [682]	training's multi_error: 0.290429	training's multi_logloss: 0.689994	valid_1's multi_error: 0.23481	valid_1's multi_logloss: 0.592648
# [683]	training's multi_error: 0.29041	training's multi_logloss: 0.689941	valid_1's multi_error: 0.234833	valid_1's multi_logloss: 0.592628
# [684]	training's multi_error: 0.290382	training's multi_logloss: 0.689886	valid_1's multi_error: 0.234813	valid_1's multi_logloss: 0.592598
# [685]	training's multi_error: 0.290355	training's multi_logloss: 0.689835	valid_1's multi_error: 0.234803	valid_1's multi_logloss: 0.592569
# [686]	training's multi_error: 0.290331	training's multi_logloss: 0.689785	valid_1's multi_error: 0.234783	valid_1's multi_logloss: 0.592533
# [687]	training's multi_error: 0.290318	training's multi_logloss: 0.689728	valid_1's multi_error: 0.234799	valid_1's multi_logloss: 0.592506
# [688]	training's multi_error: 0.290289	training's multi_logloss: 0.689672	valid_1's multi_error: 0.234782	valid_1's multi_logloss: 0.592485
# [689]	training's multi_error: 0.290283	training's multi_logloss: 0.689621	valid_1's multi_error: 0.23478	valid_1's multi_logloss: 0.592451
# [690]	training's multi_error: 0.29026	training's multi_logloss: 0.689572	valid_1's multi_error: 0.234767	valid_1's multi_logloss: 0.592418
# [691]	training's multi_error: 0.290244	training's multi_logloss: 0.689523	valid_1's multi_error: 0.234762	valid_1's multi_logloss: 0.592385
# [692]	training's multi_error: 0.290222	training's multi_logloss: 0.689464	valid_1's multi_error: 0.234725	valid_1's multi_logloss: 0.592338
# [693]	training's multi_error: 0.290187	training's multi_logloss: 0.689413	valid_1's multi_error: 0.23473	valid_1's multi_logloss: 0.592312
# [694]	training's multi_error: 0.29016	training's multi_logloss: 0.689356	valid_1's multi_error: 0.23475	valid_1's multi_logloss: 0.592301
# [695]	training's multi_error: 0.290152	training's multi_logloss: 0.689298	valid_1's multi_error: 0.234732	valid_1's multi_logloss: 0.592251
# [696]	training's multi_error: 0.290128	training's multi_logloss: 0.689246	valid_1's multi_error: 0.234733	valid_1's multi_logloss: 0.592221
# [697]	training's multi_error: 0.290099	training's multi_logloss: 0.689193	valid_1's multi_error: 0.234727	valid_1's multi_logloss: 0.59222
# [698]	training's multi_error: 0.290094	training's multi_logloss: 0.689143	valid_1's multi_error: 0.234717	valid_1's multi_logloss: 0.592192
# [699]	training's multi_error: 0.290059	training's multi_logloss: 0.689082	valid_1's multi_error: 0.234738	valid_1's multi_logloss: 0.592177
# [700]	training's multi_error: 0.290038	training's multi_logloss: 0.689034	valid_1's multi_error: 0.234724	valid_1's multi_logloss: 0.592148
# [701]	training's multi_error: 0.290007	training's multi_logloss: 0.688972	valid_1's multi_error: 0.234696	valid_1's multi_logloss: 0.592131
# [702]	training's multi_error: 0.289993	training's multi_logloss: 0.68892	valid_1's multi_error: 0.234688	valid_1's multi_logloss: 0.592088
# [703]	training's multi_error: 0.289981	training's multi_logloss: 0.688869	valid_1's multi_error: 0.234683	valid_1's multi_logloss: 0.592053
# [704]	training's multi_error: 0.289956	training's multi_logloss: 0.688821	valid_1's multi_error: 0.234682	valid_1's multi_logloss: 0.592018
# [705]	training's multi_error: 0.289923	training's multi_logloss: 0.688765	valid_1's multi_error: 0.234639	valid_1's multi_logloss: 0.591982
# [706]	training's multi_error: 0.289891	training's multi_logloss: 0.688708	valid_1's multi_error: 0.234628	valid_1's multi_logloss: 0.591944
# [707]	training's multi_error: 0.289887	training's multi_logloss: 0.688658	valid_1's multi_error: 0.234633	valid_1's multi_logloss: 0.591918
# [708]	training's multi_error: 0.289876	training's multi_logloss: 0.688609	valid_1's multi_error: 0.234606	valid_1's multi_logloss: 0.591881
# [709]	training's multi_error: 0.289858	training's multi_logloss: 0.688556	valid_1's multi_error: 0.234623	valid_1's multi_logloss: 0.591851
# [710]	training's multi_error: 0.289829	training's multi_logloss: 0.688507	valid_1's multi_error: 0.23461	valid_1's multi_logloss: 0.591821
# [711]	training's multi_error: 0.289799	training's multi_logloss: 0.688451	valid_1's multi_error: 0.234604	valid_1's multi_logloss: 0.591803
# [712]	training's multi_error: 0.28976	training's multi_logloss: 0.688395	valid_1's multi_error: 0.23473	valid_1's multi_logloss: 0.592055
# [713]	training's multi_error: 0.289731	training's multi_logloss: 0.688322	valid_1's multi_error: 0.234778	valid_1's multi_logloss: 0.592136
# [714]	training's multi_error: 0.289716	training's multi_logloss: 0.688269	valid_1's multi_error: 0.234733	valid_1's multi_logloss: 0.592105
# [715]	training's multi_error: 0.289704	training's multi_logloss: 0.68822	valid_1's multi_error: 0.234728	valid_1's multi_logloss: 0.59208
# [716]	training's multi_error: 0.289676	training's multi_logloss: 0.688165	valid_1's multi_error: 0.234738	valid_1's multi_logloss: 0.592029
# [717]	training's multi_error: 0.28966	training's multi_logloss: 0.688116	valid_1's multi_error: 0.234721	valid_1's multi_logloss: 0.592001
# [718]	training's multi_error: 0.289637	training's multi_logloss: 0.688069	valid_1's multi_error: 0.234703	valid_1's multi_logloss: 0.591983
# [719]	training's multi_error: 0.289616	training's multi_logloss: 0.688021	valid_1's multi_error: 0.234671	valid_1's multi_logloss: 0.591948
# [720]	training's multi_error: 0.289602	training's multi_logloss: 0.687972	valid_1's multi_error: 0.234666	valid_1's multi_logloss: 0.591925
# [721]	training's multi_error: 0.28959	training's multi_logloss: 0.687926	valid_1's multi_error: 0.234686	valid_1's multi_logloss: 0.591902
# [722]	training's multi_error: 0.289565	training's multi_logloss: 0.687879	valid_1's multi_error: 0.234689	valid_1's multi_logloss: 0.591881
# [723]	training's multi_error: 0.289541	training's multi_logloss: 0.687829	valid_1's multi_error: 0.234686	valid_1's multi_logloss: 0.59184
# [724]	training's multi_error: 0.289511	training's multi_logloss: 0.687773	valid_1's multi_error: 0.234706	valid_1's multi_logloss: 0.591848
# [725]	training's multi_error: 0.289491	training's multi_logloss: 0.687728	valid_1's multi_error: 0.234692	valid_1's multi_logloss: 0.591832
# [726]	training's multi_error: 0.289474	training's multi_logloss: 0.687681	valid_1's multi_error: 0.234732	valid_1's multi_logloss: 0.591806
# [727]	training's multi_error: 0.289461	training's multi_logloss: 0.687629	valid_1's multi_error: 0.234712	valid_1's multi_logloss: 0.591761
# [728]	training's multi_error: 0.289441	training's multi_logloss: 0.687577	valid_1's multi_error: 0.234662	valid_1's multi_logloss: 0.591707
# [729]	training's multi_error: 0.289426	training's multi_logloss: 0.687528	valid_1's multi_error: 0.234683	valid_1's multi_logloss: 0.591684
# [730]	training's multi_error: 0.289402	training's multi_logloss: 0.687478	valid_1's multi_error: 0.234677	valid_1's multi_logloss: 0.591649
# [731]	training's multi_error: 0.289364	training's multi_logloss: 0.687412	valid_1's multi_error: 0.234667	valid_1's multi_logloss: 0.591599
# [732]	training's multi_error: 0.289346	training's multi_logloss: 0.687364	valid_1's multi_error: 0.234667	valid_1's multi_logloss: 0.591577
# [733]	training's multi_error: 0.289317	training's multi_logloss: 0.687319	valid_1's multi_error: 0.234667	valid_1's multi_logloss: 0.591552
# [734]	training's multi_error: 0.289305	training's multi_logloss: 0.687261	valid_1's multi_error: 0.234636	valid_1's multi_logloss: 0.591513
# [735]	training's multi_error: 0.289285	training's multi_logloss: 0.687204	valid_1's multi_error: 0.234639	valid_1's multi_logloss: 0.591487
# [736]	training's multi_error: 0.289262	training's multi_logloss: 0.687156	valid_1's multi_error: 0.234638	valid_1's multi_logloss: 0.591469
# Early stopping, best iteration is:
# [711]	training's multi_error: 0.289799	training's multi_logloss: 0.688451	valid_1's multi_error: 0.234604	valid_1's multi_logloss: 0.591803

# %%
booster.save_model((yelp_dir / 'lgb_model.txt').as_posix());

# %%
y_pred_class = booster.predict(test_dtm_numeric.astype(float))

# %% [markdown]
# The basic settings did not improve over the multinomial logistic regression, but further parameter tuning remains an unused option.

# %%
accuracy['lgb_comb'] = accuracy_score(test.stars, y_pred_class.argmax(1) + 1)

# %% [markdown]
# ## Comparison

# %%
model_map = {'nb_combined': 'Naive Bayes',
             'lr_comb': 'Logistic Regression',
             'lgb_comb': 'LightGBM'}

# %%
accuracy_ = {model_map[k]: v for k, v in accuracy.items() if model_map.get(k)}

# %%
log_reg_text = pd.read_csv(yelp_dir / 'logreg_text.csv',
                       index_col=0).squeeze('columns')
log_reg_combined = pd.read_csv(yelp_dir / 'logreg_combined.csv',
                       index_col=0).squeeze('columns')

# %%
fig, axes = plt.subplots(ncols=2, figsize=(14, 4))
pd.Series(accuracy_).sort_values().plot.barh(
    ax=axes[0], xlim=(.45, .75), title='Accuracy by Model')
axes[0].axvline(naive_benchmark, ls='--', lw=1, c='k')


log_reg = (log_reg_text.to_frame('text')
           .join(log_reg_combined.to_frame('combined')))
log_reg.plot(logx=True,
             ax=axes[1],
             title='Logistic Regression - Model Tuning')
axes[1].set_xlabel('Regularization')
axes[1].set_ylabel('Accuracy')
axes[0].set_xlabel('Accuracy')
sns.despine()
fig.tight_layout()

# %% [markdown]
# ## Textblob for Sentiment Analysis

# %%
sample_review = train.text.sample(1).iloc[0]
print(sample_review)
# Out:
# This spot is my go to for all alterations! They do a wonderful job with even complicated (multiple layers) bridesmaid dresses. All staff members are so friendly, and they do everything in a timely manner. I have started getting my dry cleaning done here as well, and don't have any complaints on that.

# %%
# Polarity ranges from -1 (most negative) to 1 (most positive).
TextBlob(sample_review).sentiment.polarity
# Out:
# 0.16166666666666668

# %%
# Define a function that accepts text and returns the polarity.
def detect_sentiment(text):
    return TextBlob(text).sentiment.polarity

# %%
train['sentiment'] = train.text.apply(detect_sentiment)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 train['sentiment'] = train.text.apply(detect_sentiment)
#
# File c:\Users\paxto\miniforge3\envs\ml4t\lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File c:\Users\paxto\miniforge3\envs\ml4t\lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\paxto\miniforge3\envs\ml4t\lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\paxto\miniforge3\envs\ml4t\lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\paxto\miniforge3\envs\ml4t\lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[72], line 3, in detect_sentiment(text)
#       2 def detect_sentiment(text):
# ----> 3     return TextBlob(text).sentiment.polarity
#
# File c:\Users\paxto\miniforge3\envs\ml4t\lib\site-packages\textblob\decorators.py:24, in cached_property.__get__(self, obj, cls)
#      22 if obj is None:
#      23     return self
# ---> 24 value = obj.__dict__[self.func.__name__] = self.func(obj)
#      25 return value
#
# File c:\Users\paxto\miniforge3\envs\ml4t\lib\site-packages\textblob\blob.py:432, in BaseBlob.sentiment(self)
#     423 @cached_property
#     424 def sentiment(self):
#     425     """Return a tuple of form (polarity, subjectivity ) where polarity
#     426     is a float within the range [-1.0, 1.0] and subjectivity is a float
#     427     within the range [0.0, 1.0] where 0.0 is very objective and 1.0 is
#    (...)
#     430     :rtype: namedtuple of the form ``Sentiment(polarity, subjectivity)``
#     431     """
# --> 432     return self.analyzer.analyze(self.raw)
#
# File c:\Users\paxto\miniforge3\envs\ml4t\lib\site-packages\textblob\en\sentiments.py:44, in PatternAnalyzer.analyze(self, text, keep_assessments)
#      42 else:
#      43     Sentiment = namedtuple('Sentiment', ['polarity', 'subjectivity'])
# ---> 44     return Sentiment(*pattern_sentiment(text))
#
# File c:\Users\paxto\miniforge3\envs\ml4t\lib\site-packages\textblob\_text.py:823, in Sentiment.__call__(self, s, negation, **kwargs)
#     820 # A string of words.
#     821 # Sentiment("a horrible movie") => (-0.6, 1.0)
#     822 elif isinstance(s, basestring):
# --> 823     a = self.assessments(((w.lower(), None) for w in " ".join(self.tokenizer(s)).split()), negation)
#     824 # A pattern.en.Text.
#     825 elif hasattr(s, "sentences"):
#
# File c:\Users\paxto\miniforge3\envs\ml4t\lib\site-packages\textblob\_text.py:1173, in Parser.find_tokens(self, string, **kwargs)
#    1169 """ Returns a list of sentences from the given string.
#    1170     Punctuation marks are separated from each word by a space.
#    1171 """
#    1172 # "The cat purs." => ["The cat purs ."]
# -> 1173 return find_tokens(text_type(string),
#    1174         punctuation = kwargs.get(  "punctuation", PUNCTUATION),
#    1175       abbreviations = kwargs.get("abbreviations", ABBREVIATIONS),
#    1176             replace = kwargs.get(      "replace", replacements),
#    1177           linebreak = r"\n{2,}")
#
# File c:\Users\paxto\miniforge3\envs\ml4t\lib\site-packages\textblob\_text.py:288, in find_tokens(string, punctuation, abbreviations, replace, linebreak)
#     286     if t.startswith(punctuation):
#     287         tokens.append(t[0]); t=t[1:]
# --> 288 while t.endswith(punctuation+(".",)) and \
#     289   not t in replace:
#     290     # Split trailing punctuation.
#     291     if t.endswith(punctuation):
#     292         tail.append(t[-1]); t=t[:-1]
#
# KeyboardInterrupt:

# %%
sample_reviews = train[['stars', 'text']].sample(100000)

# %%
# Create a new DataFrame column for sentiment (Warning: SLOW!).
sample_reviews['sentiment'] = sample_reviews.text.apply(detect_sentiment)

# %%
# Box plot of sentiment grouped by stars
sns.boxenplot(x='stars', y='sentiment', data=train);

# %%
# Widen the column display.
pd.set_option('max_colwidth', 500)

# %%
# Reviews with most negative sentiment
train[train.sentiment == -1].text.head()
# Out:
# 2495072                                                  TERRIBLE!! I Ordered And They Just Cancelled My Order Because they "don't deliver to my hotel" no notice or anything just cancelled!!! I Was Waiting For My\nOrder for about an hour!
# 4807229                                                                                                              Don't bother to give them a call they did a no show for an estimate not even a phone call to let me know horrible service
# 4379860                                                                                                      horrible, horrible, horrible.  food, service price.  it's an overpriced tourist trap.  Pease do yourself a favor, go to in n out.
# 2941002                                                                                                           Well after my miserable experience they came with the rest of my furniture today. All broken and cracked! Dump!!!!!!!!!!!!!!
# 2785241    This is probably the worst experience I have had at a restaurant.  Waited 10 minutes for even a server to come take my drink order.  Paid $15 for a crappy breakfast.  \n\nI will never eat at this California pizza kitchen again.
# Name: text, dtype: object

# %%
# Negative sentiment in a 5-star review
train.loc[(train.stars == 5) & (train.sentiment < -0.3), 'text'].head(1)
# Out:
# 255057    Appointment set through Fidelity Home Warranty. Ken came out within a couple of hours. The capacitor was bad on one of my units and replaced immediately. Thank you Fidelity and Ken at Lee Collins Air.
# Name: text, dtype: object

# %%
# Positive sentiment in a 1-star review
train.loc[(train.stars == 1) & (train.sentiment > 0.5), 'text'].head(1)
# Out:
# 5373197    The food wasn't that great and the service was okay. We should have just gone to our go to spot Baby Stacks. The steak and eggs had no flavor and the potatoes were room temperature. I guess this is what happens when you want breakfast for dinner. The bill was $46 which is fine but if the food was actually good I don't think I would be as ann
# Name: text, dtype: object

# %%
# Reset the column display width.
pd.reset_option('max_colwidth')
