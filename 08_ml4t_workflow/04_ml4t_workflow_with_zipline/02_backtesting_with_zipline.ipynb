# %% [markdown]
# # Backtesting with zipline - Pipeline API with Custom Data

# %% [markdown]
# The [Pipeline API](https://www.quantopian.com/docs/user-guide/tools/pipeline) facilitates the definition and computation of alpha factors for a cross-section of securities from historical data. The Pipeline significantly improves efficiency because it optimizes computations over the entire backtest period rather than tackling each event separately. In other words, it continues to follow an event-driven architecture but vectorizes the computation of factors where possible.
#
# A Pipeline uses Factors, Filters, and Classifiers classes to define computations that produce columns in a table with PIT values for a set of securities. Factors take one or more input arrays of historical bar data and produce one or more outputs for each security. There are numerous built-in factors, and you can also design your own `CustomFactor` computations.
#
# The following figure depicts how loading the data using the `DataFrameLoader`, computing the predictive `MLSignal` using the Pipeline API, and various scheduled activities integrate with the overall trading algorithm executed via the `run_algorithm()` function. We go over the details and the corresponding code in this section.
#
# ![The Pipeline Workflow](../../assets/zip_pipe_flow.png)
#
# You need to register your Pipeline with the `initialize()` method and can then execute it at each time step or on a custom schedule. Zipline provides numerous built-in computations such as moving averages or Bollinger Bands that can be used to quickly compute standard factors, but it also allows for the creation of custom factors as we will illustrate next.
#
# Most importantly, the Pipeline API renders alpha factor research modular because it separates the alpha factor computation from the remainder of the algorithm, including the placement and execution of trade orders and the bookkeeping of portfolio holdings, values, and so on.

# %% [markdown]
# The goal is to combine the daily return predictions with the OHCLV data from our Quandl bundle and then to go long on up to 10 equities with the highest predicted returns and short on those with the lowest predicted returns, requiring at least five stocks on either side similar to the backtrader example above. See comments in the notebook for implementation details.

# %% [markdown]
# ## Imports & Settings

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from collections import defaultdict
from time import time

import numpy as np
import pandas as pd
import pandas_datareader.data as web
from logbook import Logger, StderrHandler, INFO

import matplotlib.pyplot as plt
import seaborn as sns

from zipline import run_algorithm
from zipline.api import (attach_pipeline,
                         pipeline_output,
                         date_rules,
                         time_rules,
                         record,
                         schedule_function,
                         commission,
                         slippage,
                         set_slippage,
                         set_commission,
                         order_target,
                         order_target_percent)
from zipline.data import bundles
from zipline.utils.run_algo import load_extensions
from zipline.pipeline import Pipeline, CustomFactor
from zipline.pipeline.data import Column, DataSet
from zipline.pipeline.domain import US_EQUITIES
from zipline.pipeline.filters import StaticAssets
from zipline.pipeline.loaders.frame import DataFrameLoader

import pyfolio as pf
from pyfolio.plotting import plot_rolling_returns, plot_rolling_sharpe
from pyfolio.timeseries import forecast_cone_bootstrap

# %%
sns.set_style('whitegrid')
pd.set_option('display.expand_frame_repr', False)
np.random.seed(42)

# %% [markdown]
# ### Load zipline extensions

# %% [markdown]
# Only need this in notebook to find bundle.

# %%
load_extensions(default=True,
                extensions=[],
                strict=True,
                environ=None)

# %%
log_handler = StderrHandler(format_string='[{record.time:%Y-%m-%d %H:%M:%S.%f}]: ' +
                            '{record.level_name}: {record.func_name}: {record.message}',
                            level=INFO)
log_handler.push_application()
log = Logger('Algorithm')

# %% [markdown]
# ## Algo Params

# %% [markdown]
# We plan to hold up to 20 long and 20 short positions whenever there are at least 10 on either side that meet the criteria (positive/negative prediction for long/short position).

# %%
N_LONGS = 20
N_SHORTS = 20
MIN_POSITIONS = 10

# %% [markdown]
# ## Load Data

# %% [markdown]
# ### Quandl Wiki Bundle

# %% [markdown]
# Load the Wiki Quandl `bundle` data that we ingested earlier using `zipline ingest`. This gives us access to the security SID values, among other things.

# %%
bundle_data = bundles.load('quandl')

# %% [markdown]
# ### ML Predictions

# %% [markdown]
# We load our predictions for the 2015-17 period and extract the Zipline IDs for the ~250 stocks in our universe during this period using the `bundle.asset_finder.lookup_symbols()` method:

# %%
def load_predictions(bundle):
    predictions = pd.read_hdf('../00_data/backtest.h5', 'data')[['predicted']].dropna()
    tickers = predictions.index.get_level_values(0).unique().tolist()

    assets = bundle.asset_finder.lookup_symbols(tickers, as_of_date=None)
    predicted_sids = pd.Index([asset.sid for asset in assets])
    ticker_map = dict(zip(tickers, predicted_sids))
    return (predictions
            .unstack('ticker')
            .rename(columns=ticker_map)
            .predicted
            .tz_localize(None)), assets

# %%
predictions, assets = load_predictions(bundle_data)

# %% [markdown]
# ### Define Custom Dataset

# %% [markdown]
# To merge additional columns with our bundle, we define a custom `SignalData` class that inherits from `zipline.pipeline.DataSset` and contains a single `zipline.pipeline.Column` of type `float` and has the domain `US_EQUITIES`:

# %%
class SignalData(DataSet):
    predictions = Column(dtype=float)
    domain = US_EQUITIES

# %% [markdown]
# ### Define Pipeline Loaders

# %% [markdown]
# While the bundle’s OHLCV data can rely on the built-in `USEquityPricingLoader`, we need to define our own `zipline.pipeline.loaders.frame.DataFrameLoader`:

# %%
signal_loader = {SignalData.predictions: DataFrameLoader(SignalData.predictions, 
                                                         predictions)}

# %% [markdown]
# In fact, we need to slightly modify the Zipline library’s source code to bypass the assumption that we will only load price data. To this end, we will add a `custom_loader` parameter to the `run_algorithm` and ensure that this loader is used when the `Pipeline` needs one of `SignalData`’s `Column` instances.

# %% [markdown]
# ## Pipeline Setup

# %% [markdown]
# Our Pipeline is going to have two Boolean columns that identify the assets we would like to trade as long and short positions.
#
# To get there, we first define a `CustomFactor` called `MLSignal` that just receives the current `SignalData.predictions`. The motivation is to allow us to use some of the convenient `Factor` methods designed to rank and filter securities.

# %% [markdown]
# ### Custom ML Factor

# %%
class MLSignal(CustomFactor):
    """Converting signals to Factor
        so we can rank and filter in Pipeline"""
    inputs = [SignalData.predictions]
    window_length = 1

    def compute(self, today, assets, out, preds):
        print(preds)
        out[:] = preds

# %% [markdown]
# ### Create Pipeline

# %% [markdown]
# Now we create a `compute_signals()` that returns a `zipline.pipeline.Pipeline` which filters the assets that meet our long/short criteria. We will call ths function periodically while executing the backtest.

# %% [markdown]
# More specifically, we set up our Pipeline by instantiating the `CustomFactor` that requires no arguments other than the defaults. We combine its `top()` and `bottom()` methods with a filter to select the highest positive and lowest negative predictions:

# %%
def compute_signals():
    signals = MLSignal()
#     predictions = SignalData.predictions.latest
    return Pipeline(columns={
        'longs' : signals.top(N_LONGS, mask=signals > 0),
        'shorts': signals.bottom(N_SHORTS, mask=signals < 0)},
            screen=StaticAssets(assets)
    )

# %% [markdown]
# ## Initialize Algorithm

# %% [markdown]
# The `initialize()` function is part of the Algorithm API. It permits us to add entries to the `context` dictionary available to all backtest components, set parameters like commission and slippage, and schedule functions. We also attach our Pipeline to the algorithm:

# %%
def initialize(context):
    """
    Called once at the start of the algorithm.
    """
    context.n_longs = N_LONGS
    context.n_shorts = N_SHORTS
    context.min_positions = MIN_POSITIONS
    context.universe = assets

    set_slippage(slippage.FixedSlippage(spread=0.00))
    set_commission(commission.PerShare(cost=0, min_trade_cost=0))

    schedule_function(rebalance,
                      date_rules.every_day(),
                      time_rules.market_open(hours=1, minutes=30))

    schedule_function(record_vars,
                      date_rules.every_day(),
                      time_rules.market_close())

    pipeline = compute_signals()
    attach_pipeline(pipeline, 'signals')

# %% [markdown]
# ### Get daily Pipeline results

# %% [markdown]
# The algorithm calls the `before_trading_start()` function every day before market opens and we use it to obtain the current pipeline values, i.e., the assets suggested for long and short positions based on the ML model predictions:

# %%
def before_trading_start(context, data):
    """
    Called every day before market open.
    """
    output = pipeline_output('signals')
    context.trades = (pd.concat([output['longs'].astype(int)
                      ,output['shorts'].astype(int).mul(-1)])
                      .reset_index()
                      .drop_duplicates()
                      .set_index('index')
                      .squeeze())

# %% [markdown]
# ## Define Rebalancing Logic

# %% [markdown]
# The `rebalance()` function takes care of adjusting the portfolio positions to reflect the target long and short positions implied by the model forecasets:

# %%
def rebalance(context, data):
    """
    Execute orders according to schedule_function() date & time rules.
    """
    trades = defaultdict(list)

    for stock, trade in context.trades.items():
        if not trade:
            order_target(stock, 0)
        else:
            trades[trade].append(stock)
    context.longs, context.shorts = len(trades[1]), len(trades[-1])
    if context.longs > context.min_positions and context.shorts > context.min_positions:
        for stock in trades[-1]:
            order_target_percent(stock, -1 / context.shorts)
        for stock in trades[1]:
            order_target_percent(stock, 1 / context.longs)

# %% [markdown]
# ## Record Data Points

# %% [markdown]
# The `record_vars()` logs information to the `pd.DataFrame` returned by `run_algorithm()` as scheduled.

# %%
def record_vars(context, data):
    """
    Plot variables at the end of each day.
    """
    record(leverage=context.account.leverage,
           longs=context.longs,
           shorts=context.shorts)

# %% [markdown]
# ## Run Algorithm

# %% [markdown]
# At this point, we have defined all ingredients for the algorithm and are ready to call `run_algorithm()` with the desired `start` and `end` dates, references to the various functions we just created, and the `custom_loader` to ensure our model predictions are available to the backtest.

# %%
dates = predictions.index.get_level_values('date')
start_date = dates.min()
end_date = (dates.max() + pd.DateOffset(1))

# %%
start_date = start_date.tz_localize(None)
end_date = end_date.tz_localize(None)

# %%
start_date
# Out:
# Timestamp('2014-12-09 00:00:00')

# %%
start = time()
results = run_algorithm(start=start_date,
                       end=end_date,
                       initialize=initialize,
                       before_trading_start=before_trading_start,
                       capital_base=1e6,
                       data_frequency='daily',
                       bundle='quandl',
                       custom_loader=signal_loader) # need to modify zipline

print('Duration: {:.2f}s'.format(time() - start))
# Out:
# [[       nan 0.00173173        nan ...        nan        nan        nan]]
# [[       nan 0.00061054        nan ...        nan        nan        nan]]
# [[       nan 0.00028235        nan ...        nan        nan        nan]]
# [[       nan 0.00378141        nan ...        nan        nan        nan]]
# [[      nan 0.0026234       nan ...       nan       nan       nan]]
# [[       nan 0.00277414        nan ...        nan        nan        nan]]
# [[       nan 0.00179216        nan ...        nan        nan        nan]]
# [[       nan 0.00448186        nan ...        nan        nan        nan]]
# [[       nan 0.00581241        nan ...        nan        nan        nan]]
# [[       nan 0.00597297        nan ...        nan        nan        nan]]
# [[       nan 0.00479481        nan ...        nan        nan        nan]]
# [[       nan 0.00504734        nan ...        nan        nan        nan]]
# [[       nan 0.00451026        nan ...        nan        nan        nan]]
# [[       nan 0.00549562        nan ...        nan        nan        nan]]
# [[       nan 0.00560031        nan ...        nan        nan        nan]]
# [[      nan 0.0067037       nan ...       nan       nan       nan]]
# [[       nan 0.00484476        nan ...        nan        nan        nan]]
# [[       nan 0.00399022        nan ...        nan        nan        nan]]
# [[       nan 0.00427992        nan ...        nan        nan        nan]]
# [[       nan 0.00511824        nan ...        nan        nan        nan]]
# [[       nan 0.00673979        nan ...        nan        nan        nan]]
# [[       nan 0.00425246        nan ...        nan        nan        nan]]
# [[       nan 0.00383142        nan ...        nan        nan        nan]]
# [[       nan 0.00804249        nan ...        nan        nan        nan]]
# [[       nan 0.00624188        nan ...        nan        nan        nan]]
# [[       nan 0.00781403        nan ...        nan        nan        nan]]
# [[       nan 0.00739754        nan ...        nan        nan        nan]]
# [[       nan 0.00947666        nan ...        nan        nan        nan]]
# [[       nan 0.00740482        nan ...        nan        nan        nan]]
# [[       nan 0.00690569        nan ...        nan        nan        nan]]
# [[       nan 0.00175459        nan ...        nan        nan        nan]]
# [[       nan 0.00293404        nan ...        nan        nan        nan]]
# [[       nan 0.00254641        nan ...        nan        nan        nan]]
# [[       nan 0.00355316        nan ...        nan        nan        nan]]
# [[    nan 0.00748     nan ...     nan     nan     nan]]
# [[       nan 0.00258801        nan ...        nan        nan        nan]]
# [[       nan 0.00731898        nan ...        nan        nan        nan]]
# [[       nan 0.00489655        nan ...        nan        nan        nan]]
# [[      nan 0.0071668       nan ...       nan       nan       nan]]
# [[       nan 0.00312517        nan ...        nan        nan        nan]]
# [[       nan 0.00321281        nan ...        nan        nan        nan]]
# [[       nan 0.00226387        nan ...        nan        nan        nan]]
# [[       nan 0.01114064        nan ...        nan        nan        nan]]
# [[       nan 0.00974086        nan ...        nan        nan        nan]]
# [[       nan 0.00870225        nan ...        nan        nan        nan]]
# [[      nan 0.0122622       nan ...       nan       nan       nan]]
# [[       nan 0.01063872        nan ...        nan        nan        nan]]
# [[     nan 0.014611      nan ...      nan      nan      nan]]
# [[       nan 0.00885302        nan ...        nan        nan        nan]]
# [[       nan 0.00791501        nan ...        nan        nan        nan]]
# [[     nan 0.002787      nan ...      nan      nan      nan]]
# [[       nan 0.00311225        nan ...        nan        nan        nan]]
# [[        nan -0.00179597         nan ...         nan         nan
#           nan]]
# [[       nan 0.00246362        nan ...        nan        nan        nan]]
# [[      nan 0.0010037       nan ...       nan       nan       nan]]
# [[        nan -0.00223064         nan ...         nan         nan
#           nan]]
# [[        nan -0.00153467         nan ...         nan         nan
#           nan]]
# [[        nan -0.00341871         nan ...         nan         nan
#           nan]]
# [[        nan -0.00461565         nan ...         nan         nan
#           nan]]
# [[        nan -0.00564621         nan ...         nan         nan
#           nan]]
# [[        nan -0.00590099         nan ...         nan         nan
#           nan]]
# [[        nan -0.00639231         nan ...         nan         nan
#           nan]]
# [[        nan -0.00183458         nan ...         nan         nan
#           nan]]
# [[        nan -0.00170434         nan ...         nan         nan
#           nan]]
# [[        nan -0.00092016         nan ...         nan         nan
#           nan]]
# [[        nan -0.00209402         nan ...         nan         nan
#           nan]]
# [[        nan -0.00099666         nan ...         nan         nan
#           nan]]
# [[        nan -0.00565029         nan ...         nan         nan
#           nan]]
# [[        nan -0.00498442         nan ...         nan         nan
#           nan]]
# [[        nan -0.00580222         nan ...         nan         nan
#           nan]]
# [[        nan -0.00509162         nan ...         nan         nan
#           nan]]
# [[       nan -0.0056683        nan ...        nan        nan        nan]]
# [[        nan -0.00537103         nan ...         nan         nan
#           nan]]
# [[        nan -0.00488161         nan ...         nan         nan
#           nan]]
# [[        nan -0.00482062         nan ...         nan         nan
#           nan]]
# [[        nan -0.00379627         nan ...         nan         nan
#           nan]]
# [[       nan -0.0063845        nan ...        nan        nan        nan]]
# [[        nan -0.00349969         nan ...         nan         nan
#           nan]]
# [[        nan -0.00232186         nan ...         nan         nan
#           nan]]
# [[        nan -0.00202419         nan ...         nan         nan
#           nan]]
# [[       nan 0.00135894        nan ...        nan        nan        nan]]
# [[       nan 0.00250695        nan ...        nan        nan        nan]]
# [[       nan 0.00576315        nan ...        nan        nan        nan]]
# [[       nan 0.00728334        nan ...        nan        nan        nan]]
# [[       nan 0.00562341        nan ...        nan        nan        nan]]
# [[       nan 0.00443024        nan ...        nan        nan        nan]]
# [[       nan 0.00397232        nan ...        nan        nan        nan]]
# [[       nan 0.00525983        nan ...        nan        nan        nan]]
# [[       nan 0.00577798        nan ...        nan        nan        nan]]
# [[       nan 0.00525605        nan ...        nan        nan        nan]]
# [[       nan 0.00040856        nan ...        nan        nan        nan]]
# [[        nan -0.00112728         nan ...         nan         nan
#           nan]]
# [[        nan -0.00060756         nan ...         nan         nan
#           nan]]
# [[        nan -0.00101936         nan ...         nan         nan
#           nan]]
# [[        nan -0.00077991         nan ...         nan         nan
#           nan]]
# [[        nan -0.00078895         nan ...         nan         nan
#           nan]]
# [[           nan 1.44275036e-05            nan ...            nan
#              nan            nan]]
# [[        nan -0.00017322         nan ...         nan         nan
#           nan]]
# [[        nan -0.00369236         nan ...         nan         nan
#           nan]]
# [[        nan -0.00389022         nan ...         nan         nan
#           nan]]
# [[        nan -0.00636916         nan ...         nan         nan
#           nan]]
# [[        nan -0.00644285         nan ...         nan         nan
#           nan]]
# [[        nan -0.00946977         nan ...         nan         nan
#           nan]]
# [[        nan -0.00942928         nan ...         nan         nan
#           nan]]
# [[        nan -0.00876266         nan ...         nan         nan
#           nan]]
# [[        nan -0.00528621         nan ...         nan         nan
#           nan]]
# [[        nan -0.00303883         nan ...         nan         nan
#           nan]]
# [[        nan -0.00435062         nan ...         nan         nan
#           nan]]
# [[        nan -0.00448549         nan ...         nan         nan
#           nan]]
# [[        nan -0.00486838         nan ...         nan         nan
#           nan]]
# [[       nan 0.00273122        nan ...        nan        nan        nan]]
# [[       nan 0.00480055        nan ...        nan        nan        nan]]
# [[       nan 0.00162957        nan ...        nan        nan        nan]]
# [[       nan 0.00081064        nan ...        nan        nan        nan]]
# [[       nan 0.00022401        nan ...        nan        nan        nan]]
# [[        nan -0.00022719         nan ...         nan         nan
#           nan]]
# [[     nan 0.003022      nan ...      nan      nan      nan]]
# [[       nan 0.00323026        nan ...        nan        nan        nan]]
# [[       nan 0.00291848        nan ...        nan        nan        nan]]
# [[       nan 0.00387208        nan ...        nan        nan        nan]]
# [[       nan 0.00093473        nan ...        nan        nan        nan]]
# [[       nan 0.00278946        nan ...        nan        nan        nan]]
# [[      nan 0.0025008       nan ...       nan       nan       nan]]
# [[       nan 0.00143268        nan ...        nan        nan        nan]]
# [[       nan 0.00032687        nan ...        nan        nan        nan]]
# [[            nan -9.88660525e-05             nan ...             nan
#               nan             nan]]
# [[       nan 0.00041036        nan ...        nan        nan        nan]]
# [[        nan -0.00078628         nan ...         nan         nan
#           nan]]
# [[            nan -7.16087228e-05             nan ...             nan
#               nan             nan]]
# [[        nan -0.00092429         nan ...         nan         nan
#           nan]]
# [[        nan -0.00361573         nan ...         nan         nan
#           nan]]
# [[       nan -0.0036088        nan ...        nan        nan        nan]]
# [[        nan -0.00382154         nan ...         nan         nan
#           nan]]
# [[        nan -0.00483724         nan ...         nan         nan
#           nan]]
# [[        nan -0.00518797         nan ...         nan         nan
#           nan]]
# [[        nan -0.00428834         nan ...         nan         nan
#           nan]]
# [[        nan -0.00420381         nan ...         nan         nan
#           nan]]
# [[        nan -0.00389571         nan ...         nan         nan
#           nan]]
# [[        nan -0.00343523         nan ...         nan         nan
#           nan]]
# [[        nan -0.00325123         nan ...         nan         nan
#           nan]]
# [[       nan -0.0009908        nan ...        nan        nan        nan]]
# [[       nan -0.0004717        nan ...        nan        nan        nan]]
# [[        nan -0.00029461         nan ...         nan         nan
#           nan]]
# [[        nan -0.00112461         nan ...         nan         nan
#           nan]]
# [[        nan -0.00134434         nan ...         nan         nan
#           nan]]
# [[        nan -0.00166596         nan ...         nan         nan
#           nan]]
# [[        nan -0.00203476         nan ...         nan         nan
#           nan]]
# [[        nan -0.00228924         nan ...         nan         nan
#           nan]]
# [[        nan -0.00254638         nan ...         nan         nan
#           nan]]
# [[        nan -0.00308002         nan ...         nan         nan
#           nan]]
# [[        nan -0.00043035         nan ...         nan         nan
#           nan]]
# [[           nan 5.02142774e-05            nan ...            nan
#              nan            nan]]
# [[       nan 0.00091591        nan ...        nan        nan        nan]]
# [[       nan 0.00054512        nan ...        nan        nan        nan]]
# [[            nan -1.94291552e-05             nan ...             nan
#               nan             nan]]
# [[        nan -0.00077403         nan ...         nan         nan
#           nan]]
# [[      nan 0.0008343       nan ...       nan       nan       nan]]
# [[        nan -0.00013298         nan ...         nan         nan
#           nan]]
# [[        nan -0.00028246         nan ...         nan         nan
#           nan]]
# [[       nan 0.00063331        nan ...        nan        nan        nan]]
# [[        nan -0.00118534         nan ...         nan         nan
#           nan]]
# [[        nan -0.00065861         nan ...         nan         nan
#           nan]]
# [[        nan -0.00200548         nan ...         nan         nan
#           nan]]
# [[        nan -0.00220573         nan ...         nan         nan
#           nan]]
# [[        nan -0.00243708         nan ...         nan         nan
#           nan]]
# [[        nan -0.00130842         nan ...         nan         nan
#           nan]]
# [[        nan -0.00251854         nan ...         nan         nan
#           nan]]
# [[        nan -0.00281033         nan ...         nan         nan
#           nan]]
# [[        nan -0.00292177         nan ...         nan         nan
#           nan]]
# [[        nan -0.00323808         nan ...         nan         nan
#           nan]]
# [[        nan -0.00197772         nan ...         nan         nan
#           nan]]
# [[        nan -0.00216692         nan ...         nan         nan
#           nan]]
# [[        nan -0.00190891         nan ...         nan         nan
#           nan]]
# [[           nan 4.54324715e-05            nan ...            nan
#              nan            nan]]
# [[        nan -0.00041919         nan ...         nan         nan
#           nan]]
# [[       nan -0.0005225        nan ...        nan        nan        nan]]
# [[        nan -0.00089846         nan ...         nan         nan
#           nan]]
# [[       nan 0.00042526        nan ...        nan        nan        nan]]
# [[        nan -0.00017667         nan ...         nan         nan
#           nan]]
# [[        nan -0.00108577         nan ...         nan         nan
#           nan]]
# [[       nan 0.00338287        nan ...        nan        nan        nan]]
# [[        nan -0.00109089         nan ...         nan         nan
#           nan]]
# [[       nan -0.0015609        nan ...        nan        nan        nan]]
# [[         nan 2.520685e-05          nan ...          nan          nan
#            nan]]
# [[       nan 0.00640274        nan ...        nan        nan        nan]]
# [[        nan -0.00542683         nan ...         nan         nan
#           nan]]
# [[        nan -0.00543533         nan ...         nan         nan
#           nan]]
# [[        nan -0.00386852         nan ...         nan         nan
#           nan]]
# [[        nan -0.00476527         nan ...         nan         nan
#           nan]]
# [[        nan -0.00241188         nan ...         nan         nan
#           nan]]
# [[       nan 0.00135502        nan ...        nan        nan        nan]]
# [[        nan -0.00216104         nan ...         nan         nan
#           nan]]
# [[        nan -0.00259146         nan ...         nan         nan
#           nan]]
# [[        nan -0.00422957         nan ...         nan         nan
#           nan]]
# [[        nan -0.00290929         nan ...         nan         nan
#           nan]]
# [[        nan -0.00439489         nan ...         nan         nan
#           nan]]
# [[        nan -0.00078188         nan ...         nan         nan
#           nan]]
# [[       nan 0.00023035        nan ...        nan        nan        nan]]
# [[      nan 0.0104899       nan ...       nan       nan       nan]]
# [[       nan 0.01087181        nan ...        nan        nan        nan]]
# [[      nan 0.0082848       nan ...       nan       nan       nan]]
# [[       nan 0.00642829        nan ...        nan        nan        nan]]
# [[       nan 0.00859267        nan ...        nan        nan        nan]]
# [[       nan 0.00780807        nan ...        nan        nan        nan]]
# [[       nan 0.00933402        nan ...        nan        nan        nan]]
# [[       nan 0.00490282        nan ...        nan        nan        nan]]
# [[       nan 0.00905753        nan ...        nan        nan        nan]]
# [[       nan 0.00074045        nan ...        nan        nan        nan]]
# [[       nan 0.00888215        nan ...        nan        nan        nan]]
# [[       nan 0.00567373        nan ...        nan        nan        nan]]
# [[       nan 0.01557069        nan ...        nan        nan        nan]]
# [[       nan 0.00887848        nan ...        nan        nan        nan]]
# [[       nan 0.00117569        nan ...        nan        nan        nan]]
# [[       nan 0.00377649        nan ...        nan        nan        nan]]
# [[       nan 0.00332403        nan ...        nan        nan        nan]]
# [[       nan 0.00155441        nan ...        nan        nan        nan]]
# [[      nan 0.0072813       nan ...       nan       nan       nan]]
# [[       nan 0.00544448        nan ...        nan        nan        nan]]
# [[       nan 0.00640247        nan ...        nan        nan        nan]]
# [[       nan 0.01258302        nan ...        nan        nan        nan]]
# [[       nan 0.00144609        nan ...        nan        nan        nan]]
# [[       nan 0.00540235        nan ...        nan        nan        nan]]
# [[       nan 0.00340674        nan ...        nan        nan        nan]]
# [[       nan 0.00304708        nan ...        nan        nan        nan]]
# [[       nan 0.00714135        nan ...        nan        nan        nan]]
# [[       nan 0.00807092        nan ...        nan        nan        nan]]
# [[           nan 3.62213039e-05            nan ...            nan
#              nan            nan]]
# [[        nan -0.00012836         nan ...         nan         nan
#           nan]]
# [[        nan -0.00112491         nan ...         nan         nan
#           nan]]
# [[       nan 0.00283562        nan ...        nan        nan        nan]]
# [[       nan 0.00181496        nan ...        nan        nan        nan]]
# [[       nan 0.00120206        nan ...        nan        nan        nan]]
# [[       nan 0.00311701        nan ...        nan        nan        nan]]
# [[       nan 0.00325795        nan ...        nan        nan        nan]]
# [[       nan 0.00249168        nan ...        nan        nan        nan]]
# [[       nan 0.00339152        nan ...        nan        nan        nan]]
# [[       nan 0.00346518        nan ...        nan        nan        nan]]
# [[       nan 0.00449191        nan ...        nan        nan        nan]]
# [[       nan 0.00483836        nan ...        nan        nan        nan]]
# [[       nan 0.00785121        nan ...        nan        nan        nan]]
# [[       nan 0.00341885        nan ...        nan        nan        nan]]
# [[       nan 0.00307626        nan ...        nan        nan        nan]]
# [[       nan 0.00180741        nan ...        nan        nan        nan]]
# [[       nan 0.00445948        nan ...        nan        nan        nan]]
# [[       nan 0.00353969        nan ...        nan        nan        nan]]
# [[      nan 0.0017675       nan ...       nan       nan       nan]]
# [[       nan 0.00221851        nan ...        nan        nan        nan]]
# [[        nan -0.00503963         nan ...         nan         nan
#           nan]]
# [[        nan -0.00634448         nan ...         nan         nan
#           nan]]
# [[        nan -0.00437532         nan ...         nan         nan
#           nan]]
# [[        nan -0.00651311         nan ...         nan         nan
#           nan]]
# [[        nan -0.00753532         nan ...         nan         nan
#           nan]]
# [[        nan -0.00670014         nan ...         nan         nan
#           nan]]
# [[        nan -0.00532692         nan ...         nan         nan
#           nan]]
# [[       nan -0.0064578        nan ...        nan        nan        nan]]
# [[        nan -0.00473416         nan ...         nan         nan
#           nan]]
# [[       nan -0.0027198        nan ...        nan        nan        nan]]
# [[        nan -0.00314351         nan ...         nan         nan
#           nan]]
# [[        nan -0.00437522         nan ...         nan         nan
#           nan]]
# [[        nan -0.00230621         nan ...         nan         nan
#           nan]]
# [[       nan 0.00051747        nan ...        nan        nan        nan]]
# [[        nan -0.00198433         nan ...         nan         nan
#           nan]]
# [[       nan -0.0032674        nan ...        nan        nan        nan]]
# [[        nan -0.00308008         nan ...         nan         nan
#           nan]]
# [[        nan -0.00577851         nan ...         nan         nan
#           nan]]
# [[        nan -0.00486885         nan ...         nan         nan
#           nan]]
# [[        nan -0.00427309         nan ...         nan         nan
#           nan]]
# [[        nan -0.00351989         nan ...         nan         nan
#           nan]]
# [[        nan -0.00810108         nan ...         nan         nan
#           nan]]
# [[        nan -0.00680229         nan ...         nan         nan
#           nan]]
# [[        nan -0.00563568         nan ...         nan         nan
#           nan]]
# [[        nan -0.00737453         nan ...         nan         nan
#           nan]]
# [[        nan -0.00567151         nan ...         nan         nan
#           nan]]
# [[        nan -0.00585931         nan ...         nan         nan
#           nan]]
# [[        nan -0.00798919         nan ...         nan         nan
#           nan]]
# [[        nan -0.00742984         nan ...         nan         nan
#           nan]]
# [[        nan -0.00518388         nan ...         nan         nan
#           nan]]
# [[        nan -0.00688829         nan ...         nan         nan
#           nan]]
# [[        nan -0.00535978         nan ...         nan         nan
#           nan]]
# [[        nan -0.00565728         nan ...         nan         nan
#           nan]]
# [[        nan -0.00887564         nan ...         nan         nan
#           nan]]
# [[        nan -0.01060203         nan ...         nan         nan
#           nan]]
# [[        nan -0.00954452         nan ...         nan         nan
#           nan]]
# [[        nan -0.01134093         nan ...         nan         nan
#           nan]]
# [[        nan -0.01073049         nan ...         nan         nan
#           nan]]
# [[        nan -0.00887666         nan ...         nan         nan
#           nan]]
# [[        nan -0.01091889         nan ...         nan         nan
#           nan]]
# [[        nan -0.01266817         nan ...         nan         nan
#           nan]]
# [[        nan -0.00864956         nan ...         nan         nan
#           nan]]
# [[        nan -0.00947468         nan ...         nan         nan
#           nan]]
# [[        nan -0.00475169         nan ...         nan         nan
#           nan]]
# [[        nan -0.00211715         nan ...         nan         nan
#           nan]]
# [[        nan -0.00285669         nan ...         nan         nan
#           nan]]
# [[        nan -0.00323815         nan ...         nan         nan
#           nan]]
# [[        nan -0.00652018         nan ...         nan         nan
#           nan]]
# [[        nan -0.00611197         nan ...         nan         nan
#           nan]]
# [[       nan -0.0071895        nan ...        nan        nan        nan]]
# [[        nan -0.00527568         nan ...         nan         nan
#           nan]]
# [[        nan -0.00608175         nan ...         nan         nan
#           nan]]
# [[        nan -0.00719603         nan ...         nan         nan
#           nan]]
# [[        nan -0.00408222         nan ...         nan         nan
#           nan]]
# [[        nan -0.00981494         nan ...         nan         nan
#           nan]]
# [[        nan -0.01084215         nan ...         nan         nan
#           nan]]
# [[        nan -0.01036983         nan ...         nan         nan
#           nan]]
# [[       nan -0.0110485        nan ...        nan        nan        nan]]
# [[        nan -0.01078846         nan ...         nan         nan
#           nan]]
# [[       nan -0.0096517        nan ...        nan        nan        nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[       nan 0.01114204        nan ...        nan        nan        nan]]
# [[      nan 0.0113008       nan ...       nan       nan       nan]]
# [[       nan 0.01119505        nan ...        nan        nan        nan]]
# [[       nan 0.00832601        nan ...        nan        nan        nan]]
# [[       nan 0.00957655        nan ...        nan        nan        nan]]
# [[       nan 0.01013604        nan ...        nan        nan        nan]]
# [[       nan 0.00697434        nan ...        nan        nan        nan]]
# [[nan nan nan ... nan nan nan]]
# [[        nan -0.00074704         nan ...         nan         nan
#           nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[      nan 0.0041511       nan ...       nan       nan       nan]]
# [[        nan -0.00040562         nan ...         nan         nan
#           nan]]
# [[            nan -2.09625984e-05             nan ...             nan
#               nan             nan]]
# [[       nan 0.00099688        nan ...        nan        nan        nan]]
# [[       nan 0.00157956        nan ...        nan        nan        nan]]
# [[        nan -0.00239131         nan ...         nan         nan
#           nan]]
# [[        nan -0.00563139         nan ...         nan         nan
#           nan]]
# [[        nan -0.00572023         nan ...         nan         nan
#           nan]]
# [[        nan -0.00760504         nan ...         nan         nan
#           nan]]
# [[        nan -0.00552192         nan ...         nan         nan
#           nan]]
# [[        nan -0.00840228         nan ...         nan         nan
#           nan]]
# [[        nan -0.00817664         nan ...         nan         nan
#           nan]]
# [[        nan -0.00867582         nan ...         nan         nan
#           nan]]
# [[        nan -0.00857329         nan ...         nan         nan
#           nan]]
# [[        nan -0.00886424         nan ...         nan         nan
#           nan]]
# [[        nan -0.00791901         nan ...         nan         nan
#           nan]]
# [[        nan -0.00079731         nan ...         nan         nan
#           nan]]
# [[        nan -0.00251029         nan ...         nan         nan
#           nan]]
# [[        nan -0.00204171         nan ...         nan         nan
#           nan]]
# [[       nan 0.00039902        nan ...        nan        nan        nan]]
# [[       nan 0.00250006        nan ...        nan        nan        nan]]
# [[       nan 0.00396297        nan ...        nan        nan        nan]]
# [[       nan 0.00350123        nan ...        nan        nan        nan]]
# [[     nan 0.003453      nan ...      nan      nan      nan]]
# [[       nan 0.00379754        nan ...        nan        nan        nan]]
# [[       nan 0.00518633        nan ...        nan        nan        nan]]
# [[        nan -0.00079527         nan ...         nan         nan
#           nan]]
# [[        nan -0.00087044         nan ...         nan         nan
#           nan]]
# [[        nan -0.00028759         nan ...         nan         nan
#           nan]]
# [[        nan -0.00024405         nan ...         nan         nan
#           nan]]
# [[       nan -0.0016603        nan ...        nan        nan        nan]]
# [[        nan -0.00213643         nan ...         nan         nan
#           nan]]
# [[        nan -0.00212309         nan ...         nan         nan
#           nan]]
# [[        nan -0.00357763         nan ...         nan         nan
#           nan]]
# [[       nan -0.0037644        nan ...        nan        nan        nan]]
# [[        nan -0.00345207         nan ...         nan         nan
#           nan]]
# [[        nan -0.00299111         nan ...         nan         nan
#           nan]]
# [[       nan -0.0023802        nan ...        nan        nan        nan]]
# [[        nan -0.00208852         nan ...         nan         nan
#           nan]]
# [[        nan -0.00263824         nan ...         nan         nan
#           nan]]
# [[        nan -0.00237887         nan ...         nan         nan
#           nan]]
# [[        nan -0.00161432         nan ...         nan         nan
#           nan]]
# [[        nan -0.00207301         nan ...         nan         nan
#           nan]]
# [[        nan -0.00118678         nan ...         nan         nan
#           nan]]
# [[        nan -0.00013509         nan ...         nan         nan
#           nan]]
# [[        nan -0.00091848         nan ...         nan         nan
#           nan]]
# [[       nan -0.0001929        nan ...        nan        nan        nan]]
# [[          nan 5.1349668e-05           nan ...           nan
#             nan           nan]]
# [[      nan 0.0005121       nan ...       nan       nan       nan]]
# [[      nan 0.0006626       nan ...       nan       nan       nan]]
# [[            nan -9.01310195e-05             nan ...             nan
#               nan             nan]]
# [[        nan -0.00079136         nan ...         nan         nan
#           nan]]
# [[        nan -0.00094608         nan ...         nan         nan
#           nan]]
# [[        nan -0.00186038         nan ...         nan         nan
#           nan]]
# [[        nan -0.00130103         nan ...         nan         nan
#           nan]]
# [[        nan -0.00092556         nan ...         nan         nan
#           nan]]
# [[        nan -0.00512534         nan ...         nan         nan
#           nan]]
# [[        nan -0.00515454         nan ...         nan         nan
#           nan]]
# [[        nan -0.00354366         nan ...         nan         nan
#           nan]]
# [[        nan -0.00288197         nan ...         nan         nan
#           nan]]
# [[       nan -0.0045965        nan ...        nan        nan        nan]]
# [[        nan -0.00686382         nan ...         nan         nan
#           nan]]
# [[        nan -0.00673363         nan ...         nan         nan
#           nan]]
# [[        nan -0.00860629         nan ...         nan         nan
#           nan]]
# [[        nan -0.00694725         nan ...         nan         nan
#           nan]]
# [[        nan -0.00556972         nan ...         nan         nan
#           nan]]
# [[        nan -0.00112712         nan ...         nan         nan
#           nan]]
# [[        nan -0.00302282         nan ...         nan         nan
#           nan]]
# [[        nan -0.00058829         nan ...         nan         nan
#           nan]]
# [[        nan -0.00100603         nan ...         nan         nan
#           nan]]
# [[        nan -0.00360211         nan ...         nan         nan
#           nan]]
# [[        nan -0.00267667         nan ...         nan         nan
#           nan]]
# [[        nan -0.00244614         nan ...         nan         nan
#           nan]]
# [[      nan -0.004178       nan ...       nan       nan       nan]]
# [[       nan 0.00391128        nan ...        nan        nan        nan]]
# [[       nan 0.00551227        nan ...        nan        nan        nan]]
# [[        nan -0.00083326         nan ...         nan         nan
#           nan]]
# [[        nan -0.00203545         nan ...         nan         nan
#           nan]]
# [[       nan -0.0042981        nan ...        nan        nan        nan]]
# [[        nan -0.00626164         nan ...         nan         nan
#           nan]]
# [[        nan -0.00199434         nan ...         nan         nan
#           nan]]
# [[        nan -0.00012814         nan ...         nan         nan
#           nan]]
# [[        nan -0.00072722         nan ...         nan         nan
#           nan]]
# [[       nan 0.00019992        nan ...        nan        nan        nan]]
# [[        nan -0.00313772         nan ...         nan         nan
#           nan]]
# [[        nan -0.01065692         nan ...         nan         nan
#           nan]]
# [[       nan -0.0149419        nan ...        nan        nan        nan]]
# [[        nan -0.01573142         nan ...         nan         nan
#           nan]]
# [[       nan -0.0128071        nan ...        nan        nan        nan]]
# [[        nan -0.01290637         nan ...         nan         nan
#           nan]]
# [[        nan -0.01017251         nan ...         nan         nan
#           nan]]
# [[        nan -0.00623519         nan ...         nan         nan
#           nan]]
# [[        nan -0.00350456         nan ...         nan         nan
#           nan]]
# [[        nan -0.00551026         nan ...         nan         nan
#           nan]]
# [[       nan -0.0040275        nan ...        nan        nan        nan]]
# [[        nan -0.00648815         nan ...         nan         nan
#           nan]]
# [[        nan -0.00295125         nan ...         nan         nan
#           nan]]
# [[      nan -0.002835       nan ...       nan       nan       nan]]
# [[        nan -0.00105998         nan ...         nan         nan
#           nan]]
# [[        nan -0.00168286         nan ...         nan         nan
#           nan]]
# [[       nan 0.00095075        nan ...        nan        nan        nan]]
# [[        nan -0.00091562         nan ...         nan         nan
#           nan]]
# [[          nan 5.4643546e-05           nan ...           nan
#             nan           nan]]
# [[       nan -0.0020953        nan ...        nan        nan        nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[        nan -0.00453436         nan ...         nan         nan
#           nan]]
# [[        nan -0.00461094         nan ...         nan         nan
#           nan]]
# [[        nan -0.00261866         nan ...         nan         nan
#           nan]]
# [[        nan -0.00254175         nan ...         nan         nan
#           nan]]
# [[nan nan nan ... nan nan nan]]
# [[        nan -0.00251101         nan ...         nan         nan
#           nan]]
# [[        nan -0.00372044         nan ...         nan         nan
#           nan]]
# [[nan nan nan ... nan nan nan]]
# [[       nan -0.0008642        nan ...        nan        nan        nan]]
# [[       nan 0.00060227        nan ...        nan        nan        nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[       nan 0.00030783        nan ...        nan        nan        nan]]
# [[        nan -0.00120019         nan ...         nan         nan
#           nan]]
# [[nan nan nan ... nan nan nan]]
# [[        nan -0.00238193         nan ...         nan         nan
#           nan]]
# [[        nan -0.00279817         nan ...         nan         nan
#           nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[       nan -0.0041796        nan ...        nan        nan        nan]]
# [[      nan -0.002919       nan ...       nan       nan       nan]]
# [[        nan -0.00085175         nan ...         nan         nan
#           nan]]
# [[        nan -0.00226078         nan ...         nan         nan
#           nan]]
# [[        nan -0.00191574         nan ...         nan         nan
#           nan]]
# [[        nan -0.00099284         nan ...         nan         nan
#           nan]]
# [[        nan -0.00369635         nan ...         nan         nan
#           nan]]
# [[       nan -0.0024789        nan ...        nan        nan        nan]]
# [[        nan -0.00320314         nan ...         nan         nan
#           nan]]
# [[       nan 0.00039661        nan ...        nan        nan        nan]]
# [[        nan         nan -0.00122902 ...         nan         nan
#           nan]]
# [[       nan        nan -0.0061827 ...        nan        nan        nan]]
# [[        nan         nan -0.00816492 ...         nan         nan
#           nan]]
# [[        nan         nan -0.01184039 ...         nan         nan
#           nan]]
# [[        nan         nan -0.00779422 ...         nan         nan
#           nan]]
# [[        nan         nan -0.00882216 ...         nan         nan
#           nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[       nan        nan 0.00181232 ...        nan        nan        nan]]
# [[       nan        nan 0.00123528 ...        nan        nan        nan]]
# [[      nan       nan 0.0012194 ...       nan       nan       nan]]
# [[       nan        nan 0.00412866 ...        nan        nan        nan]]
# [[       nan        nan 0.00534349 ...        nan        nan        nan]]
# [[       nan        nan 0.00406156 ...        nan        nan        nan]]
# [[       nan        nan 0.00280827 ...        nan        nan        nan]]
# [[       nan        nan 0.00332939 ...        nan        nan        nan]]
# [[       nan        nan 0.00293497 ...        nan        nan        nan]]
# [[       nan        nan 0.00201998 ...        nan        nan        nan]]
# [[       nan        nan 0.00249985 ...        nan        nan        nan]]
# [[       nan        nan 0.00307933 ...        nan        nan        nan]]
# [[       nan        nan 0.00422184 ...        nan        nan        nan]]
# [[       nan        nan 0.00404619 ...        nan        nan        nan]]
# [[       nan        nan 0.00472959 ...        nan        nan        nan]]
# [[      nan       nan 0.0045712 ...       nan       nan       nan]]
# [[       nan        nan 0.00400231 ...        nan        nan        nan]]
# [[       nan        nan 0.00462411 ...        nan        nan        nan]]
# [[       nan        nan 0.00441814 ...        nan        nan        nan]]
# [[       nan        nan 0.00313571 ...        nan        nan        nan]]
# [[       nan        nan 0.00261873 ...        nan        nan        nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[       nan        nan 0.00131848 ...        nan        nan        nan]]
# [[           nan            nan 8.09164156e-05 ...            nan
#              nan            nan]]
# [[      nan       nan 0.0005815 ...       nan       nan       nan]]
# [[       nan        nan 0.00149209 ...        nan        nan        nan]]
# [[       nan        nan 0.00094433 ...        nan        nan        nan]]
# [[       nan        nan 0.00227115 ...        nan        nan        nan]]
# [[            nan             nan -3.02397957e-05 ...             nan
#               nan             nan]]
# [[       nan        nan 0.00051968 ...        nan        nan        nan]]
# [[       nan        nan 0.00065643 ...        nan        nan        nan]]
# [[nan nan nan ... nan nan nan]]
# [[       nan        nan 0.00070034 ...        nan        nan        nan]]
# [[        nan         nan -0.00016971 ...         nan         nan
#           nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[        nan         nan -0.00283963 ...         nan         nan
#           nan]]
# [[        nan         nan -0.00100846 ...         nan         nan
#           nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[       nan        nan 0.00040532 ...        nan        nan        nan]]
# [[        nan         nan -0.00066889 ...         nan         nan
#           nan]]
# [[        nan         nan -0.00366857 ...         nan         nan
#           nan]]
# [[        nan         nan -0.00144752 ...         nan         nan
#           nan]]
# [[        nan         nan -0.00350157 ...         nan         nan
#           nan]]
# [[        nan         nan -0.00525355 ...         nan         nan
#           nan]]
# [[        nan         nan -0.00570563 ...         nan         nan
#           nan]]
# [[       nan        nan -0.0072893 ...        nan        nan        nan]]
# [[        nan         nan -0.00507685 ...         nan         nan
#           nan]]
# [[            nan             nan -2.01403251e-05 ...             nan
#               nan             nan]]
# [[        nan         nan -0.00085994 ...         nan         nan
#           nan]]
# [[        nan         nan -0.00289057 ...         nan         nan
#           nan]]
# [[            nan             nan -7.16442472e-05 ...             nan
#               nan             nan]]
# [[nan nan nan ... nan nan nan]]
# [[       nan        nan -0.0001774 ...        nan        nan        nan]]
# [[        nan         nan -0.00108077 ...         nan         nan
#           nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[        nan         nan -0.00982025 ...         nan         nan
#           nan]]
# [[        nan         nan -0.01019024 ...         nan         nan
#           nan]]
# [[        nan         nan -0.00990154 ...         nan         nan
#           nan]]
# [[        nan         nan -0.00279973 ...         nan         nan
#           nan]]
# [[        nan         nan -0.00407179 ...         nan         nan
#           nan]]
# [[        nan         nan -0.00342255 ...         nan         nan
#           nan]]
# [[        nan         nan -0.00330275 ...         nan         nan
#           nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[       nan        nan 0.00282604 ...        nan        nan        nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[       nan        nan 0.00280886 ...        nan        nan        nan]]
# [[       nan        nan 0.00258622 ...        nan        nan        nan]]
# [[       nan        nan 0.00310853 ...        nan        nan        nan]]
# [[       nan        nan 0.00283009 ...        nan        nan        nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]]
# Duration: 94.40s

# %%
results['positions']
# Out:
# 2014-12-09 21:00:00+00:00                                                   []
# 2014-12-10 21:00:00+00:00    [{'sid': Equity(192 [APA]), 'amount': -849, 'c...
# 2014-12-11 21:00:00+00:00    [{'sid': Equity(652 [COP]), 'amount': -17, 'co...
# 2014-12-12 21:00:00+00:00    [{'sid': Equity(652 [COP]), 'amount': -776, 'c...
# 2014-12-15 21:00:00+00:00    [{'sid': Equity(195 [APC]), 'amount': -19, 'co...
#                                                    ...
# 2017-11-24 18:00:00+00:00                                                   []
# 2017-11-27 21:00:00+00:00                                                   []
# 2017-11-28 21:00:00+00:00                                                   []
# 2017-11-29 21:00:00+00:00    [{'sid': Equity(8 [AAPL]), 'amount': -285, 'co...
# 2017-11-30 21:00:00+00:00    [{'sid': Equity(8 [AAPL]), 'amount': -6, 'cost...
# Name: positions, Length: 751, dtype: object

# %% [markdown]
# ## Performance Analysis with PyFolio

# %% [markdown]
# Now we can evaluate the results using `pyfolio` tearsheets or its various `pyfolio.plotting` functions.

# %%
returns, positions, transactions = pf.utils.extract_rets_pos_txn_from_zipline(results)

# %%
benchmark = web.DataReader('SP500', 'fred', '2014', '2018').squeeze()
benchmark = benchmark.pct_change().tz_localize('UTC')

# %%
LIVE_DATE = '2017-01-01'

# %%
common_index = returns.index.intersection(benchmark.index)
returns = returns.loc[common_index]
benchmark = benchmark.loc[common_index]

# %%
fig, axes = plt.subplots(ncols=2, figsize=(16, 5))
plot_rolling_returns(returns,
                     factor_returns=benchmark,
                     live_start_date=LIVE_DATE,
                     logy=False,
                     cone_std=2,
                     legend_loc='best',
                     volatility_match=False,
                     cone_function=forecast_cone_bootstrap,
                    ax=axes[0])
plot_rolling_sharpe(returns, ax=axes[1], rolling_window=63)
axes[0].set_title('Cumulative Returns - In and Out-of-Sample')
axes[1].set_title('Rolling Sharpe Ratio (3 Months)')
sns.despine()
fig.tight_layout();

# %%
pf.create_full_tear_sheet(returns, 
                          positions=positions, 
                          transactions=transactions,
                          benchmark_rets=benchmark,
                          live_start_date=LIVE_DATE, 
                          round_trips=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=4>2015-05-04</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=4>2017-11-30</td></tr>
#     <tr style="text-align: right;"><th>In-sample months</th><td colspan=4>20</td></tr>
#     <tr style="text-align: right;"><th>Out-of-sample months</th><td colspan=4>11</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>In-sample</th>
#       <th>Out-of-sample</th>
#       <th>All</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-4.243%</td>
#       <td>1.91%</td>
#       <td>-2.107%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-6.987%</td>
#       <td>1.749%</td>
#       <td>-5.359%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>9.335%</td>
#       <td>6.609%</td>
#       <td>8.467%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>-0.42</td>
#       <td>0.32</td>
#       <td>-0.21</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-0.18</td>
#       <td>0.43</td>
#       <td>-0.09</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.75</td>
#       <td>0.25</td>
#       <td>0.58</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-24.094%</td>
#       <td>-4.491%</td>
#       <td>-24.094%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>0.91</td>
#       <td>1.07</td>
#       <td>0.96</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>-0.55</td>
#       <td>0.46</td>
#       <td>-0.28</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-0.67</td>
#       <td>0.05</td>
#       <td>-0.58</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>4.82</td>
#       <td>1.80</td>
#       <td>5.12</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.89</td>
#       <td>1.00</td>
#       <td>0.92</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.192%</td>
#       <td>-0.824%</td>
#       <td>-1.074%</td>
#     </tr>
#     <tr>
#       <th>Gross leverage</th>
#       <td>1.34</td>
#       <td>1.31</td>
#       <td>1.33</td>
#     </tr>
#     <tr>
#       <th>Daily turnover</th>
#       <td>169.27%</td>
#       <td>183.276%</td>
#       <td>173.657%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>-0.04</td>
#       <td>-0.01</td>
#       <td>-0.02</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>-0.03</td>
#       <td>0.18</td>
#       <td>-0.01</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>24.09</td>
#       <td>2015-08-26</td>
#       <td>2016-10-20</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2.25</td>
#       <td>2015-07-15</td>
#       <td>2015-07-17</td>
#       <td>2015-08-05</td>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.95</td>
#       <td>2015-08-07</td>
#       <td>2015-08-12</td>
#       <td>2015-08-14</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.60</td>
#       <td>2015-08-19</td>
#       <td>2015-08-20</td>
#       <td>2015-08-24</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.38</td>
#       <td>2015-06-11</td>
#       <td>2015-06-12</td>
#       <td>2015-06-16</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Fall2015</th>
#       <td>-0.04%</td>
#       <td>-1.95%</td>
#       <td>1.30%</td>
#     </tr>
#     <tr>
#       <th>New Normal</th>
#       <td>-0.01%</td>
#       <td>-2.92%</td>
#       <td>2.59%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 long positions of all time</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>sid</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>CRM</th>
#       <td>35.41%</td>
#     </tr>
#     <tr>
#       <th>QCOM</th>
#       <td>18.43%</td>
#     </tr>
#     <tr>
#       <th>TWTR</th>
#       <td>17.93%</td>
#     </tr>
#     <tr>
#       <th>TGT</th>
#       <td>15.71%</td>
#     </tr>
#     <tr>
#       <th>PANW</th>
#       <td>15.19%</td>
#     </tr>
#     <tr>
#       <th>MET</th>
#       <td>15.06%</td>
#     </tr>
#     <tr>
#       <th>INCY</th>
#       <td>14.91%</td>
#     </tr>
#     <tr>
#       <th>TSLA</th>
#       <td>14.88%</td>
#     </tr>
#     <tr>
#       <th>MYL</th>
#       <td>14.81%</td>
#     </tr>
#     <tr>
#       <th>HES</th>
#       <td>14.49%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 short positions of all time</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>sid</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>CRM</th>
#       <td>-30.73%</td>
#     </tr>
#     <tr>
#       <th>AMD</th>
#       <td>-19.68%</td>
#     </tr>
#     <tr>
#       <th>MU</th>
#       <td>-15.94%</td>
#     </tr>
#     <tr>
#       <th>SRPT</th>
#       <td>-15.33%</td>
#     </tr>
#     <tr>
#       <th>NFLX</th>
#       <td>-15.20%</td>
#     </tr>
#     <tr>
#       <th>TWTR</th>
#       <td>-15.19%</td>
#     </tr>
#     <tr>
#       <th>ABT</th>
#       <td>-15.18%</td>
#     </tr>
#     <tr>
#       <th>COP</th>
#       <td>-14.72%</td>
#     </tr>
#     <tr>
#       <th>X</th>
#       <td>-14.49%</td>
#     </tr>
#     <tr>
#       <th>AAOI</th>
#       <td>-14.25%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 positions of all time</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>sid</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>CRM</th>
#       <td>35.41%</td>
#     </tr>
#     <tr>
#       <th>AMD</th>
#       <td>19.68%</td>
#     </tr>
#     <tr>
#       <th>QCOM</th>
#       <td>18.43%</td>
#     </tr>
#     <tr>
#       <th>TWTR</th>
#       <td>17.93%</td>
#     </tr>
#     <tr>
#       <th>MU</th>
#       <td>15.94%</td>
#     </tr>
#     <tr>
#       <th>TGT</th>
#       <td>15.71%</td>
#     </tr>
#     <tr>
#       <th>SRPT</th>
#       <td>15.33%</td>
#     </tr>
#     <tr>
#       <th>NFLX</th>
#       <td>15.20%</td>
#     </tr>
#     <tr>
#       <th>PANW</th>
#       <td>15.19%</td>
#     </tr>
#     <tr>
#       <th>ABT</th>
#       <td>15.18%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Summary stats</th>
#       <th>All trades</th>
#       <th>Short trades</th>
#       <th>Long trades</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Total number of round_trips</th>
#       <td>19038.00</td>
#       <td>9159.00</td>
#       <td>9879.00</td>
#     </tr>
#     <tr>
#       <th>Percent profitable</th>
#       <td>0.49</td>
#       <td>0.49</td>
#       <td>0.50</td>
#     </tr>
#     <tr>
#       <th>Winning round_trips</th>
#       <td>9403.00</td>
#       <td>4466.00</td>
#       <td>4937.00</td>
#     </tr>
#     <tr>
#       <th>Losing round_trips</th>
#       <td>9501.00</td>
#       <td>4622.00</td>
#       <td>4879.00</td>
#     </tr>
#     <tr>
#       <th>Even round_trips</th>
#       <td>134.00</td>
#       <td>71.00</td>
#       <td>63.00</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>PnL stats</th>
#       <th>All trades</th>
#       <th>Short trades</th>
#       <th>Long trades</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Total profit</th>
#       <td>$-37126.78</td>
#       <td>$-122016.22</td>
#       <td>$84889.45</td>
#     </tr>
#     <tr>
#       <th>Gross profit</th>
#       <td>$4191425.77</td>
#       <td>$2088892.79</td>
#       <td>$2102532.97</td>
#     </tr>
#     <tr>
#       <th>Gross loss</th>
#       <td>$-4228552.54</td>
#       <td>$-2210909.02</td>
#       <td>$-2017643.53</td>
#     </tr>
#     <tr>
#       <th>Profit factor</th>
#       <td>$0.99</td>
#       <td>$0.94</td>
#       <td>$1.04</td>
#     </tr>
#     <tr>
#       <th>Avg. trade net profit</th>
#       <td>$-1.95</td>
#       <td>$-13.32</td>
#       <td>$8.59</td>
#     </tr>
#     <tr>
#       <th>Avg. winning trade</th>
#       <td>$445.75</td>
#       <td>$467.73</td>
#       <td>$425.87</td>
#     </tr>
#     <tr>
#       <th>Avg. losing trade</th>
#       <td>$-445.06</td>
#       <td>$-478.34</td>
#       <td>$-413.54</td>
#     </tr>
#     <tr>
#       <th>Ratio Avg. Win:Avg. Loss</th>
#       <td>$1.00</td>
#       <td>$0.98</td>
#       <td>$1.03</td>
#     </tr>
#     <tr>
#       <th>Largest winning trade</th>
#       <td>$11070.57</td>
#       <td>$11070.57</td>
#       <td>$6145.92</td>
#     </tr>
#     <tr>
#       <th>Largest losing trade</th>
#       <td>$-25762.15</td>
#       <td>$-19056.24</td>
#       <td>$-25762.15</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Duration stats</th>
#       <th>All trades</th>
#       <th>Short trades</th>
#       <th>Long trades</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avg duration</th>
#       <td>1 days 11:29:58.487078474</td>
#       <td>1 days 12:26:11.438039087</td>
#       <td>1 days 10:37:51.363093430</td>
#     </tr>
#     <tr>
#       <th>Median duration</th>
#       <td>1 days 00:00:00</td>
#       <td>1 days 00:00:00</td>
#       <td>1 days 00:00:00</td>
#     </tr>
#     <tr>
#       <th>Longest duration</th>
#       <td>65 days 23:00:00</td>
#       <td>65 days 23:00:00</td>
#       <td>5 days 03:00:00</td>
#     </tr>
#     <tr>
#       <th>Shortest duration</th>
#       <td>0 days 00:00:00</td>
#       <td>0 days 00:00:00</td>
#       <td>0 days 00:00:00</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Return stats</th>
#       <th>All trades</th>
#       <th>Short trades</th>
#       <th>Long trades</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avg returns all round_trips</th>
#       <td>-0.00%</td>
#       <td>-0.00%</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <th>Avg returns winning</th>
#       <td>0.04%</td>
#       <td>0.05%</td>
#       <td>0.04%</td>
#     </tr>
#     <tr>
#       <th>Avg returns losing</th>
#       <td>-0.04%</td>
#       <td>-0.05%</td>
#       <td>-0.04%</td>
#     </tr>
#     <tr>
#       <th>Median returns all round_trips</th>
#       <td>0.00%</td>
#       <td>-0.00%</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <th>Median returns winning</th>
#       <td>0.02%</td>
#       <td>0.02%</td>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <th>Median returns losing</th>
#       <td>-0.02%</td>
#       <td>-0.02%</td>
#       <td>-0.02%</td>
#     </tr>
#     <tr>
#       <th>Largest winning trade</th>
#       <td>1.02%</td>
#       <td>1.02%</td>
#       <td>0.65%</td>
#     </tr>
#     <tr>
#       <th>Largest losing trade</th>
#       <td>-1.98%</td>
#       <td>-1.98%</td>
#       <td>-1.10%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Symbol stats</th>
#       <th>AAL</th>
#       <th>AAOI</th>
#       <th>AAPL</th>
#       <th>ABBV</th>
#       <th>ABT</th>
#       <th>ACN</th>
#       <th>ADBE</th>
#       <th>ADI</th>
#       <th>ADP</th>
#       <th>ADSK</th>
#       <th>AET</th>
#       <th>AGN</th>
#       <th>AIG</th>
#       <th>ALTR</th>
#       <th>ALXN</th>
#       <th>AMAT</th>
#       <th>AMBA</th>
#       <th>AMD</th>
#       <th>AMGN</th>
#       <th>AMT</th>
#       <th>AMZN</th>
#       <th>ANTM</th>
#       <th>APA</th>
#       <th>APC</th>
#       <th>APD</th>
#       <th>ARNC</th>
#       <th>ATVI</th>
#       <th>AVGO</th>
#       <th>AXP</th>
#       <th>AZO</th>
#       <th>BA</th>
#       <th>BAC</th>
#       <th>BAX</th>
#       <th>BBY</th>
#       <th>BDX</th>
#       <th>BIDU</th>
#       <th>BIIB</th>
#       <th>BK</th>
#       <th>BMY</th>
#       <th>BP</th>
#       <th>BSX</th>
#       <th>C</th>
#       <th>CAT</th>
#       <th>CB</th>
#       <th>CCE</th>
#       <th>CCI</th>
#       <th>CCL</th>
#       <th>CELG</th>
#       <th>CHK</th>
#       <th>CHTR</th>
#       <th>CI</th>
#       <th>CL</th>
#       <th>CMCSA</th>
#       <th>CMG</th>
#       <th>CMI</th>
#       <th>CNC</th>
#       <th>COF</th>
#       <th>COL</th>
#       <th>COP</th>
#       <th>COST</th>
#       <th>COTY</th>
#       <th>CRM</th>
#       <th>CSCO</th>
#       <th>CSX</th>
#       <th>CTL</th>
#       <th>CTSH</th>
#       <th>CVS</th>
#       <th>CVX</th>
#       <th>CXO</th>
#       <th>DAL</th>
#       <th>DE</th>
#       <th>DFS</th>
#       <th>DG</th>
#       <th>DHR</th>
#       <th>DIS</th>
#       <th>DISH</th>
#       <th>DLR</th>
#       <th>DLTR</th>
#       <th>DTV</th>
#       <th>DUK</th>
#       <th>DVN</th>
#       <th>EA</th>
#       <th>EBAY</th>
#       <th>EFX</th>
#       <th>EL</th>
#       <th>EMR</th>
#       <th>ENDP</th>
#       <th>EOG</th>
#       <th>EQIX</th>
#       <th>EQT</th>
#       <th>ESRX</th>
#       <th>EXPE</th>
#       <th>F</th>
#       <th>FB</th>
#       <th>FCX</th>
#       <th>FDX</th>
#       <th>FL</th>
#       <th>FLT</th>
#       <th>FOXA</th>
#       <th>FTI</th>
#       <th>GE</th>
#       <th>GILD</th>
#       <th>GM</th>
#       <th>GOOG</th>
#       <th>GOOGL</th>
#       <th>GPN</th>
#       <th>GS</th>
#       <th>GWW</th>
#       <th>HAL</th>
#       <th>HCA</th>
#       <th>HD</th>
#       <th>HES</th>
#       <th>HON</th>
#       <th>HPQ</th>
#       <th>HSY</th>
#       <th>HTZ</th>
#       <th>HUM</th>
#       <th>IBM</th>
#       <th>ILMN</th>
#       <th>INCY</th>
#       <th>INTC</th>
#       <th>INTU</th>
#       <th>ISRG</th>
#       <th>JCI</th>
#       <th>JNJ</th>
#       <th>JPM</th>
#       <th>KHC</th>
#       <th>KMI</th>
#       <th>KO</th>
#       <th>KORS</th>
#       <th>KR</th>
#       <th>LB</th>
#       <th>LDOS</th>
#       <th>LL</th>
#       <th>LLY</th>
#       <th>LMT</th>
#       <th>LOW</th>
#       <th>LRCX</th>
#       <th>LUV</th>
#       <th>LVS</th>
#       <th>LYB</th>
#       <th>M</th>
#       <th>MA</th>
#       <th>MAR</th>
#       <th>MCD</th>
#       <th>MCHP</th>
#       <th>MCK</th>
#       <th>MDLZ</th>
#       <th>MDT</th>
#       <th>MET</th>
#       <th>MGM</th>
#       <th>MMM</th>
#       <th>MO</th>
#       <th>MPC</th>
#       <th>MRK</th>
#       <th>MRO</th>
#       <th>MS</th>
#       <th>MSFT</th>
#       <th>MU</th>
#       <th>MYL</th>
#       <th>NEE</th>
#       <th>NEM</th>
#       <th>NFLX</th>
#       <th>NKE</th>
#       <th>NOV</th>
#       <th>NVDA</th>
#       <th>NWL</th>
#       <th>OKE</th>
#       <th>ORCL</th>
#       <th>ORLY</th>
#       <th>OXY</th>
#       <th>PANW</th>
#       <th>PCG</th>
#       <th>PEP</th>
#       <th>PFE</th>
#       <th>PG</th>
#       <th>PM</th>
#       <th>PNC</th>
#       <th>PRGO</th>
#       <th>PSX</th>
#       <th>PXD</th>
#       <th>PYPL</th>
#       <th>QCOM</th>
#       <th>RAD</th>
#       <th>RCL</th>
#       <th>REGN</th>
#       <th>RF</th>
#       <th>RIG</th>
#       <th>SBAC</th>
#       <th>SBUX</th>
#       <th>SCHW</th>
#       <th>SE</th>
#       <th>SHW</th>
#       <th>SIG</th>
#       <th>SLB</th>
#       <th>SO</th>
#       <th>SPG</th>
#       <th>SRPT</th>
#       <th>STZ</th>
#       <th>SWKS</th>
#       <th>SWN</th>
#       <th>SYF</th>
#       <th>SYY</th>
#       <th>T</th>
#       <th>TAP</th>
#       <th>TDG</th>
#       <th>TGT</th>
#       <th>TJX</th>
#       <th>TMO</th>
#       <th>TMUS</th>
#       <th>TSLA</th>
#       <th>TSN</th>
#       <th>TWTR</th>
#       <th>TXN</th>
#       <th>UAA</th>
#       <th>UAL</th>
#       <th>ULTA</th>
#       <th>UNH</th>
#       <th>UNP</th>
#       <th>UPS</th>
#       <th>URI</th>
#       <th>USB</th>
#       <th>UTX</th>
#       <th>V</th>
#       <th>VLO</th>
#       <th>VMW</th>
#       <th>VRTX</th>
#       <th>VRX</th>
#       <th>VZ</th>
#       <th>WBA</th>
#       <th>WDC</th>
#       <th>WFC</th>
#       <th>WLL</th>
#       <th>WMB</th>
#       <th>WMT</th>
#       <th>WYNN</th>
#       <th>X</th>
#       <th>XOM</th>
#       <th>YELP</th>
#       <th>YUM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avg returns all round_trips</th>
#       <td>0.01%</td>
#       <td>-0.00%</td>
#       <td>-0.01%</td>
#       <td>-0.00%</td>
#       <td>-0.00%</td>
#       <td>0.01%</td>
#       <td>-0.00%</td>
#       <td>0.01%</td>
#       <td>0.03%</td>
#       <td>0.06%</td>
#       <td>0.00%</td>
#       <td>0.00%</td>
#       <td>-0.01%</td>
#       <td>0.01%</td>
#       <td>-0.01%</td>
#       <td>0.00%</td>
#       <td>0.04%</td>
#       <td>-0.00%</td>
#       <td>0.00%</td>
#       <td>0.03%</td>
#       <td>0.00%</td>
#       <td>-0.00%</td>
#       <td>-0.02%</td>
#       <td>0.04%</td>
#       <td>-0.01%</td>
#       <td>NaN</td>
#       <td>0.02%</td>
#       <td>-0.00%</td>
#       <td>-0.00%</td>
#       <td>-0.01%</td>
#       <td>0.01%</td>
#       <td>-0.00%</td>
#       <td>-0.01%</td>
#       <td>0.02%</td>
#       <td>-0.00%</td>
#       <td>-0.00%</td>
#       <td>-0.00%</td>
#       <td>-0.00%</td>
#       <td>0.00%</td>
#       <td>0.01%</td>
#       <td>-0.02%</td>
#       <td>0.00%</td>
#       <td>0.00%</td>
#       <td>-0.00%</td>
#       <td>-0.00%</td>
#       <td>-0.01%</td>
#       <td>-0.03%</td>
#       <td>0.00%</td>
#       <td>-0.01%</td>
#       <td>-0.01%</td>
#       <td>-0.01%</td>
#       <td>0.02%</td>
#       <td>0.00%</td>
#       <td>0.00%</td>
#       <td>-0.26%</td>
#       <td>0.07%</td>
#       <td>0.01%</td>
#       <td>0.03%</td>
#       <td>-0.01%</td>
#       <td>-0.00%</td>
#       <td>0.03%</td>
#       <td>-0.02%</td>
#       <td>-0.00%</td>
#       <td>-0.00%</td>
#       <td>-0.05%</td>
#       <td>0.01%</td>
#       <td>0.00%</td>
#       <td>-0.00%</td>
#       <td>-0.01%</td>
#       <td>0.00%</td>
#       <td>0.01%</td>
#       <td>NaN</td>
#       <td>0.00%</td>
#       <td>0.00%</td>
#       <td>-0.00%</td>
#       <td>-0.02%</td>
#       <td>-0.02%</td>
#       <td>0.02%</td>
#       <td>-0.00%</td>
#       <td>0.01%</td>
#       <td>-0.03%</td>
#       <td>0.01%</td>
#       <td>-0.01%</td>
#       <td>0.00%</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.01%</td>
#       <td>-0.00%</td>
#       <td>0.00%</td>
#       <td>-0.01%</td>
#       <td>-0.00%</td>
#       <td>0.01%</td>
#       <td>-0.00%</td>
#       <td>-0.00%</td>
#       <td>-0.01%</td>
#       <td>0.00%</td>
#       <td>-0.07%</td>
#       <td>0.08%</td>
#       <td>-0.00%</td>
#       <td>0.16%</td>
#       <td>0.00%</td>
#       <td>0.01%</td>
#       <td>0.00%</td>
#       <td>-0.01%</td>
#       <td>-0.01%</td>
#       <td>0.02%</td>
#       <td>0.01%</td>
#       <td>0.00%</td>
#       <td>0.01%</td>
#       <td>0.02%</td>
#       <td>-0.00%</td>
#       <td>-0.13%</td>
#       <td>0.01%</td>
#       <td>-0.22%</td>
#       <td>0.01%</td>
#       <td>NaN</td>
#       <td>0.00%</td>
#       <td>-0.00%</td>
#       <td>0.10%</td>
#       <td>-0.00%</td>
#       <td>-0.01%</td>
#       <td>-0.01%</td>
#       <td>0.04%</td>
#       <td>-0.00%</td>
#       <td>-0.00%</td>
#       <td>-0.01%</td>
#       <td>0.01%</td>
#       <td>0.01%</td>
#       <td>0.00%</td>
#       <td>0.00%</td>
#       <td>0.00%</td>
#       <td>0.03%</td>
#       <td>0.02%</td>
#       <td>NaN</td>
#       <td>0.00%</td>
#       <td>-0.00%</td>
#       <td>-0.00%</td>
#       <td>-0.00%</td>
#       <td>-0.00%</td>
#       <td>0.02%</td>
#       <td>0.02%</td>
#       <td>-0.00%</td>
#       <td>0.00%</td>
#       <td>-0.00%</td>
#       <td>-0.00%</td>
#       <td>-0.04%</td>
#       <td>-0.01%</td>
#       <td>0.00%</td>
#       <td>-0.01%</td>
#       <td>-0.01%</td>
#       <
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Profitability (PnL / PnL total) per name</th>
#       <th></th>
#     </tr>
#     <tr>
#       <th>symbol</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>TWTR</th>
#       <td>115.55%</td>
#     </tr>
#     <tr>
#       <th>VRX</th>
#       <td>113.33%</td>
#     </tr>
#     <tr>
#       <th>FCX</th>
#       <td>108.32%</td>
#     </tr>
#     <tr>
#       <th>X</th>
#       <td>75.34%</td>
#     </tr>
#     <tr>
#       <th>SBUX</th>
#       <td>67.00%</td>
#     </tr>
#     <tr>
#       <th>CRM</th>
#       <td>55.41%</td>
#     </tr>
#     <tr>
#       <th>AAPL</th>
#       <td>52.55%</td>
#     </tr>
#     <tr>
#       <th>CVX</th>
#       <td>35.57%</td>
#     </tr>
#     <tr>
#       <th>CHK</th>
#       <td>34.96%</td>
#     </tr>
#     <tr>
#       <th>MET</th>
#       <td>34.51%</td>
#     </tr>
#     <tr>
#       <th>GOOG</th>
#       <td>33.90%</td>
#     </tr>
#     <tr>
#       <th>EBAY</th>
#       <td>29.71%</td>
#     </tr>
#     <tr>
#       <th>COP</th>
#       <td>29.36%</td>
#     </tr>
#     <tr>
#       <th>AIG</th>
#       <td>25.42%</td>
#     </tr>
#     <tr>
#       <th>HES</th>
#       <td>24.58%</td>
#     </tr>
#     <tr>
#       <th>WMB</th>
#       <td>24.49%</td>
#     </tr>
#     <tr>
#       <th>DVN</th>
#       <td>23.63%</td>
#     </tr>
#     <tr>
#       <th>PFE</th>
#       <td>22.29%</td>
#     </tr>
#     <tr>
#       <th>INTC</th>
#       <td>22.07%</td>
#     </tr>
#     <tr>
#       <th>GOOGL</th>
#       <td>21.68%</td>
#     </tr>
#     <tr>
#       <th>CHTR</th>
#       <td>21.48%</td>
#     </tr>
#     <tr>
#       <th>MRO</th>
#       <td>20.57%</td>
#     </tr>
#     <tr>
#       <th>JPM</th>
#       <td>19.47%</td>
#     </tr>
#     <tr>
#       <th>JNJ</th>
#       <td>19.03%</td>
#     </tr>
#     <tr>
#       <th>PXD</th>
#       <td>18.67%</td>
#     </tr>
#     <tr>
#       <th>CSCO</th>
#       <td>18.54%</td>
#     </tr>
#     <tr>
#       <th>MDT</th>
#       <td>18.44%</td>
#     </tr>
#     <tr>
#       <th>VZ</th>
#       <td>17.83%</td>
#     </tr>
#     <tr>
#       <th>BAC</th>
#       <td>16.99%</td>
#     </tr>
#     <tr>
#       <th>ALXN</th>
#       <td>15.75%</td>
#     </tr>
#     <tr>
#       <th>HPQ</th>
#       <td>13.33%</td>
#     </tr>
#     <tr>
#       <th>XOM</th>
#       <td>12.21%</td>
#     </tr>
#     <tr>
#       <th>ORLY</th>
#       <td>12.14%</td>
#     </tr>
#     <tr>
#       <th>DIS</th>
#       <td>11.99%</td>
#     </tr>
#     <tr>
#       <th>CSX</th>
#       <td>11.69%</td>
#     </tr>
#     <tr>
#       <th>NEM</th>
#       <td>11.53%</td>
#     </tr>
#     <tr>
#       <th>WYNN</th>
#       <td>11.31%</td>
#     </tr>
#     <tr>
#       <th>M</th>
#       <td>10.83%</td>
#     </tr>
#     <tr>
#       <th>F</th>
#       <td>10.76%</td>
#     </tr>
#     <tr>
#       <th>EOG</th>
#       <td>9.69%</td>
#     </tr>
#     <tr>
#       <th>AZO</th>
#       <td>9.66%</td>
#     </tr>
#     <tr>
#       <th>TJX</th>
#       <td>9.63%</td>
#     </tr>
#     <tr>
#       <th>FOXA</th>
#       <td>9.55%</td>
#     </tr>
#     <tr>
#       <th>AMD</th>
#       <td>9.52%</td>
#     </tr>
#     <tr>
#       <th>WFC</th>
#       <td>9.13%</td>
#     </tr>
#     <tr>
#       <th>ESRX</th>
#       <td>8.90%</td>
#     </tr>
#     <tr>
#       <th>GM</th>
#       <td>8.70%</td>
#     </tr>
#     <tr>
#       <th>APA</th>
#       <td>8.38%</td>
#     </tr>
#     <tr>
#       <th>IBM</th>
#       <td>8.20%</td>
#     </tr>
#     <tr>
#       <th>COST</th>
#       <td>8.12%</td>
#     </tr>
#     <tr>
#       <th>MCK</th>
#       <td>8.07%</td>
#     </tr>
#     <tr>
#       <th>CI</th>
#       <td>7.77%</td>
#     </tr>
#     <tr>
#       <th>LOW</th>
#       <td>7.74%</td>
#     </tr>
#     <tr>
#       <th>NOV</th>
#       <td>7.28%</td>
#     </tr>
#     <tr>
#       <th>CMI</th>
#       <td>6.95%</td>
#     </tr>
#     <tr>
#       <th>WMT</th>
#       <td>6.90%</td>
#     </tr>
#     <tr>
#       <th>MPC</th>
#       <td>6.61%</td>
#     </tr>
#     <tr>
#       <th>LVS</th>
#       <td>6.40%</td>
#     </tr>
#     <tr>
#       <th>LL</th>
#       <td>6.24%</td>
#     </tr>
#     <tr>
#       <th>DG</th>
#       <td>5.96%</td>
#     </tr>
#     <tr>
#       <th>BIIB</th>
#       <td>5.94%</td>
#     </tr>
#     <tr>
#       <th>AXP</th>
#       <td>5.89%</td>
#     </tr>
#     <tr>
#       <th>WDC</th>
#       <td>5.86%</td>
#     </tr>
#     <tr>
#       <th>RAD</th>
#       <td>5.12%</td>
#     </tr>
#     <tr>
#       <th>T</th>
#       <td>4.97%</td>
#     </tr>
#     <tr>
#       <th>OXY</th>
#       <td>4.61%</td>
#     </tr>
#     <tr>
#       <th>ABT</th>
#       <td>4.54%</td>
#     </tr>
#     <tr>
#       <th>LRCX</th>
#       <td>4.38%</td>
#     </tr>
#     <tr>
#       <th>STZ</th>
#       <td>4.20%</td>
#     </tr>
#     <tr>
#       <th>DLR</th>
#       <td>4.16%</td>
#     </tr>
#     <tr>
#       <th>MO</th>
#       <td>3.72%</td>
#     </tr>
#     <tr>
#       <th>SWN</th>
#       <td>3.67%</td>
#     </tr>
#     <tr>
#       <th>MS</th>
#       <td>3.66%</td>
#     </tr>
#     <tr>
#       <th>AVGO</th>
#       <td>3.18%</td>
#     </tr>
#     <tr>
#       <th>TAP</th>
#       <td>2.73%</td>
#     </tr>
#     <tr>
#       <th>UTX</th>
#       <td>2.68%</td>
#     </tr>
#     <tr>
#       <th>TGT</th>
#       <td>2.60%</td>
#     </tr>
#     <tr>
#       <th>CMCSA</th>
#       <td>2.53%</td>
#     </tr>
#     <tr>
#       <th>MMM</th>
#       <td>2.49%</td>
#     </tr>
#     <tr>
#       <th>TXN</th>
#       <td>2.40%</td>
#     </tr>
#     <tr>
#       <th>AAOI</th>
#       <td>2.34%</td>
#     </tr>
#     <tr>
#       <th>MCHP</th>
#       <td>2.10%</td>
#     </tr>
#     <tr>
#       <th>MDLZ</th>
#       <td>2.04%</td>
#     </tr>
#     <tr>
#       <th>FL</th>
#       <td>1.95%</td>
#     </tr>
#     <tr>
#       <th>PRGO</th>
#       <td>1.89%</td>
#     </tr>
#     <tr>
#       <th>DLTR</th>
#       <td>1.84%</td>
#     </tr>
#     <tr>
#       <th>CCI</th>
#       <td>1.78%</td>
#     </tr>
#     <tr>
#       <th>HTZ</th>
#       <td>1.72%</td>
#     </tr>
#     <tr>
#       <th>BAX</th>
#       <td>1.72%</td>
#     </tr>
#     <tr>
#       <th>CB</th>
#       <td>1.70%</td>
#     </tr>
#     <tr>
#       <th>URI</th>
#       <td>1.69%</td>
#     </tr>
#     <tr>
#       <th>GWW</th>
#       <td>1.67%</td>
#     </tr>
#     <tr>
#       <th>BP</th>
#       <td>1.67%</td>
#     </tr>
#     <tr>
#       <th>LMT</th>
#       <td>1.48%</td>
#     </tr>
#     <tr>
#       <th>BSX</th>
#       <td>1.41%</td>
#     </tr>
#     <tr>
#       <th>SHW</th>
#       <td>1.35%</td>
#     </tr>
#     <tr>
#       <th>EQT</th>
#       <td>1.33%</td>
#     </tr>
#     <tr>
#       <th>CTL</th>
#       <td>1.28%</td>
#     </tr>
#     <tr>
#       <th>DISH</th>
#       <td>1.23%</td>
#     </tr>
#     <tr>
#       <th>NWL</th>
#       <td>1.11%</td>
#     </tr>
#     <tr>
#       <th>CVS</th>
#       <td>0.98%</td>
#     </tr>
#     <tr>
#       <th>HD</th>
#       <td>0.86%</td>
#     </tr>
#     <tr>
#       <th>INCY</th>
#       <td>0.86%</td>
#     </tr>
#     <tr>
#       <th>CCL</th>
#       <td>0.80%</td>
#     </tr>
#     <tr>
#       <th>RCL</th>
#       <td>0.74%</td>
#     </tr>
#     <tr>
#       <th>ADBE</th>
#       <td>0.70%</td>
#     </tr>
#     <tr>
#       <th>CXO</th>
#       <td>0.67%</td>
#     </tr>
#     <tr>
#       <th>SLB</th>
#       <td>0.66%</td>
#     </tr>
#     <tr>
#       <th>BK</th>
#       <td>0.52%</td>
#     </tr>
#     <tr>
#       <th>TMO</th>
#       <td>0.40%</td>
#     </tr>
#     <tr>
#       <th>OKE</th>
#       <td>0.38%</td>
#     </tr>
#     <tr>
#       <th>MAR</th>
#       <td>0.35%</td>
#     </tr>
#     <tr>
#       <th>INTU</th>
#       <td>0.32%</td>
#     </tr>
#     <tr>
#       <th>BDX</th>
#       <td>0.27%</td>
#     </tr>
#     <tr>
#       <th>DFS</th>
#       <td>0.25%</td>
#     </tr>
#     <tr>
#       <th>APD</th>
#       <td>0.15%</td>
#     </tr>
#     <tr>
#       <th>EL</th>
#       <td>0.15%</td>
#     </tr>
#     <tr>
#       <th>DTV</th>
#       <td>0.15%</td>
#     </tr>
#     <tr>
#       <th>DHR</th>
#       <td>-0.06%</td>
#     </tr>
#     <tr>
#       <th>EMR</th>
#       <td>-0.14%</td>
#     </tr>
#     <tr>
#       <th>HSY</th>
#       <td>-0.15%</td>
#     </tr>
#     <tr>
#       <th>ANTM</th>
#       <td>-0.26%</td>
#     </tr>
#     <tr>
#       <th>SCHW</th>
#       <td>-0.34%</td>
#     </tr>
#     <tr>
#       <th>KHC</th>
#       <td>-0.58%</td>
#     </tr>
#     <tr>
#       <th>GPN</th>
#       <td>-0.61%</td>
#     </tr>
#     <tr>
#       <th>TMUS</th>
#       <td>-0.94%</td>
#     </tr>
#     <tr>
#       <th>KORS</th>
#       <td>-0.98%</td>
#     </tr>
#     <tr>
#       <th>UAA</th>
#       <td>-1.03%</td>
#     </tr>
#     <tr>
#       <th>ABBV</th>
#       <td>-1.11%</td>
#     </tr>
#     <tr>
#       <th>EFX</th>
#       <td>-1.17%</td>
#     </tr>
#     <tr>
#       <th>
