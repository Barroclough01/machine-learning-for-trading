# %% [markdown]
# # Basic Image Classification with Feedforward NN and LetNet5

# %% [markdown]
# All libraries we introduced in the last chapter provide support for convolutional layers. We are going to illustrate the LeNet5 architecture using the most basic MNIST handwritten digit dataset, and then use AlexNet on CIFAR10, a simplified version of the original ImageNet to demonstrate the use of data augmentation.
# LeNet5 and MNIST using Keras.

# %% [markdown]
# ## Imports

# %%
# %matplotlib inline

from pathlib import Path
from random import randint
import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras.datasets import mnist
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (Conv2D, 
                                     AveragePooling2D, 
                                     Dense, 
                                     Dropout, 
                                     Flatten,
                                     Input)
import matplotlib.pyplot as plt
import seaborn as sns

# %%
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
if gpu_devices:
    print('Using GPU')
    tf.config.experimental.set_memory_growth(gpu_devices[0], True)
else:
    print('Using CPU')
# Out:
# Using CPU

# %%
sns.set_style('whitegrid')

# %%
results_path = Path('results')
mnist_path = results_path / 'mnist'
if not mnist_path.exists():
    mnist_path.mkdir(parents=True)

# %% [markdown]
# ## Load MNIST Database

# %% [markdown]
# The original MNIST dataset contains 60,000 images in 28x28 pixel resolution with a single grayscale containing handwritten digits from 0 to 9. A good alternative is the more challenging but structurally similar Fashion MNIST dataset that we encountered in Chapter 12 on Unsupervised Learning.

# %% [markdown]
# We can load it in keras out of the box:

# %%
# use Keras to import pre-shuffled MNIST database
(X_train, y_train), (X_test, y_test) = mnist.load_data()

print("The MNIST database has a training set of %d examples." % len(X_train))
print("The MNIST database has a test set of %d examples." % len(X_test))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# The MNIST database has a training set of 60000 examples.
# The MNIST database has a test set of 10000 examples.

# %%
X_train.shape, X_test.shape
# Out:
# ((60000, 28, 28), (10000, 28, 28))

# %% [markdown]
# ## Visualize Data

# %% [markdown]
# ### Visualize First 10 Training Images

# %% [markdown]
# The below figure shows the first ten images in the dataset and highlights significant variation among instances of the same digit. On the right, it shows how the pixel values for an indivual image range from 0 to 255.

# %%
fig, axes = plt.subplots(ncols=5, nrows=2, figsize=(20, 8))
axes = axes.flatten()
for i, ax in enumerate(axes):
    ax.imshow(X_train[i], cmap='gray')
    ax.axis('off')
    ax.set_title('Digit: {}'.format(y_train[i]), fontsize=16)
fig.suptitle('First 10 Digits', fontsize=20)
fig.tight_layout()
fig.subplots_adjust(top=.9)

# %% [markdown]
# ### Show random image in detail

# %%
fig, ax = plt.subplots(figsize = (14, 14)) 

i = randint(0, len(X_train))
img = X_train[i]

ax.imshow(img, cmap='gray')
ax.set_title('Digit: {}'.format(y_train[i]), fontsize=16)

width, height = img.shape
thresh = img.max()/2.5
for x in range(width):
    for y in range(height):
        ax.annotate('{:2}'.format(img[x][y]), 
                    xy=(y,x),
                    horizontalalignment='center',
                    verticalalignment='center',
                    color='white' if img[x][y]<thresh else 'black')

# %% [markdown]
# ## Prepare Data

# %% [markdown]
# ### Rescale pixel values

# %% [markdown]
# We rescale the pixel values to the range [0, 1] to normalize the training data and faciliate the backpropagation process and convert the data to 32 bit floats that reduce memory requirements and computational cost while providing sufficient precision for our use case:

# %%
# rescale [0,255] --> [0,1]
X_train = X_train.astype('float32')/255
X_test = X_test.astype('float32')/255

# %% [markdown]
# ### One-Hot Label Encoding using Keras

# %% [markdown]
# Print first ten labels

# %%
print('Integer-valued labels:')
print(y_train[:10])
# Out:
# Integer-valued labels:
# [5 0 4 1 9 2 1 3 1 4]

# %% [markdown]
# ## Feed-Forward NN

# %% [markdown]
# ### Model Architecture

# %%
ffnn = Sequential([
    Input(shape=X_train.shape[1:]),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.2),
    Dense(512, activation='relu'),
    Dropout(0.2),
    Dense(10, activation='softmax')
])

# %%
ffnn.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_1 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 512)            │       401,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │         5,130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 669,706 (2.55 MB)
#  Trainable params: 669,706 (2.55 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Compile the Model

# %%
ffnn.compile(loss='sparse_categorical_crossentropy', 
              optimizer='rmsprop', 
              metrics=['accuracy'])

# %% [markdown]
# ### Calculate Baseline Classification Accuracy

# %%
# evaluate test accuracy
baseline_accuracy = ffnn.evaluate(X_test, y_test, verbose=0)[1]

# print test accuracy
print(f'Test accuracy: {baseline_accuracy:.2%}')
# Out:
# Test accuracy: 10.73%

# %% [markdown]
# ### Callback for model persistence

# %%
ffn_path = mnist_path / 'ffn.best.keras'

# %%
checkpointer = ModelCheckpoint(filepath=ffn_path.as_posix(), 
                               verbose=1, 
                               save_best_only=True)

# %% [markdown]
# ### Early Stopping Callback

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=20)

# %% [markdown]
# ### Train the Model

# %%
epochs = 100
batch_size = 32

# %%
ffnn_history = ffnn.fit(X_train,
                        y_train,
                        batch_size=batch_size,
                        epochs=epochs,
                        validation_split=0.2,
                        callbacks=[checkpointer, early_stopping],
                        verbose=1,
                        shuffle=True)
# Out:
# Epoch 1/100
# 1495/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8766 - loss: 0.3858
# Epoch 1: val_loss improved from inf to 0.11466, saving model to results/mnist/ffn.best.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8768 - loss: 0.3852 - val_accuracy: 0.9673 - val_loss: 0.1147
# Epoch 2/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9651 - loss: 0.1234
# Epoch 2: val_loss improved from 0.11466 to 0.10399, saving model to results/mnist/ffn.best.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9651 - loss: 0.1234 - val_accuracy: 0.9713 - val_loss: 0.1040
# Epoch 3/100
# 1490/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9762 - loss: 0.0874
# Epoch 3: val_loss did not improve from 0.10399
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9762 - loss: 0.0874 - val_accuracy: 0.9732 - val_loss: 0.1236
# Epoch 4/100
# 1490/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9800 - loss: 0.0773
# Epoch 4: val_loss did not improve from 0.10399
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9800 - loss: 0.0773 - val_accuracy: 0.9744 - val_loss: 0.1091
# Epoch 5/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9846 - loss: 0.0582
# Epoch 5: val_loss improved from 0.10399 to 0.09716, saving model to results/mnist/ffn.best.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9846 - loss: 0.0582 - val_accuracy: 0.9783 - val_loss: 0.0972
# Epoch 6/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9852 - loss: 0.0544
# Epoch 6: val_loss did not improve from 0.09716
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9852 - loss: 0.0544 - val_accuracy: 0.9760 - val_loss: 0.1193
# Epoch 7/100
# 1494/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9868 - loss: 0.0505
# Epoch 7: val_loss did not improve from 0.09716
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9868 - loss: 0.0506 - val_accuracy: 0.9794 - val_loss: 0.1047
# Epoch 8/100
# 1498/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9885 - loss: 0.0451
# Epoch 8: val_loss did not improve from 0.09716
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9885 - loss: 0.0452 - val_accuracy: 0.9794 - val_loss: 0.1101
# Epoch 9/100
# 1499/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9897 - loss: 0.0405
# Epoch 9: val_loss did not improve from 0.09716
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9897 - loss: 0.0405 - val_accuracy: 0.9779 - val_loss: 0.1238
# Epoch 10/100
# 1491/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9904 - loss: 0.0377
# Epoch 10: val_loss did not improve from 0.09716
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9904 - loss: 0.0377 - val_accuracy: 0.9804 - val_loss: 0.1283
# Epoch 11/100
# 1494/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9906 - loss: 0.0349
# Epoch 11: val_loss did not improve from 0.09716
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9906 - loss: 0.0349 - val_accuracy: 0.9803 - val_loss: 0.1296
# Epoch 12/100
# 1489/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9930 - loss: 0.0269
# Epoch 12: val_loss did not improve from 0.09716
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9930 - loss: 0.0269 - val_accuracy: 0.9793 - val_loss: 0.1385
# Epoch 13/100
# 1499/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9926 - loss: 0.0266
# Epoch 13: val_loss did not improve from 0.09716
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9926 - loss: 0.0266 - val_accuracy: 0.9808 - val_loss: 0.1449
# Epoch 14/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9928 - loss: 0.0328
# Epoch 14: val_loss did not improve from 0.09716
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9928 - loss: 0.0328 - val_accuracy: 0.9806 - val_loss: 0.1347
# Epoch 15/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9939 - loss: 0.0239
# Epoch 15: val_loss did not improve from 0.09716
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9939 - loss: 0.0239 - val_accuracy: 0.9803 - val_loss: 0.1410
# Epoch 16/100
# 1493/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9949 - loss: 0.0198
# Epoch 16: val_loss did not improve from 0.09716
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9949 - loss: 0.0198 - val_accuracy: 0.9792 - val_loss: 0.1553
# Epoch 17/100
# 1491/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9948 - loss: 0.0195
# Epoch 17: val_loss did not improve from 0.09716
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9948 - loss: 0.0195 - val_accuracy: 0.9806 - val_loss: 0.1528
# Epoch 18/100
# 1498/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9947 - loss: 0.0215
# Epoch 18: val_loss did not improve from 0.09716
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9947 - loss: 0.0215 - val_accuracy: 0.9814 - val_loss: 0.1563
# Epoch 19/100
# 1499/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9939 - loss: 0.0242
# Epoch 19: val_loss did not improve from 0.09716
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9939 - loss: 0.0242 - val_accuracy: 0.9801 - val_loss: 0.1436
# Epoch 20/100
# 1497/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9951 - loss: 0.0193
# Epoch 20: val_loss did not improve from 0.09716
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9951 - loss: 0.0193 - val_accuracy: 0.9824 - val_loss: 0.1357
# Epoch 21/100
# 1499/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9958 - loss: 0.0178
# Epoch 21: val_loss did not improve from 0.09716
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9958 - loss: 0.0178 - val_accuracy: 0.9818 - val_loss: 0.1489
# Epoch 22/100
# 1492/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9963 - loss: 0.0136
# Epoch 22: val_loss did not improve from 0.09716
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9963 - loss: 0.0136 - val_accuracy: 0.9820 - val_loss: 0.1665
# Epoch 23/100
# 1494/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9961 - loss: 0.0132
# Epoch 23: val_loss did not improve from 0.09716
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9961 - loss: 0.0132 - val_accuracy: 0.9816 - val_loss: 0.1641
# Epoch 24/100
# 1499/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9970 - loss: 0.0125
# Epoch 24: val_loss did not improve from 0.09716
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9970 - loss: 0.0125 - val_accuracy: 0.9809 - val_loss: 0.1798
# Epoch 25/100
# 1499/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9967 - loss: 0.0124
# Epoch 25: val_loss did not improve from 0.09716
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9967 - loss: 0.0124 - val_accuracy: 0.9822 - val_loss: 0.1624

# %% [markdown]
# ### Plot CV Results

# %%
pd.DataFrame(ffnn_history.history)[['accuracy', 'val_accuracy']].plot(figsize=(14,4))
sns.despine();

# %% [markdown]
# ### Load the Best Model

# %%
# load the weights that yielded the best validation accuracy
ffnn.load_weights(ffn_path.as_posix())

# %% [markdown]
# ### Test Classification Accuracy

# %%
# evaluate test accuracy
ffnn_accuracy = ffnn.evaluate(X_test, y_test, verbose=0)[1]

print(f'Test accuracy: {ffnn_accuracy:.2%}')
# Out:
# Test accuracy: 97.78%

# %% [markdown]
# ## LeNet5

# %%
K.clear_session()

# %% [markdown]
# ### Model Architecture

# %% [markdown]
# We can define a simplified version of LeNet5 that omits the original final layer containing radial basis functions as follows, using the default ‘valid’ padding and single step strides unless defined otherwise:

# %%
lenet5 = Sequential([
    Input(shape=(28, 28, 1)),
    Conv2D(filters=6,
           kernel_size=5,
           activation='relu',
           name='CONV1'),
    AveragePooling2D(pool_size=(2, 2),
                     strides=(1, 1),
                     padding='valid',
                     name='POOL1'),
    Conv2D(filters=16, kernel_size=(5, 5), activation='tanh', name='CONV2'),
    AveragePooling2D(pool_size=(2, 2), strides=(2, 2), name='POOL2'),
    Conv2D(filters=120, kernel_size=(5, 5), activation='tanh', name='CONV3'),
    Flatten(name='FLAT'),
    Dense(units=84, activation='tanh', name='FC6'),
    Dense(units=10, activation='softmax', name='FC7')
])

# %% [markdown]
# The summary indicates that the model thus defined has over 300,000 parameters:

# %%
lenet5.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ CONV1 (Conv2D)                  │ (None, 24, 24, 6)      │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ POOL1 (AveragePooling2D)        │ (None, 23, 23, 6)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ CONV2 (Conv2D)                  │ (None, 19, 19, 16)     │         2,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ POOL2 (AveragePooling2D)        │ (None, 9, 9, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ CONV3 (Conv2D)                  │ (None, 5, 5, 120)      │        48,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ FLAT (Flatten)                  │ (None, 3000)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ FC6 (Dense)                     │ (None, 84)             │       252,084 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ FC7 (Dense)                     │ (None, 10)             │           850 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 303,626 (1.16 MB)
#  Trainable params: 303,626 (1.16 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# We compile using crossentropy loss and the original stochastic gradient optimizer:

# %%
lenet5.compile(loss='sparse_categorical_crossentropy',
               optimizer='SGD',
               metrics=['accuracy'])

# %% [markdown]
# ### Define checkpoint callback

# %%
lenet_path = mnist_path / 'lenet.best.keras'

# %%
checkpointer = ModelCheckpoint(filepath=lenet_path.as_posix(),
                               verbose=1,
                               save_best_only=True)

# %% [markdown]
# Now we are ready to train the model. The model expects 4D input so we reshape accordingly. We use the standard batch size of 32, 80-20 train-validation split, use checkpointing to store the model weights if the validation error improves, and make sure the dataset is randomly shuffled:

# %% [markdown]
# ### Train Model

# %%
batch_size=32
epochs=100

# %%
lenet_history = lenet5.fit(
    X_train.reshape(-1, 28, 28, 1),
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_split=0.2,  # use 0 to train on all data
    callbacks=[checkpointer, early_stopping],
    verbose=1,
    shuffle=True)
# Out:
# Epoch 1/100
# 1493/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7791 - loss: 0.8034
# Epoch 1: val_loss improved from inf to 0.22977, saving model to results/mnist/lenet.best.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.7796 - loss: 0.8016 - val_accuracy: 0.9353 - val_loss: 0.2298
# Epoch 2/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9365 - loss: 0.2227
# Epoch 2: val_loss improved from 0.22977 to 0.15479, saving model to results/mnist/lenet.best.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9365 - loss: 0.2226 - val_accuracy: 0.9553 - val_loss: 0.1548
# Epoch 3/100
# 1496/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9572 - loss: 0.1459
# Epoch 3: val_loss improved from 0.15479 to 0.11712, saving model to results/mnist/lenet.best.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - accuracy: 0.9572 - loss: 0.1459 - val_accuracy: 0.9668 - val_loss: 0.1171
# Epoch 4/100
# 1495/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9680 - loss: 0.1123
# Epoch 4: val_loss improved from 0.11712 to 0.09837, saving model to results/mnist/lenet.best.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9680 - loss: 0.1123 - val_accuracy: 0.9716 - val_loss: 0.0984
# Epoch 5/100
# 1495/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9719 - loss: 0.0940
# Epoch 5: val_loss improved from 0.09837 to 0.08413, saving model to results/mnist/lenet.best.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9719 - loss: 0.0940 - val_accuracy: 0.9742 - val_loss: 0.0841
# Epoch 6/100
# 1496/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9760 - loss: 0.0806
# Epoch 6: val_loss improved from 0.08413 to 0.07458, saving model to results/mnist/lenet.best.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - accuracy: 0.9760 - loss: 0.0806 - val_accuracy: 0.9781 - val_loss: 0.0746
# Epoch 7/100
# 1496/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9810 - loss: 0.0666
# Epoch 7: val_loss improved from 0.07458 to 0.06953, saving model to results/mnist/lenet.best.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9810 - loss: 0.0666 - val_accuracy: 0.9795 - val_loss: 0.0695
# Epoch 8/100
# 1494/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9827 - loss: 0.0598
# Epoch 8: val_loss improved from 0.06953 to 0.06518, saving model to results/mnist/lenet.best.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9827 - loss: 0.0598 - val_accuracy: 0.9797 - val_loss: 0.0652
# Epoch 9/100
# 1491/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9844 - loss: 0.0533
# Epoch 9: val_loss improved from 0.06518 to 0.05946, saving model to results/mnist/lenet.best.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9844 - loss: 0.0533 - val_accuracy: 0.9829 - val_loss: 0.0595
# Epoch 10/100
# 1497/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9853 - loss: 0.0505
# Epoch 10: val_loss improved from 0.05946 to 0.05544, saving model to results/mnist/lenet.best.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9853 - loss: 0.0505 - val_accuracy: 0.9830 - val_loss: 0.0554
# Epoch 11/100
# 1497/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9874 - loss: 0.0453
# Epoch 11: val_loss improved from 0.05544 to 0.05439, saving model to results/mnist/lenet.best.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - accuracy: 0.9874 - loss: 0.0453 - val_accuracy: 0.9833 - val_loss: 0.0544
# Epoch 12/100
# 1495/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9889 - loss: 0.0401
# Epoch 12: val_loss improved from 0.05439 to 0.05130, saving model to results/mnist/lenet.best.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9889 - loss: 0.0401 - val_accuracy: 0.9854 - val_loss: 0.0513
# Epoch 13/100
# 1498/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9889 - loss: 0.0393
# Epoch 13: val_loss improved from 0.05130 to 0.05001, saving model to results/mnist/lenet.best.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9889 - loss: 0.0393 - val_accuracy: 0.9853 - val_loss: 0.0500
# Epoch 14/100
# 1497/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9908 - loss: 0.0342
# Epoch 14: val_loss did not improve from 0.05001
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9908 - loss: 0.0342 - val_accuracy: 0.9853 - val_loss: 0.0502
# Epoch 15/100
# 1491/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9906 - loss: 0.0333
# Epoch 15: val_loss improved from 0.05001 to 0.04801, saving model to results/mnist/lenet.best.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9906 - loss: 0.0333 - val_accuracy: 0.9859 - val_loss: 0.0480
# Epoch 16/100
# 1494/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9919 - loss: 0.0311
# Epoch 16: val_loss improved from 0.04801 to 0.04728, saving model to results/mnist/lenet.best.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9919 - loss: 0.0311 - val_accuracy: 0.9865 - val_loss: 0.0473
# Epoch 17/100
# 1499/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9917 - loss: 0.0290
# Epoch 17: val_loss improved from 0.04728 to 0.04468, saving model to results/mnist/lenet.best.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9917 - loss: 0.0290 - val_accuracy: 0.9867 - val_loss: 0.0447
# Epoch 18/100
# 1497/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9934 - loss: 0.0260
# Epoch 18: val_loss improved from 0.04468 to 0.04351, saving model to results/mnist/lenet.best.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9934 - loss: 0.0260 - val_accuracy: 0.9866 - val_loss: 0.0435
# Epoch 19/100
# 1494/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9931 - loss: 0.0263
# Epoch 19: val_loss did not improve from 0.04351
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9931 - loss: 0.0263 - val_accuracy: 0.9859 - val_loss: 0.0462
# Epoch 20/100
# 1492/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9937 - loss: 0.0252
# Epoch 20: val_loss improved from 0.04351 to 0.04283, saving model to results/mnist/lenet.best.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9937 - loss: 0.0252 - val_accuracy: 0.9875 - val_loss: 0.0428
# Epoch 21/100
# 1499/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9940 - loss: 0.0239
# Epoch 21: val_loss improved from 0.04283 to 0.04154, saving model to results/mnist/lenet.best.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9940 - loss: 0.0239 - val_accuracy: 0.9884 - val_loss: 0.0415
# Epoch 22/100
# 1499/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9947 - loss: 0.0224
# Epoch 22: val_loss did not improve from 0.04154
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9947 - loss: 0.0224 - val_accuracy: 0.9880 - val_loss: 0.0428
# Epoch 23/100
# 1496/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9952 - loss: 0.0199
# Epoch 23: val_loss improved from 0.04154 to 0.04149, saving model to results/mnist/lenet.best.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9952 - loss: 0.0199 - val_accuracy: 0.9872 - val_loss: 0.0415
# Epoch 24/100
# 1491/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9957 - loss: 0.0194
# Epoch 24: val_loss did not improve from 0.04149
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9957 - loss: 0.0194 - val_accuracy: 0.9873 - val_loss: 0.0428
# Epoch 25/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9951 - loss: 0.0195
# Epoch 25: val_loss did not improve from 0.04149
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9951 - loss: 0.0195 - val_accuracy: 0.9877 - val_loss: 0.0432
# Epoch 26/100
# 1496/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9956 - loss: 0.0184
# Epoch 26: val_loss improved from 0.04149 to 0.04040, saving model to results/mnist/lenet.best.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9956 - loss: 0.0184 - val_accuracy: 0.9883 - val_loss: 0.0404
# Epoch 27/100
# 1498/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9964 - loss: 0.0164
# Epoch 27: val_loss improved from 0.04040 to 0.03979, saving model to results/mnist/lenet.best.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9964 - loss: 0.0164 - val_accuracy: 0.9879 - val_loss: 0.0398
# Epoch 28/100
# 1496/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9962 - loss: 0.0163
# Epoch 28: val_loss improved from 0.03979 to 0.03875, saving model to results/mnist/lenet.best.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9962 - loss: 0.0163 - val_accuracy: 0.9888 - val_loss: 0.0387
# Epoch 29/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9972 - loss: 0.0148
# Epoch 29: val_loss did not improve from 0.03875
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9972 - loss: 0.0148 - val_accuracy: 0.9880 - val_loss: 0.0403
# Epoch 30/100
# 1499/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9964 - loss: 0.0154
# Epoch 30: val_loss did not improve from 0.03875
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9964 - loss: 0.0154 - val_accuracy: 0.9880 - val_loss: 0.0400
# Epoch 31/100
# 1499/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9969 - loss: 0.0145
# Epoch 31: val_loss improved from 0.03875 to 0.03862, saving model to results/mnist/lenet.best.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9969 - loss: 0.0145 - val_accuracy: 0.9881 - val_loss: 0.0386
# Epoch 32/100
# 1499/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9969 - loss: 0.0142
# Epoch 32: val_loss improved from 0.03862 to 0.03805, saving model to results/mnist/lenet.best.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9969 - loss: 0.0142 - val_accuracy: 0.9893 - val_loss: 0.0381
# Epoch 33/100
# 1494/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9973 - loss: 0.0127
# Epoch 33: val_loss did not improve from 0.03805
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9973 - loss: 0.0127 - val_accuracy: 0.9883 - val_loss: 0.0388
# Epoch 34/100
# 1492/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9978 - loss: 0.0124
# Epoch 34: val_loss did not improve from 0.03805
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9978 - loss: 0.0124 - val_accuracy: 0.9882 - val_loss: 0.0391
# Epoch 35/100
# 1494/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9976 - loss: 0.0116
# Epoch 35: val_loss did not improve from 0.03805
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9976 - loss: 0.0116 - val_accuracy: 0.9886 - val_loss: 0.0382
# Epoch 36/100
# 1492/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9979 - loss: 0.0110
# Epoch 36: val_loss improved from 0.03805 to 0.03778, saving model to results/mnist/lenet.best.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9979 - loss: 0.0110 - val_accuracy: 0.9891 - val_loss: 0.0378
# Epoch 37/100
# 1496/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9976 - loss: 0.0111
# Epoch 37: val_loss did not improve from 0.03778
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9976 - loss: 0.0111 - val_accuracy: 0.9889 - val_loss: 0.0381
# Epoch 38/100
# 1497/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9985 - loss: 0.0094
# Epoch 38: val_loss did not improve from 0.03778
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9985 - loss: 0.0094 - val_accuracy: 0.9885 - val_loss: 0.0399
# Epoch 39/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9982 - loss: 0.0097
# Epoch 39: val_loss improved from 0.03778 to 0.03694, saving model to results/mnist/lenet.best.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9982 - loss: 0.0097 - val_accuracy: 0.9892 - val_loss: 0.0369
# Epoch 40/100
# 1498/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9987 - loss: 0.0091
# Epoch 40: val_loss did not improve from 0.03694
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9987 - loss: 0.0091 - val_accuracy: 0.9886 - val_loss: 0.0377
# Epoch 41/100
# 1494/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9984 - loss: 0.0091
# Epoch 41: val_loss improved from 0.03694 to 0.03651, saving model to results/mnist/lenet.best.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9984 - loss: 0.0091 - val_accuracy: 0.9893 - val_loss: 0.0365
# Epoch 42/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9986 - loss: 0.0089
# Epoch 42: val_loss did not improve from 0.03651
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9986 - loss: 0.0089 - val_accuracy: 0.9884 - val_loss: 0.0374
# Epoch 43/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9988 - loss: 0.0078
# Epoch 43: val_loss did not improve from 0.03651
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9988 - loss: 0.0078 - val_accuracy: 0.9896 - val_loss: 0.0366
# Epoch 44/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9987 - loss: 0.0080
# Epoch 44: val_loss improved from 0.03651 to 0.03644, saving model to results/mnist/lenet.best.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - accuracy: 0.9987 - loss: 0.0080 - val_accuracy: 0.9888 - val_loss: 0.0364
# Epoch 45/100
# 1495/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9991 - loss: 0.0073
# Epoch 45: val_loss did not improve from 0.03644
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.9991 - loss: 0.0073 - val_accuracy: 0.9883 - val_loss: 0.0368
# Epoch 46/100
# 1498/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9993 - loss: 0.0065
# Epoch 46: val_loss improved from 0.03644 to 0.03627, saving model to results/mnist/lenet.best.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9993 - loss: 0.0065 - val_accuracy: 0.9890 - val_loss: 0.0363
# Epoch 47/100
# 1494/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9991 - loss: 0.0070
# Epoch 47: val_loss did not improve from 0.03627
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9991 - loss: 0.0070 - val_accuracy: 0.9893 - val_loss: 0.0366
# Epoch 48/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9990 - loss: 0.0070
# Epoch 48: val_loss did not improve from 0.03627
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9990 - loss: 0.0070 - val_accuracy: 0.9893 - val_loss: 0.0368
# Epoch 49/100
# 1492/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9991 - loss: 0.0066
# Epoch 49: val_loss improved from 0.03627 to 0.03598, saving model to results/mnist/lenet.best.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9991 - loss: 0.0066 - val_accuracy: 0.9889 - val_loss: 0.0360
# Epoch 50/100
# 1495/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9994 - loss: 0.0061
# Epoch 50: val_loss did not improve from 0.03598
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9994 - loss: 0.0061 - val_accuracy: 0.9888 - val_loss: 0.0363
# Epoch 51/100
# 1492/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9993 - loss: 0.0060
# Epoch 51: val_loss did not improve from 0.03598
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9993 - loss: 0.0060 - val_accuracy: 0.9893 - val_loss: 0.0363
# Epoch 52/100
# 1496/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9995 - loss: 0.0056
# Epoch 52: val_loss improved from 0.03598 to 0.03591, saving model to results/mnist/lenet.best.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9995 - loss: 0.0056 - val_accuracy: 0.9895 - val_loss: 0.0359
# Epoch 53/100
# 1492/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9994 - loss: 0.0057
# Epoch 53: val_loss improved from 0.03591 to 0.03567, saving model to results/mnist/lenet.best.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9994 - loss: 0.0057 - val_accuracy: 0.9894 - val_loss: 0.0357
# Epoch 54/100
# 1494/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9995 - loss: 0.0055
# Epoch 54: val_loss did not improve from 0.03567
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9995 - loss: 0.0055 - val_accuracy: 0.9885 - val_loss: 0.0370
# Epoch 55/100
# 1498/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9995 - loss: 0.0050
# Epoch 55: val_loss improved from 0.03567 to 0.03535, saving model to results/mnist/lenet.best.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9995 - loss: 0.0050 - val_accuracy: 0.9894 - val_loss: 0.0353
# Epoch 56/100
# 1496/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9995 - loss: 0.0051
# Epoch 56: val_loss did not improve from 0.03535
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9995 - loss: 0.0051 - val_accuracy: 0.9883 - val_loss: 0.0373
# Epoch 57/100
# 1495/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9995 - loss: 0.0049
# Epoch 57: val_loss did not improve from 0.03535
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9995 - loss: 0.0049 - val_accuracy: 0.9890 - val_loss: 0.0361
# Epoch 58/100
# 1498/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9996 - loss: 0.0047
# Epoch 58: val_loss did not improve from 0.03535
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9996 - loss: 0.0047 - val_accuracy: 0.9894 - val_loss: 0.0362
# Epoch 59/100
# 1498/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9997 - loss: 0.0045
# Epoch 59: val_loss did not improve from 0.03535
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9997 - loss: 0.0045 - val_accuracy: 0.9895 - val_loss: 0.0371
# Epoch 60/100
# 1499/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9994 - loss: 0.0047
# Epoch 60: val_loss did not improve from 0.03535
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9994 - loss: 0.0047 - val_accuracy: 0.9893 - val_loss: 0.0361
# Epoch 61/100
# 1495/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9997 - loss: 0.0042
# Epoch 61: val_loss did not improve from 0.03535
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9997 - loss: 0.0042 - val_accuracy: 0.9894 - val_loss: 0.0361
# Epoch 62/100
# 1496/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9996 - loss: 0.0043
# Epoch 62: val_loss did not improve from 0.03535
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9996 - loss: 0.0043 - val_accuracy: 0.9893 - val_loss: 0.0357
# Epoch 63/100
# 1499/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9995 - loss: 0.0040
# Epoch 63: val_loss did not improve from 0.03535
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9995 - loss: 0.0040 - val_accuracy: 0.9892 - val_loss: 0.0366
# Epoch 64/100
# 1491/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9996 - loss: 0.0040
# Epoch 64: val_loss improved from 0.03535 to 0.03521, saving model to results/mnist/lenet.best.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9996 - loss: 0.0040 - val_accuracy: 0.9896 - val_loss: 0.0352
# Epoch 65/100
# 1497/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9998 - loss: 0.0037
# Epoch 65: val_loss did not improve from 0.03521
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9998 - loss: 0.0037 - val_accuracy: 0.9890 - val_loss: 0.0360
# Epoch 66/100
# 1492/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9995 - loss: 0.0041
# Epoch 66: val_loss did not improve from 0.03521
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9995 - loss: 0.0041 - val_accuracy: 0.9894 - val_loss: 0.0353
# Epoch 67/100
# 1491/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9998 - loss: 0.0035
# Epoch 67: val_loss did not improve from 0.03521
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9998 - loss: 0.0035 - val_accuracy: 0.9895 - val_loss: 0.0362
# Epoch 68/100
# 1495/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9998 - loss: 0.0034
# Epoch 68: val_loss did not improve from 0.03521
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9998 - loss: 0.0034 - val_accuracy: 0.9895 - val_loss: 0.0359
# Epoch 69/100
# 1497/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9998 - loss: 0.0036
# Epoch 69: val_loss did not improve from 0.03521
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9998 - loss: 0.0036 - val_accuracy: 0.9898 - val_loss: 0.0362
# Epoch 70/100
# 1492/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9998 - loss: 0.0032
# Epoch 70: val_loss did not improve from 0.03521
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9998 - loss: 0.0032 - val_accuracy: 0.9898 - val_loss: 0.0356
# Epoch 71/100
# 1492/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9998 - loss: 0.0034
# Epoch 71: val_loss did not improve from 0.03521
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9998 - loss: 0.0034 - val_accuracy: 0.9894 - val_loss: 0.0359
# Epoch 72/100
# 1494/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9998 - loss: 0.0032
# Epoch 72: val_loss did not improve from 0.03521
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9998 - loss: 0.0032 - val_accuracy: 0.9898 - val_loss: 0.0355
# Epoch 73/100
# 1493/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9998 - loss: 0.0031
# Epoch 73: val_loss did not improve from 0.03521
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - accuracy: 0.9998 - loss: 0.0031 - val_accuracy: 0.9898 - val_loss: 0.0360
# Epoch 74/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9998 - loss: 0.0029
# Epoch 74: val_loss did not improve from 0.03521
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9998 - loss: 0.0029 - val_accuracy: 0.9895 - val_loss: 0.0362
# Epoch 75/100
# 1498/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9998 - loss: 0.0031
# Epoch 75: val_loss did not improve from 0.03521
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9998 - loss: 0.0031 - val_accuracy: 0.9899 - val_loss: 0.0354
# Epoch 76/100
# 1499/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9998 - loss: 0.0029
# Epoch 76: val_loss did not improve from 0.03521
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9998 - loss: 0.0029 - val_accuracy: 0.9902 - val_loss: 0.0356
# Epoch 77/100
# 1498/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9999 - loss: 0.0028
# Epoch 77: val_loss did not improve from 0.03521
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9999 - loss: 0.0028 - val_accuracy: 0.9896 - val_loss: 0.0358
# Epoch 78/100
# 1496/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9999 - loss: 0.0027
# Epoch 78: val_loss did not improve from 0.03521
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9999 - loss: 0.0027 - val_accuracy: 0.9896 - val_loss: 0.0362
# Epoch 79/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9999 - loss: 0.0027
# Epoch 79: val_loss did not improve from 0.03521
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9999 - loss: 0.0027 - val_accuracy: 0.9893 - val_loss: 0.0365
# Epoch 80/100
# 1498/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9999 - loss: 0.0026
# Epoch 80: val_loss did not improve from 0.03521
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9999 - loss: 0.0026 - val_accuracy: 0.9898 - val_loss: 0.0359
# Epoch 81/100
# 1496/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9998 - loss: 0.0027
# Epoch 81: val_loss did not improve from 0.03521
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9998 - loss: 0.0027 - val_accuracy: 0.9892 - val_loss: 0.0364
# Epoch 82/100
# 1494/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9999 - loss: 0.0025
# Epoch 82: val_loss did not improve from 0.03521
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9999 - loss: 0.0025 - val_accuracy: 0.9900 - val_loss: 0.0362
# Epoch 83/100
# 1496/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9999 - loss: 0.0025
# Epoch 83: val_loss did not improve from 0.03521
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9999 - loss: 0.0025 - val_accuracy: 0.9898 - val_loss: 0.0359
# Epoch 84/100
# 1495/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0023
# Epoch 84: val_loss did not improve from 0.03521
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.9898 - val_loss: 0.0357

# %% [markdown]
# ### Plot CV Results

# %% [markdown]
# On a single GPU, 50 epochs take around 2.5 minutes, resulting in a test accuracy of 99.09%, slightly below the same result as for the original LeNet5:

# %%
pd.DataFrame(lenet_history.history)[['accuracy', 'val_accuracy']].plot(figsize=(14,4))
sns.despine();

# %% [markdown]
# ### Test Classification Accuracy

# %%
# evaluate test accuracy
lenet_accuracy = lenet5.evaluate(X_test.reshape(-1, 28, 28, 1), y_test, verbose=0)[1]
print('Test accuracy: {:.2%}'.format(lenet_accuracy))
# Out:
# Test accuracy: 98.98%

# %% [markdown]
# ## Summary

# %% [markdown]
# For comparison, a simple two-layer feedforward network achieves only 37.36% test accuracy.
#
# The LeNet5 improvement on MNIST is, in fact, modest. Non-neural methods have also achieved classification accuracies greater than or equal to 99%, including K-Nearest Neighbours or Support Vector Machines. CNNs really shine with more challenging datasets as we will see next.
